# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats.mstats import winsorize
import re
from ipywidgets import interact, Dropdown, IntSlider, Output, widgets
from IPython.display import display

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10, 6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)

pd.options.display.max_rows = 500    # pd.set_option('display.max_rows', None)
pd.options.display.max_columns = 150 # pd.set_option('display.max_columns', None)

# %%
df0 = pd.read_csv("autoscout_cleaned.csv")
df = df0.copy()

# %%
df.shape
# Out:
# (2364, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2364 entries, 0 to 2363
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   make_model               2364 non-null   object
#  1   short_description        2362 non-null   object
#  2   make                     2364 non-null   object
#  3   model                    2364 non-null   object
#  4   location                 2364 non-null   object
#  5   price                    2364 non-null   float64
#  6   body_type                2364 non-null   object
#  7   type                     2364 non-null   object
#  8   doors                    2364 non-null   float64
#  9   warranty                 2364 non-null   object
#  10  mileage                  2364 non-null   float64
#  11  first_registration       2364 non-null   object
#  12  gearbox                  2364 non-null   object
#  13  fuel_type                2210 non-null   object
#  14  seller                   2364 non-null   object
#  15  seats                    2339 non-null   float64
#  16  engine_size              2358 non-null   float64
#  17  gears                    2116 non-null   float64
#  18  co_emissions             2364 non-null   float64
#  19  drivetrain               1110 non-null   object
#  20  cylinders                2104 non-null   float64
#  21  comfort_&_convenience    2361 non-null   object
#  22  entertainment_&_media    2359 non-null   object
#  23  safety_&_security        2361 non-null   object
#  24  extras                   2359 non-null   object
#  25  empty_weight             2179 non-null   float64
#  26  full_service_history     2364 non-null   object
#  27  upholstery               2230 non-null   object
#  28  production_date          2364 non-null   float64
#  29  previous_owner           2204 non-null   float64
#  30  energy_efficiency_class  2364 non-null   object
#  31  new                      2364 non-null   object
#  32  combined_fuel_cons       2364 non-null   float64
# dtypes: float64(12), object(21)
# memory usage: 609.6+ KB

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df)
# Out:
# Column short_description has mixed object types.
# Column fuel_type has mixed object types.
# Column drivetrain has mixed object types.
# Column comfort_&_convenience has mixed object types.
# Column entertainment_&_media has mixed object types.
# Column safety_&_security has mixed object types.
# Column extras has mixed object types.
# Column upholstery has mixed object types.
#  NO PROBLEM  with the data types of Columns in the DataFrame.

# %% [markdown]
# MISSING VALUES

# %%
missing_percentage = df.isnull().sum()*100 / df.shape[0]

# %% [markdown]
# LIST COMPREHENSION
#  % OF EACH COLUMN IN THE OUTPUT

# %%
miss_val = []
[miss_val.append(column) for column in df.columns if any(df[column].isnull())]

missing_percentage = df[miss_val].isnull().sum()*100 / df[miss_val].shape[0]
missing_percentage = missing_percentage.sort_values(ascending=False)
print("Columns that have missing values :")
print("---"*11)
print(f"{miss_val}\n\n{missing_percentage}")
# Out:
# Columns that have missing values :
# ---------------------------------
# ['short_description', 'fuel_type', 'seats', 'engine_size', 'gears', 'drivetrain', 'cylinders', 'comfort_&_convenience', 'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight', 'upholstery', 'previous_owner']
#
# drivetrain              53.05
# cylinders               11.00
# gears                   10.49
# empty_weight             7.83
# previous_owner           6.77
# fuel_type                6.51
# upholstery               5.67
# seats                    1.06
# engine_size              0.25
# entertainment_&_media    0.21
# extras                   0.21
# comfort_&_convenience    0.13
# safety_&_security        0.13
# short_description        0.08
# dtype: float64

# %%
def df_nans(df, limit):
    """
    Returns a Pandas Series containing the percentage of missing values in each column of the input DataFrame 'df' that
    exceeds the given 'limit'.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to analyze for missing values.
    limit : float
        The threshold (in percentage) above which to consider a column as having too many missing values.

    Returns:
    --------
    pandas.Series
        A Series containing the percentage of missing values in each column of the input DataFrame 'df' that exceeds
        the given 'limit'.
        If no column has missing values that exceed the given limit, returns a string message indicating this.
    """
    missing = df.isnull().sum()*100 / df.shape[0]
    missing = missing.loc[lambda x : x >= limit]
    if missing.empty:
        return "No columns have missing values that exceed the given limit."
    else:
        return missing

def show_missing_values(limit):
    return df_nans(df, limit)

def column_nans(serial):
    # display percentage of NaNs in a Series
    return serial.isnull().sum()*100 / serial.shape[0]

# %%
# the percentage of missing values in each column that exceeds the given 'limit'.

interact(show_missing_values, limit=(0, 100, 5))
# Out:
# interactive(children=(IntSlider(value=50, description='limit', step=5), Output()), _dom_classes=('widget-inter…
# <function __main__.show_missing_values(limit)>

# %% [markdown]
# DUPLICATION

# %%
df.duplicated(keep=False).sum()
# Out:
# 317

# %%
df[df.duplicated(keep=False)]
# Out:
#                    make_model  \
# 79       Mercedes-Benz AMG GT
# 80       Mercedes-Benz AMG GT
# 83     Mercedes-Benz S 63 AMG
# 84     Mercedes-Benz S 63 AMG
# 141    Mercedes-Benz C 43 AMG
# 142    Mercedes-Benz C 43 AMG
# 203       Mercedes-Benz G 400
# 204       Mercedes-Benz G 400
# 263       Mercedes-Benz C 200
# 264       Mercedes-Benz C 200
# 271       Mercedes-Benz C 220
# 272       Mercedes-Benz C 220
# 552          Opel Grandland X
# 553          Opel Grandland X
# 554          Opel Crossland X
# 564          Opel Crossland X
# 581          Opel Grandland X
# 585          Opel Grandland X
# 587          Opel Grandland X
# 588          Opel Grandland X
# 625          Opel Crossland X
# 632          Opel Crossland X
# 653                Opel Mokka
# 654                Opel Mokka
# 1202             Skoda Kodiaq
# 1205             Skoda Kodiaq
# 1207             Skoda Kodiaq
# 1239            Skoda Octavia
# 1243            Skoda Octavia
# 1308            Dacia Sandero
# 1309            Dacia Sandero
# 1425            Toyota Proace
# 1427              Toyota C-HR
# 1430              Toyota C-HR
# 1459            Toyota Proace
# 1556             Nissan Micra
# 1564             Nissan Micra
# 1637          Nissan Townstar
# 1643          Nissan Townstar
# 1693            Ford EcoSport
# 1694            Ford EcoSport
# 1769                Ford Kuga
# 1770                Ford Kuga
# 1901               Ford Focus
# 1902               Ford Focus
# 1934              Ford Fiesta
# 1935              Ford Fiesta
# 2068               Volvo XC60
# 2069               Volvo XC60
# 2070               Volvo XC60
# 2071               Volvo XC60
# 2072               Volvo XC60
# 2073               Volvo XC60
# 2074               Volvo XC60
# 2075               Volvo XC40
# 2076               Volvo XC60
# 2077               Volvo XC90
# 2078               Volvo XC60
# 2079               Volvo XC40
# 2080               Volvo XC40
# 2081               Volvo XC90
# 2082               Volvo XC60
# 2083               Volvo XC40
# 2084               Volvo XC90
# 2085               Volvo XC90
# 2086               Volvo XC60
# 2087               Volvo XC90
# 2088               Volvo XC40
# 2089               Volvo XC60
# 2090               Volvo XC40
# 2091               Volvo XC90
# 2092               Volvo XC90
# 2093               Volvo XC40
# 2094               Volvo XC90
# 2095               Volvo XC60
# 2096               Volvo XC40
# 2097               Volvo XC90
# 2098               Volvo XC40
# 2099               Volvo XC40
# 2100               Volvo XC60
# 2101               Volvo XC40
# 2102               Volvo XC90
# 2103               Volvo XC60
# 2104               Volvo XC40
# 2105               Volvo XC40
# 2106               Volvo XC60
# 2107               Volvo XC40
# 2108               Volvo XC60
# 2109               Volvo XC60
# 2110               Volvo XC60
# 2111               Volvo XC40
# 2112               Volvo XC90
# 2113               Volvo XC60
# 2114               Volvo XC40
# 2115               Volvo XC60
# 2116               Volvo XC40
# 2117               Volvo XC90
# 2118               Volvo XC60
# 2119               Volvo XC90
# 2120               Volvo XC60
# 2121               Volvo XC60
# 2122               Volvo XC40
# 2123               Volvo XC40
# 2124               Volvo XC40
# 2125               Volvo XC40
# 2126               Volvo XC40
# 2127               Volvo XC60
# 2128               Volvo XC60
# 2129               Volvo XC60
# 2130               Volvo XC40
# 2131               Volvo XC60
# 2132               Volvo XC40
# 2133               Volvo XC40
# 2134               Volvo XC90
# 2135               Volvo XC60
# 2136               Volvo XC60
# 2137               Volvo XC60
# 2138               Volvo XC60
# 2139               Volvo XC60
# 2140               Volvo XC40
# 2141               Volvo XC60
# 2142               Volvo XC90
# 2143               Volvo XC60
# 2144               Volvo XC40
# 2145               Volvo XC40
# 2146               Volvo XC90
# 2147               Volvo XC60
# 2148               Volvo XC40
# 2149               Volvo XC90
# 2150               Volvo XC90
# 2151               Volvo XC60
# 2152               Volvo XC90
# 2153               Volvo XC40
# 2154               Volvo XC60
# 2155               Volvo XC40
# 2156               Volvo XC90
# 2157               Volvo XC90
# 2158               Volvo XC40
# 2159               Volvo XC90
# 2160               Volvo XC60
# 2161               Volvo XC40
# 2162               Volvo XC90
# 2163               Volvo XC40
# 2164               Volvo XC40
# 2165               Volvo XC60
# 2166               Volvo XC40
# 2167               Volvo XC90
# 2168               Volvo XC60
# 2169               Volvo XC60
# 2170               Volvo XC40
# 2171               Volvo XC60
# 2172               Volvo XC60
# 2173               Volvo XC60
# 2174               Volvo XC40
# 2175               Volvo XC90
# 2176               Volvo XC60
# 2177               Volvo XC40
# 2178               Volvo XC60
# 2179               Volvo XC40
# 2180               Volvo XC90
# 2181               Volvo XC60
# 2182               Volvo XC90
# 2183               Volvo XC60
# 2184               Volvo XC60
# 2185               Volvo XC40
# 2186               Volvo XC60
# 2187               Volvo XC60
# 2188               Volvo XC60
# 2189               Volvo XC40
# 2190               Volvo XC60
# 2191               Volvo XC40
# 2192               Volvo XC40
# 2193               Volvo XC90
# 2194                Volvo V60
# 2195                Volvo V60
# 2196                Volvo V60
# 2197                Volvo V60
# 2198                Volvo V60
# 2199                Volvo V90
# 2200                Volvo V60
# 2201                Volvo V60
# 2202  Volvo V60 Cross Country
# 2203                Volvo V90
# 2204                Volvo V60
# 2205                Volvo V60
# 2206                Volvo V90
# 2209  Volvo V90 Cross Country
# 2210  Volvo V90 Cross Country
# 2211  Volvo V90 Cross Country
# 2212                Volvo V60
# 2213                Volvo V60
# 2214  Volvo V90 Cross Country
# 2215                Volvo V60
# 2216                Volvo V60
# 2217                Volvo V60
# 2218  Volvo V90 Cross Country
# 2220                Volvo V90
# 2221                Volvo V90
# 2222                Volvo V90
# 2223                Volvo V60
# 2224                Volvo V90
# 2225                Volvo V90
# 2226                Volvo V60
# 2227  Volvo V90 Cross Country
# 2228  Volvo V90 Cross Country
# 2229                Volvo V90
# 2230  Volvo V90 Cross Country
# 2231  Volvo V90 Cross Country
# 2232                Volvo V90
# 2233                Volvo V90
# 2234                Volvo V90
# 2235                Volvo V60
# 2237                Volvo V60
# 2238                Volvo V60
# 2239                Volvo V90
# 2240                Volvo V90
# 2241  Volvo V60 Cross Country
# 2242  Volvo V60 Cross Country
# 2243                Volvo V90
# 2244                Volvo V90
# 2245                Volvo V90
# 2246                Volvo V60
# 2247                Volvo V40
# 2248                Volvo V60
# 2249                Volvo V60
# 2250  Volvo V90 Cross Country
# 2251  Volvo V90 Cross Country
# 2252                Volvo V90
# 2253                Volvo V60
# 2254                Volvo V60
# 2255  Volvo V60 Cross Country
# 2256                Volvo V60
# 2257                Volvo V60
# 2258  Volvo V90 Cross Country
# 2259                Volvo V60
# 2260                Volvo V40
# 2261                Volvo V90
# 2262  Volvo V90 Cross Country
# 2263                Volvo V60
# 2264                Volvo V60
# 2265                Volvo V60
# 2266                Volvo V40
# 2267                Volvo V60
# 2268  Volvo V90 Cross Country
# 2269  Volvo V90 Cross Country
# 2270                Volvo V60
# 2271                Volvo V60
# 2272                Volvo V60
# 2273                Volvo V60
# 2274                Volvo V60
# 2275                Volvo V60
# 2276                Volvo V90
# 2277                Volvo V60
# 2278                Volvo V60
# 2279  Volvo V60 Cross Country
# 2280                Volvo V90
# 2281                Volvo V60
# 2282                Volvo V60
# 2283                Volvo V90
# 2286  Volvo V90 Cross Country
# 2287  Volvo V90 Cross Country
# 2288  Volvo V90 Cross Country
# 2289                Volvo V60
# 2290                Volvo V60
# 2291  Volvo V90 Cross Country
# 2292                Volvo V60
# 2293                Volvo V60
# 2294                Volvo V60
# 2295  Volvo V90 Cross Country
# 2297                Volvo V90
# 2298                Volvo V90
# 2299                Volvo V90
# 2300                Volvo V60
# 2301                Volvo V90
# 2302                Volvo V90
# 2303                Volvo V60
# 2304  Volvo V90 Cross Country
# 2305  Volvo V90 Cross Country
# 2306                Volvo V90
# 2307  Volvo V90 Cross Country
# 2308  Volvo V90 Cross Country
# 2309                Volvo V90
# 2310                Volvo V90
# 2311                Volvo V90
# 2312                Volvo V60
# 2314                Volvo V60
# 2315                Volvo V60
# 2316                Volvo V90
# 2317                Volvo V90
# 2318  Volvo V60 Cross Country
# 2319  Volvo V60 Cross Country
# 2320                Volvo V90
# 2321                Volvo V90
# 2322                Volvo V90
# 2323                Volvo V60
# 2324                Volvo V40
# 2325                Volvo V60
# 2326                Volvo V60
# 2327  Volvo V90 Cross Country
# 2328  Volvo V90 Cross Country
# 2329                Volvo V90
# 2330                Volvo V60
# 2331                Volvo V60
# 2332  Volvo V60 Cross Country
# 2333                Volvo V60
# 2334                Volvo V60
# 2335  Volvo V90 Cross Country
# 2336                Volvo V60
# 2337                Volvo V40
# 2338                Volvo V90
# 2339  Volvo V90 Cross Country
# 2340                Volvo V60
# 2341                Volvo V40
# 2342                Volvo V60
# 2343  Volvo V90 Cross Country
# 2344  Volvo V90 Cross Country
# 2345                Volvo V60
#
#                                       short_description           make  \
# 79     GT 63 S AMG 4M+ Com/SHD/360/KeyG/Massage/Sitzkil  Mercedes-Benz
# 80     GT 63 S AMG 4M+ Com/SHD/360/KeyG/Massage/Sitzkil  Mercedes-Benz
# 83              4M+ Pano+DISTRONIC+HUP+TV+ILS+Swarovski  Mercedes-Benz
# 84              4M+ Pano+DISTRONIC+HUP+TV+ILS+Swarovski  Mercedes-Benz
# 141               4M Coupé 19"+PANO+MULTIBEAM+BURMESTER  Mercedes-Benz
# 142               4M Coupé 19"+PANO+MULTIBEAM+BURMESTER  Mercedes-Benz
# 203            d AMG/20"/Multibeam/Burmester/360°K/AHK/  Mercedes-Benz
# 204            d AMG/20"/Multibeam/Burmester/360°K/AHK/  Mercedes-Benz
# 263                                          T AMG Line  Mercedes-Benz
# 264                                          T AMG Line  Mercedes-Benz
# 271            d T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ  Mercedes-Benz
# 272            d T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ  Mercedes-Benz
# 552               INNOVATION 4 FLA+SpurW+LED+LM+KlimaA+           Opel
# 553               INNOVATION 4 FLA+SpurW+LED+LM+KlimaA+           Opel
# 554    Crossland 1.2T Elegance *Sitz- + Lenkradheizung*           Opel
# 564    Crossland 1.2T Elegance *Sitz- + Lenkradheizung*           Opel
# 581                  1.2 Turbo 120 Jahre FLA LM 2xKlima           Opel
# 585                  1.2 Turbo 120 Jahre FLA LM 2xKlima           Opel
# 587                 2.0 D 120 Jahre FLA LM 2xKlima Navi           Opel
# 588                 2.0 D 120 Jahre FLA LM 2xKlima Navi           Opel
# 625     Crossland 1.2 T Elegance *Sitz-+Lenkradheizung*           Opel
# 632     Crossland 1.2 T Elegance *Sitz-+Lenkradheizung*           Opel
# 653              EDITION 1.2 ANGEBOT FÜR GEWERBEKUNDEN!           Opel
# 654              EDITION 1.2 ANGEBOT FÜR GEWERBEKUNDEN!           Opel
# 1202        Style 2.0 TSI OPF DSG 4x4 7-SITZER NAVI LED          Skoda
# 1205        Style 2.0 TSI OPF DSG 4x4 7-SITZER NAVI LED          Skoda
# 1207        Style 2.0 TSI OPF DSG 4x4 7-SITZER NAVI LED          Skoda
# 1239              RS Combi 5J Garantie/Columbus SOFORT!          Skoda
# 1243              RS Combi 5J Garantie/Columbus SOFORT!          Skoda
# 1308   Stepway 3 Comfort TCe 90 Keyless, PDC v+h+Kamera          Dacia
# 1309   Stepway 3 Comfort TCe 90 Keyless, PDC v+h+Kamera          Dacia
# 1425              Comfort L2 1.5 D-4D SOFORT lieferbar!         Toyota
# 1427                        2.0 Hybrid Team Deutschland         Toyota
# 1430                        2.0 Hybrid Team Deutschland         Toyota
# 1459              Comfort L2 1.5 D-4D SOFORT lieferbar!         Toyota
# 1556         1.0 92PS N-WAY PDC Sitzh. Bluetooth ZV EFH         Nissan
# 1564         1.0 92PS N-WAY PDC Sitzh. Bluetooth ZV EFH         Nissan
# 1637         Kombi L1 1.3 DIG-T 130PS 6MT N-DESIGN Navi         Nissan
# 1643         Kombi L1 1.3 DIG-T 130PS 6MT N-DESIGN Navi         Nissan
# 1693              Active 1.0 *LED*B&O*BLIS*SHZ*CAM*PDC*           Ford
# 1694              Active 1.0 *LED*B&O*BLIS*SHZ*CAM*PDC*           Ford
# 1769           2.0 Hybrid ST-LINE X *LED *ACC *PDC *RFK           Ford
# 1770           2.0 Hybrid ST-LINE X *LED *ACC *PDC *RFK           Ford
# 1901         Active Style 1.0 Hybrid *LED*CAM*NAVI*ACC*           Ford
# 1902         Active Style 1.0 Hybrid *LED*CAM*NAVI*ACC*           Ford
# 1934                     1.0 EcoBoost S&S Aut. TITANIUM           Ford
# 1935                     1.0 EcoBoost S&S Aut. TITANIUM           Ford
# 2068  R Design Plug-In Hybrid Twin Engine EU6d Recharge          Volvo
# 2069  R Design Plug-In Hybrid Twin Engine EU6d Recharge          Volvo
# 2070          R Design AWD T6 AHK Standh. Polestar Navi          Volvo
# 2071  R DesignPlug-In Hybrid AWD T8 EU6d-Temp,HUD,Ka...          Volvo
# 2072  R Design AWD T8 EU6dtemp,Kamera,HeadUp,Standh,...          Volvo
# 2073  T8 AWD Polestar Engineered EU6d MY22 22'' HUD AHK          Volvo
# 2074  T8 AWD Polestar Engineered EU6d MY22 22'' HUD AHK          Volvo
# 2075  Momentum Pro 2WD D3 EU6d-Temp, Kamera,Sitzheiz...          Volvo
# 2076  R Design Plug-In Hybrid AWD T8,LM22,Keyless,Pa...          Volvo
# 2077  Momentum AWD D5 Scheckheft Leder LED Navi ACC ...          Volvo
# 2078  Recharge T8 AWD Polestar Engineered EU6d 22'' ...          Volvo
# 2079                         D3 Geartronic Momentum Pro          Volvo
# 2080  Momentum 2WD D3 EU6d-Temp,LM19,DAB,Lenkradheiz...          Volvo
# 2081        T8 AWD Recharge Inscription Vollausstattung          Volvo
# 2082  T6 AWD R-Design Polestar AHK Bowers ACC StandH...          Volvo
# 2083  Momentum 2WD D3 EU6d-T Business-Paket Licht-Paket          Volvo
# 2084                         D5 AWD Geartronic Momentum          Volvo
# 2085        T8 AWD Recharge 7S Inscription Massagesitze          Volvo
# 2086  D5 AWD R-Design EU6d-T AHK ACC StandHZG LED 36...          Volvo
# 2087  Inscription Expression Recharge AWD T8 EU6d -7...          Volvo
# 2088  T3 Momentum Pro LED DAB Harman Panorama Navi R...          Volvo
# 2089  Inscription AWD T8 EU6dtemp,LM20,Kamera,DAB,Ha...          Volvo
# 2090  R Design AWD T5 EU6d-Temp,DAb,Kamera,beheizbar...          Volvo
# 2091  B5 AWD Diesel Ultimate Bright EU6d 22'' AHK HU...          Volvo
# 2092  Inscription AWD D5, LM21,Anhängerkupplung,360K...          Volvo
# 2093  T5 Twin Engine Plus Bright Recharge Plug-In Hy...          Volvo
# 2094                         D5 AWD Geartronic Momentum          Volvo
# 2095                         D5 AWD Geartronic Momentum          Volvo
# 2096  Momentum Pro 2WD T3 EU6d-Temp,LM19,Navi,LED,DA...          Volvo
# 2097      T8 AWD Recharge Geartronic Inscription*Leder*          Volvo
# 2098                          T4 Geartronic Inscription          Volvo
# 2099       Momentum Pro FLA+SpurH+AHK+el.Heck+KeyLess+L          Volvo
# 2100  T8 Twin Engine Inscription *B&W*HUD*BLIS*Luft*...          Volvo
# 2101  Momentum 2WD T3 EU6d-Temp,LM19,Standheizung,Ka...          Volvo
# 2102  Inscription AWD D5 EU6d-Temp,B&W,Schiebdach,DA...          Volvo
# 2103       D3 2WD  Momentum el. Heckkl. LED Tmat EU6d-T          Volvo
# 2104  Inscription 2WD T3 EU6d-Temp,LM19,Frontscheibe...          Volvo
# 2105  Inscription 2WD T3 EU6d-Temp,LM19,Frontscheibe...          Volvo
# 2106        T6 AWD R Design *Glasdach*Standh.*Navi*AHK*          Volvo
# 2107        1.5 R Design Klima*Navi*LED*Memory*SHZ+Lnkr          Volvo
# 2108           T5 Momentum LED**LEDER**SITZHEIZUNG**PDC          Volvo
# 2109  2WD D4 EU6d-T R Design LED Navi Keyless Kurven...          Volvo
# 2110               Momentum Drive el.Heck+LM+KlimaA+PDC          Volvo
# 2111  Momentum Pro 2WD T4 EU6d-Temp,LM20,DAB+,360Kam...          Volvo
# 2112          T8 AWD Twin Engine Geartronic Inscription          Volvo
# 2113      T8 Twin Engine R-Design *B&W*Luft*HUD*ACC*SH*          Volvo
# 2114  Momentum Pro 2WD T3 EU6d-Temp, Sitzheizung, Na...          Volvo
# 2115                                        D3 Momentum          Volvo
# 2116                     D4 AWD Geartronic Momentum Pro          Volvo
# 2117  Inscription AWD D5 EU6d-Temp,7-Sitze,Schiebeda...          Volvo
# 2118  B4 Diesel AWD Plus Bright EU6d 20'' Panorama S...          Volvo
# 2119          B5 AWD Momentum Pro ACC/BLIS/AHK/7-Sitzer          Volvo
# 2120         T6 AWD R-Design *Vollausstattung*B&W*Luft*          Volvo
# 2121    Momentum 2WD D4 EU6dtemp,Kamera,Navi,LED,Sitzh,          Volvo
# 2122  Inscription Expression Plug-In Hybrid 2WD T5 E...          Volvo
# 2123                         D3 Geartronic Momentum Pro          Volvo
# 2124  AWD D3 EU6d-Temp,Kamera,Navi,beheizbare Fronts...          Volvo
# 2125                         D3 Geartronic Momentum Pro          Volvo
# 2126  AWD D3 EU6d-Temp,Kamera,Navi,beheizbare Fronts...          Volvo
# 2127                             D4 Geartronic R-Design          Volvo
# 2128  R Design T4 EU6d-Temp,HUD,DAB,Kamera,BLIS,Lenk...          Volvo
# 2129                                        D3 Momentum          Volvo
# 2130            D4 Momentum FLA SpurH AHK LED LM KlimaA          Volvo
# 2131  Inscription Recharge Plug-In Hybrid AWD T6 Rec...          Volvo
# 2132  Recharge Inscription 2WD T5 EU6d - LM20,Schieb...          Volvo
# 2133  Inscription 2WD EU6d T3 Automatikgetriebe (120...          Volvo
# 2134  Inscription AWD B5 Diesel EU6d - Luftfahrw,LM2...          Volvo
# 2135          R Design AWD T6 AHK Standh. Polestar Navi          Volvo
# 2136  R DesignPlug-In Hybrid AWD T8 EU6d-Temp,HUD,Ka...          Volvo
# 2137  R Design AWD T8 EU6dtemp,Kamera,HeadUp,Standh,...          Volvo
# 2138  T8 AWD Polestar Engineered EU6d MY22 22'' HUD AHK          Volvo
# 2139  T8 AWD Polestar Engineered EU6d MY22 22'' HUD AHK          Volvo
# 2140  Momentum Pro 2WD D3 EU6d-Temp, Kamera,Sitzheiz...          Volvo
# 2141  R Design Plug-In Hybrid AWD T8,LM22,Keyless,Pa...          Volvo
# 2142  Momentum AWD D5 Scheckheft Leder LED Navi ACC ...          Volvo
# 2143  Recharge T8 AWD Polestar Engineered EU6d 22'' ...          Volvo
# 2144                         D3 Geartronic Momentum Pro          Volvo
# 2145  Momentum 2WD D3 EU6d-Temp,LM19,DAB,Lenkradheiz...          Volvo
# 2146        T8 AWD Recharge Inscription Vollausstattung          Volvo
# 2147  T6 AWD R-Design Polestar AHK Bowers ACC StandH...          Volvo
# 2148  Momentum 2WD D3 EU6d-T Business-Paket Licht-Paket          Volvo
# 2149                         D5 AWD Geartronic Momentum          Volvo
# 2150        T8 AWD Recharge 7S Inscription Massagesitze          Volvo
# 2151  D5 AWD R-Design EU6d-T AHK ACC StandHZG LED 36...          Volvo
# 2152  Inscription Expression Recharge AWD T8 EU6d -7...          Volvo
# 2153  T3 Momentum Pro LED DAB Harman Panorama Navi R...          Volvo
# 2154  Inscription AWD T8 EU6dtemp,LM20,Kamera,DAB,Ha...          Volvo
# 2155  R Design AWD T5 EU6d-Temp,DAb,Kamera,beheizbar...          Volvo
# 2156  B5 AWD Diesel Ultimate Bright EU6d 22'' AHK HU...          Volvo
# 2157  Inscription AWD D5, LM21,Anhängerkupplung,360K...          Volvo
# 2158  T5 Twin Engine Plus Bright Recharge Plug-In Hy...          Volvo
# 2159                         D5 AWD Geartronic Momentum          Volvo
# 2160                         D5 AWD Geartronic Momentum          Volvo
# 2161  Momentum Pro 2WD T3 EU6d-Temp,LM19,Navi,LED,DA...          Volvo
# 2162      T8 AWD Recharge Geartronic Inscription*Leder*          Volvo
# 2163                          T4 Geartronic Inscription          Volvo
# 2164       Momentum Pro FLA+SpurH+AHK+el.Heck+KeyLess+L          Volvo
# 2165  T8 Twin Engine Inscription *B&W*HUD*BLIS*Luft*...          Volvo
# 2166  Momentum 2WD T3 EU6d-Temp,LM19,Standheizung,Ka...          Volvo
# 2167  Inscription AWD D5 EU6d-Temp,B&W,Schiebdach,DA...          Volvo
# 2168       D3 2WD  Momentum el. Heckkl. LED Tmat EU6d-T          Volvo
# 2169        T6 AWD R Design *Glasdach*Standh.*Navi*AHK*          Volvo
# 2170        1.5 R Design Klima*Navi*LED*Memory*SHZ+Lnkr          Volvo
# 2171           T5 Momentum LED**LEDER**SITZHEIZUNG**PDC          Volvo
# 2172  2WD D4 EU6d-T R Design LED Navi Keyless Kurven...          Volvo
# 2173               Momentum Drive el.Heck+LM+KlimaA+PDC          Volvo
# 2174  Momentum Pro 2WD T4 EU6d-Temp,LM20,DAB+,360Kam...          Volvo
# 2175          T8 AWD Twin Engine Geartronic Inscription          Volvo
# 2176      T8 Twin Engine R-Design *B&W*Luft*HUD*ACC*SH*          Volvo
# 2177  Momentum Pro 2WD T3 EU6d-Temp, Sitzheizung, Na...          Volvo
# 2178                                        D3 Momentum          Volvo
# 2179                     D4 AWD Geartronic Momentum Pro          Volvo
# 2180  Inscription AWD D5 EU6d-Temp,7-Sitze,Schiebeda...          Volvo
# 2181  B4 Diesel AWD Plus Bright EU6d 20'' Panorama S...          Volvo
# 2182          B5 AWD Momentum Pro ACC/BLIS/AHK/7-Sitzer          Volvo
# 2183         T6 AWD R-Design *Vollausstattung*B&W*Luft*          Volvo
# 2184    Momentum 2WD D4 EU6dtemp,Kamera,Navi,LED,Sitzh,          Volvo
# 2185  Inscription Expression Plug-In Hybrid 2WD T5 E...          Volvo
# 2186                             D4 Geartronic R-Design          Volvo
# 2187  R Design T4 EU6d-Temp,HUD,DAB,Kamera,BLIS,Lenk...          Volvo
# 2188                                        D3 Momentum          Volvo
# 2189            D4 Momentum FLA SpurH AHK LED LM KlimaA          Volvo
# 2190  Inscription Recharge Plug-In Hybrid AWD T6 Rec...          Volvo
# 2191  Recharge Inscription 2WD T5 EU6d - LM20,Schieb...          Volvo
# 2192  Inscription 2WD EU6d T3 Automatikgetriebe (120...          Volvo
# 2193  Inscription AWD B5 Diesel EU6d - Luftfahrw,LM2...          Volvo
# 2194           Momentum D4 AHK Polestar Navi Sitzh. PDC          Volvo
# 2195  Inscription Plug-In Hybrid AWD T6 EU6d,LM19,Ka...          Volvo
# 2196                      T6 AWD Geartronic Inscription          Volvo
# 2197  R Design Plug-In Hybrid AWD T6 EURO 6d-Temp,LM...          Volvo
# 2198       R Design D4 AHK WR Navi Polestar CarPlay DAB          Volvo
# 2199        Momentum D4 Standh. adapt.LED 4xSitzheizung          Volvo
# 2200  Inscription Plug-In Hybrid AWD T8 EU6d-Temp,Ka...          Volvo
# 2201         Cross Country Plus D4 ACC BLIS Leder Xenon          Volvo
# 2202               Cross Country D3  2WD Nav Tmat EURO6          Volvo
# 2203                             D4 Geartronic Momentum          Volvo
# 2204    Inscription AWD T6 EU6dtemp,LM19,LED,Navi,Sitzh          Volvo
# 2205  Inscription AWD T6 EU6dtemp,Luftfahrw,Standh,L...          Volvo
# 2206                      T6 AWD Geartronic Inscription          Volvo
# 2209         Pro AWD D4 EU6dtemp,Kamera,Sitzh,Totwinkel          Volvo
# 2210                              T6 AWD Geartronic Pro          Volvo
# 2211  Pro AWD D5,LM20,360Kamera,B&W,Schiebedach,Stan...          Volvo
# 2212         Momentum Pro D4 LED Park-Assist Navigation          Volvo
# 2213  Inscription AWD T6 EU6dtemp,Schiebed,LED,Stand...          Volvo
# 2214  Pro AWD D5 EU6dtemp - POLESTAR,AHK,Luftfahrw,S...          Volvo
# 2215  Inscription AWD T6 EU6d-Temp,Kamera,DAB,Pano,L...          Volvo
# 2216  R Design AWD T6 EU6dtemp - LM20,AHK,Leder,Kame...          Volvo
# 2217                          T5 Geartronic Inscription          Volvo
# 2218                              D5 AWD Geartronic Pro          Volvo
# 2220  Inscription Plug-In Hybrid AWD T8 EU6d,B&W,Sta...          Volvo
# 2221      T6 Recharge AWD Inscription Luftf 360° Standh          Volvo
# 2222  R-Design AWD T8 Twin Engine EU6dtemp,Luftfahrw...          Volvo
# 2223  Momentum Pro Plug-In Hybrid AWD T6 EU6d,Sitzhe...          Volvo
# 2224         T6 Recharge AWD Inscription Aut 360° Luftf          Volvo
# 2225  D5 AWD Inscription EU6d-T AHK StandHZG 360 Kamera          Volvo
# 2226  Inscription AWD T6 EU6dtemp,LM20,B&W,Schiebed,...          Volvo
# 2227  AWD D4,HeadUp,Schiebedach,Kamera,LED,Blis,Navi...          Volvo
# 2228  AWD D4,HeadUp,Schiebdach,Kamera,LED,Navigation...          Volvo
# 2229  Recharge T6 AWD R-Design EU6d MY22 20'' Androi...          Volvo
# 2230  AWD D4,Einparkhilfe,Navigation,Sitzheizung,Allrad          Volvo
# 2231                                  D4 AWD Geartronic          Volvo
# 2232  Recharge T6 AWD R-Design EU6d AHK Standh. 360 ...          Volvo
# 2233          2.0 Kombi Inscription NAVI*SHZ*Kamera*LED          Volvo
# 2234     T6 Recharge AWD R-Design Glasd 360° Luftfahrwe          Volvo
# 2235  Kombi Momentum Pro AWD T6 EU6d-T LED Navi Keyless          Volvo
# 2237          B4 Diesel Mild-Hybrid R-Design LED Xenium          Volvo
# 2238  Inscription Recharge Plug-In Hybrid AWD T6 EU6...          Volvo
# 2239             T8 Twin Engine AWD Geartronic R Design          Volvo
# 2240  Cross Country Pro AWD D4 EU6d-T Leder LED Navi...          Volvo
# 2241  Cross Country B5 AWD Benzin Ultimate EU6d 20''...          Volvo
# 2242  Pro AWD D4 EU6d-Temp,Schiebedach,LED,Navigatio...          Volvo
# 2243       D4 Inscription Aut BLIS 360° ParkAssistPilot          Volvo
# 2244  Cross Country Pro EU6d-T T6 AWD Geartronic LED...          Volvo
# 2245                             T5 Geartronic R Design          Volvo
# 2246                          D3 Geartronic Inscription          Volvo
# 2247          T2 2.0 Momentum *LED-Licht*Rückfahrkamera          Volvo
# 2248  Momentum Pro B4 EU6dtemp,Leder,Harman,Kamera,S...          Volvo
# 2249  R Design D3 EU6d-Temp,360Kam,HUD,Schiebd,Blis,...          Volvo
# 2250  AWD D4,Schiebedach,HeadUp,Kamera,Navigation,Si...          Volvo
# 2251  AWD D4 EU6d-Temp,HeadUp,Schiebedach,Kamera,Key...          Volvo
# 2252  Inscription D4 DPF EU6dtemp,LED,Kamera,Navi,LM...          Volvo
# 2253  D4 Geartronic Inscription Polestar Engineered ...          Volvo
# 2254  T6 AWD Inscription *Pano*HUD*BLIS*360*SH*HK*Le...          Volvo
# 2255  Pro AWD Diesel EU6d Cross Country B4 ACC KAMER...          Volvo
# 2256  Momentum Pro T4 EU6d-Temp,Kamera,Blind Spot,Te...          Volvo
# 2257  D3 EU6d-T Momentum LED Navi Keyless Rückfahrka...          Volvo
# 2258  AWD D4,Schiebedach,Kamera,Navigation,BlindSpot...          Volvo
# 2259  Kombi R-Design T5 MJ 2020 VMAX  Navi LED Leder...          Volvo
# 2260  V 40 T3 1.5 Kinetic Navi/Autom./Klima/Sitzhzg. BC          Volvo
# 2261  R Design Plug-In Hybrid AWD T8 EU6d-Temp,Stand...          Volvo
# 2262  AWD D5, Schiebedach, 360 Kamera,LED ,Navigatio...          Volvo
# 2263                        B4 B Geartronic Inscription          Volvo
# 2264                        B4 B Geartronic Inscription          Volvo
# 2265                       B3 B Geartronic Momentum Pro          Volvo
# 2266  Kinetic T2 Navi PDCv+h LED-Tagfahrlicht Beheiz...          Volvo
# 2267  R Design D4 EU6d-Temp,Frontscheibe heizbar,Kam...          Volvo
# 2268  AWD D4 EU6d-Temp,LM19,Navi,LED,Frontscheibe he...          Volvo
# 2269      AWD D4 - HeadUp,Kamera,Schiebed,LED,Totwinkel          Volvo
# 2270  Inscription AWD T6 EU6dtemp,360Kamera,HeadUp,S...          Volvo
# 2271           Momentum D4 AHK Polestar Navi Sitzh. PDC          Volvo
# 2272  Inscription Plug-In Hybrid AWD T6 EU6d,LM19,Ka...          Volvo
# 2273                      T6 AWD Geartronic Inscription          Volvo
# 2274  R Design Plug-In Hybrid AWD T6 EURO 6d-Temp,LM...          Volvo
# 2275       R Design D4 AHK WR Navi Polestar CarPlay DAB          Volvo
# 2276        Momentum D4 Standh. adapt.LED 4xSitzheizung          Volvo
# 2277  Inscription Plug-In Hybrid AWD T8 EU6d-Temp,Ka...          Volvo
# 2278         Cross Country Plus D4 ACC BLIS Leder Xenon          Volvo
# 2279               Cross Country D3  2WD Nav Tmat EURO6          Volvo
# 2280                             D4 Geartronic Momentum          Volvo
# 2281    Inscription AWD T6 EU6dtemp,LM19,LED,Navi,Sitzh          Volvo
# 2282  Inscription AWD T6 EU6dtemp,Luftfahrw,Standh,L...          Volvo
# 2283                      T6 AWD Geartronic Inscription          Volvo
# 2286         Pro AWD D4 EU6dtemp,Kamera,Sitzh,Totwinkel          Volvo
# 2287                              T6 AWD Geartronic Pro          Volvo
# 2288  Pro AWD D5,LM20,360Kamera,B&W,Schiebedach,Stan...          Volvo
# 2289         Momentum Pro D4 LED Park-Assist Navigation          Volvo
# 2290  Inscription AWD T6 EU6dtemp,Schiebed,LED,Stand...          Volvo
# 2291  Pro AWD D5 EU6dtemp - POLESTAR,AHK,Luftfahrw,S...          Volvo
# 2292  Inscription AWD T6 EU6d-Temp,Kamera,DAB,Pano,L...          Volvo
# 2293  R Design AWD T6 EU6dtemp - LM20,AHK,Leder,Kame...          Volvo
# 2294                          T5 Geartronic Inscription          Volvo
# 2295                              D5 AWD Geartronic Pro          Volvo
# 2297  Inscription Plug-In Hybrid AWD T8 EU6d,B&W,Sta...          Volvo
# 2298      T6 Recharge AWD Inscription Luftf 360° Standh          Volvo
# 2299  R-Design AWD T8 Twin Engine EU6dtemp,Luftfahrw...          Volvo
# 2300  Momentum Pro Plug-In Hybrid AWD T6 EU6d,Sitzhe...          Volvo
# 2301         T6 Recharge AWD Inscription Aut 360° Luftf          Volvo
# 2302  D5 AWD Inscription EU6d-T AHK StandHZG 360 Kamera          Volvo
# 2303  Inscription AWD T6 EU6dtemp,LM20,B&W,Schiebed,...          Volvo
# 2304  AWD D4,HeadUp,Schiebedach,Kamera,LED,Blis,Navi...          Volvo
# 2305  AWD D4,HeadUp,Schiebdach,Kamera,LED,Navigation...          Volvo
# 2306  Recharge T6 AWD R-Design EU6d MY22 20'' Androi...          Volvo
# 2307  AWD D4,Einparkhilfe,Navigation,Sitzheizung,Allrad          Volvo
# 2308                                  D4 AWD Geartronic          Volvo
# 2309  Recharge T6 AWD R-Design EU6d AHK Standh. 360 ...          Volvo
# 2310          2.0 Kombi Inscription NAVI*SHZ*Kamera*LED          Volvo
# 2311     T6 Recharge AWD R-Design Glasd 360° Luftfahrwe          Volvo
# 2312  Kombi Momentum Pro AWD T6 EU6d-T LED Navi Keyless          Volvo
# 2314          B4 Diesel Mild-Hybrid R-Design LED Xenium          Volvo
# 2315  Inscription Recharge Plug-In Hybrid AWD T6 EU6...          Volvo
# 2316             T8 Twin Engine AWD Geartronic R Design          Volvo
# 2317  Cross Country Pro AWD D4 EU6d-T Leder LED Navi...          Volvo
# 2318  Cross Country B5 AWD Benzin Ultimate EU6d 20''...          Volvo
# 2319  Pro AWD D4 EU6d-Temp,Schiebedach,LED,Navigatio...          Volvo
# 2320       D4 Inscription Aut BLIS 360° ParkAssistPilot          Volvo
# 2321  Cross Country Pro EU6d-T T6 AWD Geartronic LED...          Volvo
# 2322                             T5 Geartronic R Design          Volvo
# 2323                          D3 Geartronic Inscription          Volvo
# 2324          T2 2.0 Momentum *LED-Licht*Rückfahrkamera          Volvo
# 2325  Momentum Pro B4 EU6dtemp,Leder,Harman,Kamera,S...          Volvo
# 2326  R Design D3 EU6d-Temp,360Kam,HUD,Schiebd,Blis,...          Volvo
# 2327  AWD D4,Schiebedach,HeadUp,Kamera,Navigation,Si...          Volvo
# 2328  AWD D4 EU6d-Temp,HeadUp,Schiebedach,Kamera,Key...          Volvo
# 2329  Inscription D4 DPF EU6dtemp,LED,Kamera,Navi,LM...          Volvo
# 2330  D4 Geartronic Inscription Polestar Engineered ...          Volvo
# 2331  T6 AWD Inscription *Pano*HUD*BLIS*360*SH*HK*Le...          Volvo
# 2332  Pro AWD Diesel EU6d Cross Country B4 ACC KAMER...          Volvo
# 2333  Momentum Pro T4 EU6d-Temp,Kamera,Blind Spot,Te...          Volvo
# 2334  D3 EU6d-T Momentum LED Navi Keyless Rückfahrka...          Volvo
# 2335  AWD D4,Schiebedach,Kamera,Navigation,BlindSpot...          Volvo
# 2336  Kombi R-Design T5 MJ 2020 VMAX  Navi LED Leder...          Volvo
# 2337  V 40 T3 1.5 Kinetic Navi/Autom./Klima/Sitzhzg. BC          Volvo
# 2338  R Design Plug-In Hybrid AWD T8 EU6d-Temp,Stand...          Volvo
# 2339  AWD D5, Schiebedach, 360 Kamera,LED ,Navigatio...          Volvo
# 2340                       B3 B Geartronic Momentum Pro          Volvo
# 2341  Kinetic T2 Navi PDCv+h LED-Tagfahrlicht Beheiz...          Volvo
# 2342  R Design D4 EU6d-Temp,Frontscheibe heizbar,Kam...          Volvo
# 2343  AWD D4 EU6d-Temp,LM19,Navi,LED,Frontscheibe he...          Volvo
# 2344      AWD D4 - HeadUp,Kamera,Schiebed,LED,Totwinkel          Volvo
# 2345  Inscription AWD T6 EU6dtemp,360Kamera,HeadUp,S...          Volvo
#
#                    model                                           location  \
# 79               AMG GT            Julius-Rütgers-Str. 1,  15537 Erkner, DE
# 80               AMG GT            Julius-Rütgers-Str. 1,  15537 Erkner, DE
# 83             S 63 AMG                         Wörth 17,  94034 Passau, DE
# 84             S 63 AMG                         Wörth 17,  94034 Passau, DE
# 141            C 43 AMG           Altendorfer Straße 44 C,  45127 Essen, DE
# 142            C 43 AMG           Altendorfer Straße 44 C,  45127 Essen, DE
# 203               G 400        Hallesche Straße  150,  99734 Nordhausen, DE
# 204               G 400        Hallesche Straße  150,  99734 Nordhausen, DE
# 263               C 200    Halberstädter Chaussee 200,  39116 Magdeburg, DE
# 264               C 200    Halberstädter Chaussee 200,  39116 Magdeburg, DE
# 271               C 220         St.-Georgener-Straße 1,  79111 Freiburg, DE
# 272               C 220         St.-Georgener-Straße 1,  79111 Freiburg, DE
# 552         Grandland X               Lindauer Str. 107,  87435 Kempten, DE
# 553         Grandland X               Lindauer Str. 107,  87435 Kempten, DE
# 554         Crossland X               Lindauer Str. 107,  87435 Kempten, DE
# 564         Crossland X               Lindauer Str. 107,  87435 Kempten, DE
# 581         Grandland X          Georg-Brauchle-Ring 68,  80992 München, DE
# 585         Grandland X          Georg-Brauchle-Ring 68,  80992 München, DE
# 587         Grandland X               Lindauer Str. 107,  87435 Kempten, DE
# 588         Grandland X               Lindauer Str. 107,  87435 Kempten, DE
# 625         Crossland X               Lindauer Str. 107,  87435 Kempten, DE
# 632         Crossland X               Lindauer Str. 107,  87435 Kempten, DE
konrad-Zuse-Straße 11,  36251 Bad Hersfeld, DE
# 2195                V60                Stockumer Str. 80,  58453 Witten, DE
# ...
# 2128             unefficient               Volvo XC60                7.20
# 2129               efficient               Volvo XC60                5.00
# 2130               efficient               Volvo XC40                5.00
# 2131               efficient               Volvo XC60                1.90
# 2132               efficient               Volvo XC40                1.80
# 2133               efficient               Volvo XC40                6.50
# 2134               efficient               Volvo XC90                5.70
# 2135               efficient               Volvo XC60                7.70
# 2136               efficient               Volvo XC60                2.40
# 2137               efficient               Volvo XC60                2.40
# 2138               efficient               Volvo XC60                2.30
# 2139               efficient               Volvo XC60                2.30
# 2140               efficient               Volvo XC40                4.80
# 2141               efficient               Volvo XC60                1.90
# 2142               efficient               Volvo XC90                5.70
# 2143               efficient               Volvo XC60                2.30
# 2144               efficient               Volvo XC40                5.00
# 2145               efficient               Volvo XC40                5.10
# 2146               efficient               Volvo XC90                2.30
# 2147             unefficient               Volvo XC60                7.80
# 2148               efficient               Volvo XC40                5.00
# 2149               efficient               Volvo XC90                6.00
# 2150               efficient               Volvo XC90                2.30
# 2151               efficient               Volvo XC60                6.00
# 2152               efficient               Volvo XC90                2.10
# 2153               efficient               Volvo XC40                6.20
# 2154               efficient               Volvo XC60                1.80
# 2155             unefficient               Volvo XC40                7.30
# 2156               efficient               Volvo XC90                5.70
# 2157               efficient               Volvo XC90                5.80
# 2158               efficient               Volvo XC40                1.80
# 2159               efficient               Volvo XC90                6.00
# 2160               efficient               Volvo XC60                5.60
# 2161               efficient               Volvo XC40                6.20
# 2162               efficient               Volvo XC90                2.10
# 2163               efficient               Volvo XC40                6.60
# 2164               efficient               Volvo XC40                6.50
# 2165               efficient               Volvo XC60                2.10
# 2166               efficient               Volvo XC40                6.20
# 2167               efficient               Volvo XC90                5.80
# 2168               efficient               Volvo XC60                5.20
# 2169               efficient               Volvo XC60                1.90
# 2170               efficient               Volvo XC40                6.50
# 2171               efficient               Volvo XC60                7.40
# 2172               efficient               Volvo XC60                5.60
# 2173               efficient               Volvo XC60                5.90
# 2174             unefficient               Volvo XC40                6.60
# 2175               efficient               Volvo XC90                2.20
# 2176               efficient               Volvo XC60                2.40
# 2177               efficient               Volvo XC40                6.20
# 2178               efficient               Volvo XC60                5.30
# 2179               efficient               Volvo XC40                5.00
# 2180               efficient               Volvo XC90                6.00
# 2181               efficient               Volvo XC60                5.50
# 2182             unefficient               Volvo XC90                5.60
# 2183               efficient               Volvo XC60                7.70
# 2184               efficient               Volvo XC60                5.50
# 2185               efficient               Volvo XC40                1.80
# 2186               efficient               Volvo XC60                4.70
# 2187             unefficient               Volvo XC60                7.20
# 2188               efficient               Volvo XC60                5.00
# 2189               efficient               Volvo XC40                5.00
# 2190               efficient               Volvo XC60                1.90
# 2191               efficient               Volvo XC40                1.80
# 2192               efficient               Volvo XC40                6.50
# 2193               efficient               Volvo XC90                5.70
# 2194               efficient                Volvo V60                4.00
# 2195               efficient                Volvo V60                1.60
# 2196               efficient                Volvo V60                7.40
# 2197               efficient                Volvo V60                1.70
# 2198               efficient                Volvo V60                4.40
# 2199               efficient                Volvo V90                4.80
# 2200               efficient                Volvo V60                1.70
# 2201               efficient                Volvo V60                4.60
# 2202               efficient  Volvo V60 Cross Country                4.20
# 2203               efficient                Volvo V90                4.90
# 2204             unefficient                Volvo V60                7.40
# 2205             unefficient                Volvo V60                7.20
# 2206             unefficient                Volvo V90                7.70
# 2209               efficient  Volvo V90 Cross Country                5.30
# 2210               efficient  Volvo V90 Cross Country                7.60
# 2211               efficient  Volvo V90 Cross Country                5.30
# 2212               efficient                Volvo V60                4.40
# 2213             unefficient                Volvo V60                7.40
# 2214               efficient  Volvo V90 Cross Country                5.70
# 2215             unefficient                Volvo V60                7.40
# 2216             unefficient                Volvo V60                7.40
# 2217               efficient                Volvo V60                6.60
# 2218               efficient  Volvo V90 Cross Country                5.60
# 2220               efficient                Volvo V90                1.70
# 2221               efficient                Volvo V90                1.70
# 2222               efficient                Volvo V90                1.90
# 2223               efficient                Volvo V60                1.70
# 2224               efficient                Volvo V90                1.70
# 2225               efficient                Volvo V90                5.60
# 2226             unefficient                Volvo V60                7.60
# 2227               efficient  Volvo V90 Cross Country                5.20
# 2228               efficient  Volvo V90 Cross Country                5.20
# 2229               efficient                Volvo V90                1.70
# 2230               efficient  Volvo V90 Cross Country                5.20
# 2231               efficient  Volvo V90 Cross Country                5.30
# 2232               efficient                Volvo V90                1.70
# 2233               efficient                Volvo V90                4.80
# 2234               efficient                Volvo V90                1.70
# 2235             unefficient                Volvo V60                7.40
# 2237               efficient                Volvo V60                4.70
# 2238               efficient                Volvo V60                1.70
# 2239               efficient                Volvo V90                2.00
# 2240               efficient                Volvo V90                5.30
# 2241               efficient  Volvo V60 Cross Country                6.80
# 2242               efficient  Volvo V60 Cross Country                5.40
# 2243               efficient                Volvo V90                4.80
# 2244             unefficient                Volvo V90                7.60
# 2245               efficient                Volvo V90                6.80
# 2246               efficient                Volvo V60                4.60
# 2247               efficient                Volvo V40                5.90
# 2248               efficient                Volvo V60                6.20
# 2249               efficient                Volvo V60                4.50
# 2250               efficient  Volvo V90 Cross Country                5.20
# 2251               efficient  Volvo V90 Cross Country                5.20
# 2252               efficient                Volvo V90                4.80
# 2253               efficient                Volvo V60                4.50
# 2254             unefficient                Volvo V60                7.20
# 2255               efficient  Volvo V60 Cross Country                5.30
# 2256             unefficient                Volvo V60                6.80
# 2257               efficient                Volvo V60                4.60
# 2258               efficient  Volvo V90 Cross Country                5.20
# 2259               efficient                Volvo V60                6.60
# 2260               efficient                Volvo V40                5.50
# 2261               efficient                Volvo V90                1.90
# 2262               efficient  Volvo V90 Cross Country                5.30
# 2263               efficient                Volvo V60                6.20
# 2264               efficient                Volvo V60                6.20
# 2265               efficient                Volvo V60                6.10
# 2266               efficient                Volvo V40                5.60
# 2267               efficient                Volvo V60                4.50
# 2268               efficient  Volvo V90 Cross Country                5.20
# 2269               efficient  Volvo V90 Cross Country                5.20
# 2270             unefficient                Volvo V60                7.40
# 2271               efficient                Volvo V60                4.00
# 2272               efficient                Volvo V60                1.60
# 2273               efficient                Volvo V60                7.40
# 2274               efficient                Volvo V60                1.70
# 2275               efficient                Volvo V60                4.40
# 2276               efficient                Volvo V90                4.80
# 2277               efficient                Volvo V60                1.70
# 2278               efficient                Volvo V60                4.60
# 2279               efficient  Volvo V60 Cross Country                4.20
# 2280               efficient                Volvo V90                4.90
# 2281             unefficient                Volvo V60                7.40
# 2282             unefficient                Volvo V60                7.20
# 2283             unefficient                Volvo V90                7.70
# 2286               efficient  Volvo V90 Cross Country                5.30
# 2287               efficient  Volvo V90 Cross Country                7.60
# 2288               efficient  Volvo V90 Cross Country                5.30
# 2289               efficient                Volvo V60                4.40
# 2290             unefficient                Volvo V60                7.40
# 2291               efficient  Volvo V90 Cross Country                5.70
# 2292             unefficient                Volvo V60                7.40
# 2293             unefficient                Volvo V60                7.40
# 2294               efficient                Volvo V60                6.60
# 2295               efficient  Volvo V90 Cross Country                5.60
# 2297               efficient                Volvo V90                1.70
# 2298               efficient                Volvo V90                1.70
# 2299               efficient                Volvo V90                1.90
# 2300               efficient                Volvo V60                1.70
# 2301               efficient                Volvo V90                1.70
# 2302               efficient                Volvo V90                5.60
# 2303             unefficient                Volvo V60                7.60
# 2304               efficient  Volvo V90 Cross Country                5.20
# 2305               efficient  Volvo V90 Cross Country                5.20
# 2306               efficient                Volvo V90                1.70
# 2307               efficient  Volvo V90 Cross Country                5.20
# 2308               efficient  Volvo V90 Cross Country                5.30
# 2309               efficient                Volvo V90                1.70
# 2310               efficient                Volvo V90                4.80
# 2311               efficient                Volvo V90                1.70
# 2312             unefficient                Volvo V60                7.40
# 2314               efficient                Volvo V60                4.70
# 2315               efficient                Volvo V60                1.70
# 2316               efficient                Volvo V90                2.00
# 2317               efficient                Volvo V90                5.30
# 2318               efficient  Volvo V60 Cross Country                6.80
# 2319               efficient  Volvo V60 Cross Country                5.40
# 2320               efficient                Volvo V90                4.80
# 2321             unefficient                Volvo V90                7.60
# 2322               efficient                Volvo V90                6.80
# 2323               efficient                Volvo V60                4.60
# 2324               efficient                Volvo V40                5.90
# 2325               efficient                Volvo V60                6.20
# 2326               efficient                Volvo V60                4.50
# 2327               efficient  Volvo V90 Cross Country                5.20
# 2328               efficient  Volvo V90 Cross Country                5.20
# 2329               efficient                Volvo V90                4.80
# 2330               efficient                Volvo V60                4.50
# 2331             unefficient                Volvo V60                7.20
# 2332               efficient  Volvo V60 Cross Country                5.30
# 2333             unefficient                Volvo V60                6.80
# 2334               efficient                Volvo V60                4.60
# 2335               efficient  Volvo V90 Cross Country                5.20
# 2336               efficient                Volvo V60                6.60
# 2337               efficient                Volvo V40                5.50
# 2338               efficient                Volvo V90                1.90
# 2339               efficient  Volvo V90 Cross Country                5.30
# 2340               efficient                Volvo V60                6.10
# 2341               efficient                Volvo V40                5.60
# 2342               efficient                Volvo V60                4.50
# 2343               efficient  Volvo V90 Cross Country                5.20
# 2344               efficient  Volvo V90 Cross Country                5.20
# 2345             unefficient                Volvo V60                7.40

# %% [markdown]
# FIVE DEF S FOR FILLING MISSING VALUES

# %%
def first_looking(*cols):
    """
    Prints basic information about given columns in a Pandas DataFrame.

    Parameters:
    *cols (str): The names of the columns to analyze.

    Returns:
    None.

    Prints:
    - The name of each column.
    - The percentage of null values in each column.
    - The number of null values in each column.
    - The number of unique values in each column.
    - The value counts for each unique value in each column, including null values.
    """
    for col in cols:
        print("COLUMN NAME    : ", col)
        print("--------------------------------")
        print("per_of_nulls   : ", "%", round(df[col].isnull().sum()*100 / df.shape[0], 2))
        print("num_of_nulls   : ", df[col].isnull().sum())
        print("num_of_uniques : ", df[col].nunique())
        print("--------------------------------")
        print(df[col].value_counts(dropna=False))
        print("\n")

# %%
def fill_most_freq(df, group_col, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` with the most frequent value 
    in each group defined by a grouping column.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col (str): The name of the grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values, sorted by index.
    """    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %%
def fill_mode(df, group_col1, group_col2, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` based on the values in two other columns.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col1 (str): The name of the first grouping column.
    group_col2 (str): The name of the second grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values.
    """    
    for group1 in list(df[group_col1].unique()):
        for group2 in list(df[group_col2].unique()):
            cond1 = df[group_col1]==group1
            cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
            mode1 = list(df[cond1][col_name].mode())
            mode2 = list(df[cond2][col_name].mode())
            if mode2 != []:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
            elif mode1 != []:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
            else:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])
    
    print("column name    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False))

# %%
def fill_prop(df, group_col, col_name):
    """
    Fills missing values in a column of a Pandas DataFrame `df` using forward and backward fill based on a grouping column.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col (str): The name of the grouping column.
    col_name (str): The name of the column to fill missing values in.

    Returns:
    None.

    Prints:
    - The name of the column that was filled.
    - The percentage of null values in the column after filling.
    - The number of null values in the column after filling.
    - The number of unique values in the column after filling.
    - The value counts for each unique value in the column after filling, including null values, sorted by index.
    """    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %%
def fill(df, group_col1, group_col2, col_name, method):
    """
    Fills missing values in a column of a Pandas DataFrame `df` based on double-stage grouping and a specified filling method.

    Parameters:
    df (pandas.DataFrame): The DataFrame to operate on.
    group_col1 (str): The name of the first grouping column.
    group_col2 (str): The name of the second grouping column.
    col_name (str): The name of the column to fill missing values in.
    method (str): The filling method to use. Can be "mode", "mean", "median", "ffill", or "bfill".

    Returns:
    None.

    Prints:
    None.
    """
    
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

    elif method == "mean":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df[col_name].mean(), inplace = True)
        
    elif method == "median":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df[col_name].median(), inplace = True)
        
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %% [markdown]
# MISSING VALUES IN COLUMNS

# %%
df_notnull = df[df.columns[~df.isnull().any()]]
df_notnull.columns
# Out:
# Index(['make_model', 'make', 'model', 'location', 'price', 'body_type', 'type',
#        'doors', 'warranty', 'mileage', 'first_registration', 'gearbox',
#        'seller', 'co_emissions', 'full_service_history', 'production_date',
#        'energy_efficiency_class', 'new', 'combined_fuel_cons'],
#       dtype='object')

# %%
for col in df_notnull.columns:
    print(first_looking(col))
    print()
# Out:
# COLUMN NAME    :  make_model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  212
# --------------------------------
# Ford Focus                  99
# Opel Insignia               97
# Opel Astra                  94
# Opel Corsa                  89
# Ford Fiesta                 80
# Volvo V60                   70
# Opel Grandland X            62
# Volvo XC60                  54
# Ford Kuga                   53
# Toyota Yaris                48
# Opel Crossland X            48
# SEAT Leon                   46
# Volvo XC40                  44
# Volvo V90                   38
# Skoda Fabia                 34
# Nissan Qashqai              34
# Opel Cascada                34
# Ford Mustang                34
# Toyota Corolla              32
# Toyota Aygo X               31
# Renault Clio                31
# Toyota C-HR                 30
# Volvo V90 Cross Country     30
# Volvo XC90                  28
# Hyundai i30                 28
# Peugeot 308                 26
# Mercedes-Benz C 200         26
# Mercedes-Benz C 300         22
# Ford Mondeo                 22
# Mercedes-Benz AMG GT        21
# SEAT Ibiza                  21
# Opel Adam                   21
# Skoda Superb                21
# Skoda Octavia               20
# Mercedes-Benz C 63 AMG      20
# Skoda Karoq                 19
# Opel Mokka                  19
# SEAT Arona                  18
# Nissan Micra                17
# Opel Mokka X                17
# Mercedes-Benz C 400         15
# Opel Grandland              15
# Peugeot 3008                14
# SEAT Ateca                  14
# Mercedes-Benz E 400         14
# Toyota Aygo                 13
# Nissan Townstar             13
# Renault Megane              13
# Opel Karl                   12
# Skoda Kodiaq                12
# Mercedes-Benz C 43 AMG      12
# Fiat 500C                   12
# Mercedes-Benz GLC 63 AMG    12
# Toyota Supra                11
# Toyota RAV 4                11
# Nissan Juke                 11
# Fiat 500                    11
# Mercedes-Benz E 300         11
# Volvo V40                   10
# Mercedes-Benz E 53 AMG      10
# Hyundai TUCSON              10
# Skoda Citigo                 9
# Ford Transit Connect         9
# Ford Tourneo Custom          9
# Peugeot 2008                 9
# Dacia Sandero                9
# Ford Puma                    9
# Renault Kadjar               9
# Toyota Avensis               9
# Toyota Auris                 9
# Mercedes-Benz C 180          8
# Mercedes-Benz GLC 43 AMG     8
# Mercedes-Benz                8
# Hyundai BAYON                8
# Mercedes-Benz C 220          8
# Renault Captur               8
# Volvo V60 Cross Country      8
# Mercedes-Benz S 580          8
# Skoda Scala                  8
# Peugeot 508                  8
# SEAT Tarraco                 7
# Peugeot 208                  7
# Peugeot 108                  7
# Hyundai i20                  7
# Fiat Tipo                    7
# Volvo S90                    7
# Mercedes-Benz E 220          7
# Mercedes-Benz CLA 45 AMG     7
# Mercedes-Benz E 200          7
# Mercedes-Benz GLE 400        7
# Nissan 370Z                  6
# Skoda Rapid/Spaceback        6
# Nissan GT-R                  1
# Mercedes-Benz GLE 350        1
# Toyota Verso-S               1
# Mercedes-Benz CLS 300        1
# Toyota Land Cruiser          1
# Opel Vivaro                  1
# Toyota Highlander            1
# Mercedes-Benz GLE 43 AMG     1
# Toyota iQ                    1
# Mercedes-Benz G              1
# Mercedes-Benz GLE 450        1
# Mercedes-Benz GLK 250        1
# Mercedes-Benz GLK 350        1
# Skoda Yeti                   1
# Mercedes-Benz GLK 220        1
# Mercedes-Benz G 350          1
# Peugeot RCZ                  1
# Name: make_model, dtype: int64
#
#
# None
#
# COLUMN NAME    :  make
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  13
# --------------------------------
# Opel             516
# Mercedes-Benz    357
# Ford             336
# Volvo            296
# Toyota           227
# Skoda            134
# SEAT             107
# Nissan           107
# Peugeot           80
# Renault           78
# Hyundai           70
# Fiat              36
# Dacia             20
# Name: make, dtype: int64
#
#
# None
#
# COLUMN NAME    :  model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  209
# --------------------------------
# Focus                 99
# Insignia              97
# Astra                 94
# Corsa                 89
# Fiesta                80
# V60                   70
# Grandland X           62
# XC60                  54
# Kuga                  53
# Yaris                 48
# Crossland X           48
# Leon                  46
# XC40                  44
# V90                   38
# Fabia                 34
# Qashqai               34
# Cascada               34
# Mustang               34
# Corolla               32
# Aygo X                31
# Clio                  31
# C                     30
# V90 Cross Country     30
# XC90                  28
# i30                   28
# 308                   26
# C 200                 26
# C 300                 22
# Mondeo                22
# AMG GT                21
# Adam                  21
# Superb                21
# Ibiza                 21
# Octavia               20
# C 63 AMG              20
# Mokka                 19
# Karoq                 19
# Arona                 18
# Micra                 17
# Mokka X               17
# C 400                 15
# Grandland             15
# Ateca                 14
# 3008                  14
# E 400                 14
# Aygo                  13
# Megane                13
# Townstar              13
#                       13
# 500C                  12
# Karl                  12
# Kodiaq                12
# C 43 AMG              12
# GLC 63 AMG            12
# Supra                 11
# Juke                  11
# E 300                 11
# 500                   11
# RAV 4                 11
# V40                   10
# E 53 AMG              10
# TUCSON                10
# Citigo                 9
# Auris                  9
# Tourneo Custom         9
# 2008                   9
# Transit Connect        9
# Puma                   9
# Sandero                9
# Kadjar                 9
# Avensis                9
# GLC 43 AMG             8
# BAYON                  8
# C 220                  8
# C 180                  8
# V60 Cross Country      8
# Captur                 8
# S 580                  8
# Scala                  8
# 508                    8
# Tarraco                7
# 208                    7
# 108                    7
# i20                    7
# Tipo                   7
# S90                    7
# CLA 45 AMG             7
# E 200                  7
# GLE 400                7
# E 220                  7
# Proace                 6
# Talisman               6
# Pulsar                 6
# NV200                  6
# X                      6
# 370Z                   6
# Rapid                  6
# CLA 200                6
# GLC 400                6
# Prius                  6
# S60                    6
# Duster                 5
# Hilux                  5
# A 250                  5
# CLS 400                5
# GLC 300                5
# 5008                   5
# GLE 300                5
# i10                    5
# Jogger                 4
# Kamiq                  4
# Mirai                  4
# GLB 35 AMG             4
# Yaris Cross            4
# EcoSport               4
# GLE 580                4
# Crossland              4
# CLA 35 AMG             4
# E 350                  4
# A 35 AMG               4
# Ranger                 4
# Edge                   4
# S 63 AMG               4
# CLS 450                4
# CLS 53 AMG             3
# SLC 200                3
# G 500                  3
# G 400                  3
# KONA                   3
# 500X                   3
# CLA 180                3
# Navara                 3
# C 250                  3
# GLA 200                3
# Transit Custom         2
# S 400                  2
# IONIQ                  2
# NV300                  2
# i40                    2
# E 450                  2
# Primastar              2
# GLC 350                2
# Tourneo Courier        2
# 207                    2
# G 63 AMG               2
# GLA 220                2
# A 45 AMG               2
# 124 Spider             2
# GLS 400                2
# Alpine A110            2
# Logan                  2
# GLC 250                2
# Twingo                 2
# GLE 53 AMG             2
# GT86                   2
# B 250                  2
# Alaskan                2
# Kangoo                 1
# Express                1
# CLS 63 AMG             1
# Megane E               1
# SL 600                 1
# S                      1
# VELOSTER               1
# Grand C                1
# iX35                   1
# GLE 43 AMG             1
# SL 63 AMG              1
# SANTA FE               1
# CL                     1
# STARIA                 1
# E 250                  1
# S 350                  1
# Vectra                 1
# S 560                  1
# SLK                    1
# SL 500                 1
# Zafira Life            1
# S80                    1
# Grand Tourneo          1
# B 200                  1
# RCZ                    1
# C 350                  1
# Highlander             1
# Vivaro                 1
# Land Cruiser           1
# iQ                     1
# CLS 300                1
# Verso                  1
# GLE 450                1
# GLK 250                1
# GT                     1
# GLK 350                1
# Yeti                   1
# GLK 220                1
# G 350                  1
# G                      1
# Mii                    1
# GLC 200                1
# GLB 200                1
# Punto                  1
# GLC 220                1
# 107                    1
# Bronco                 1
# E 63 AMG               1
# GLE 350                1
# Explorer               1
# S 500                  1
# Combo Life             1
# Name: model, dtype: int64
#
#
# None
#
# COLUMN NAME    :  location
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  375
# --------------------------------
# Stockumer Str. 80,  58453 Witten, DE                                         85
# Cannstatter Str. 46,  70190 Stuttgart, DE                                    59
# An der Seilfahrt 2,  45472 Mülheim an der Ruhr, DE                           45
# Lindauer Str. 107,  87435 Kempten, DE                                        40
# St.-Georgener-Straße 1,  79111 Freiburg, DE                                  37
# Hans-Böckler-Str. 26,  37079 Göttingen, DE                                   32
# Meckenheimer Straße 12,  53359 Rheinbach, DE                                 31
# Autofocus 3,  15517 Fürstenwalde, DE                                         28
# Konrad-Zuse-Straße 11,  36251 Bad Hersfeld, DE                               28
# Dieselstr. 1,  84069 Schierling, DE                                          28
# Bebraer Str. 6,  37269 Eschwege, DE                                          27
# Donaustraße 5c,  86165 Augsburg, DE                                          27
# Hermann-Köhl-Str. 3,  86899 Landsberg am Lech, DE                            27
# Watzmannstraße 54,  84034 Landshut, DE                                       26
# Herforder Str. 175,  32105 Bad Salzuflen, DE                                 25
# Am Riederbruch 8,  60386 Frankfurt am Main, DE                               24
# Masteweg 2,  58640 Iserlohn, DE                                              23
# Hüttenstraße 59,  87600 Kaufbeuren, DE                                       22
# Hauptstr. 167,  13158 Berlin, DE                                             22
# Am Hahnweg 2,  01328 Dresden, DE                                             22
# Nevigeser Straße 151,  42553 Velbert, DE                                     20
# Wunsiedler Straße 2,  95032 Hof, DE                                          20
# Merseburger Straße 223,  06130 Halle, DE                                     19
# Gießener Straße 122-124,  35415 Pohlheim, DE                                 19
# Bayreuther Straße 39-41,  92224 Amberg, DE                                   19
# Buronstr. 71,  87600 Kaufbeuren, DE                                          18
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1258
# --------------------------------
# 16990.00    26
# 27990.00    23
# 19990.00    23
# 21990.00    20
# 24990.00    19
#             ..
# 22488.00     1
# 17379.00     1
# 35790.00     1
# 22788.00     1
# 43700.00     1
# Name: price, Length: 1258, dtype: int64
#
#
# None
#
# COLUMN NAME    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# Off-Road/Pick-up    684
# Station wagon       609
# Sedan               461
# Compact             293
# Coupe               175
# Convertible         142
# Name: body_type, dtype: int64
#
#
# None
#
# COLUMN NAME    :  type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
#  Used              1741
#  Demonstration      342
#  Employee's car     166
#  Pre-registered     115
# Name: type, dtype: int64
#
#
# None
#
# COLUMN NAME    :  doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# 5.00    1889
# 2.00     216
# 3.00     132
# 4.00     127
# Name: doors, dtype: int64
#
#
# None
#
# COLUMN NAME    :  warranty
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  37
# --------------------------------
#  12     855
#  60     734
#  24     412
#  Yes    130
#  0       61
#  36      40
#  84      40
#  72      31
#  48      10
#  32       5
#  33       5
#  13       4
#  23       3
#  20       2
#  26       2
#  34       2
#  21       2
#  35       2
#  16       2
#  47       2
#  30       2
#  14       2
#  29       2
#  37       1
#  42       1
#  9        1
#  18       1
#  19       1
#  51       1
#  31       1
#  25       1
#  50       1
#  49       1
#  80       1
#  52       1
#  28       1
#  22       1
# Name: warranty, dtype: int64
#
#
# None
#
# COLUMN NAME    :  mileage
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1645
# --------------------------------
# 10.00       68
# 5000.00     26
# 3000.00     21
# 5.00        20
# 100.00      16
#             ..
# 54674.00     1
# 80543.00     1
# 31944.00     1
# 38721.00     1
# 37846.00     1
# Name: mileage, Length: 1645, dtype: int64
#
#
# None
#
# COLUMN NAME    :  first_registration
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  139
# --------------------------------
# 04/2022    76
# 05/2022    71
# 07/2020    64
# 06/2019    63
# 07/2019    63
# 07/2022    62
# 05/2019    62
# 04/2019    61
# 09/2022    57
# 02/2019    54
# 08/2022    49
# 10/2021    47
# 03/2022    47
# 01/2022    45
# 06/2021    45
# 01/2019    43
# 06/2022    43
# 07/2021    42
# 02/2022    42
# 03/2021    42
# 08/2019    40
# 11/2021    36
# 12/2021    35
# 06/2020    34
# 09/2020    34
# 06/2018    33
# 09/2019    33
# 05/2018    31
# 11/2018    31
# 09/2021    31
# 08/2021    31
# 03/2019    30
# 08/2020    29
# 04/2018    29
# 03/2020    28
# 03/2018    27
# 11/2020    26
# 12/2019    26
# 10/2019    26
# 02/2020    25
# 04/2021    25
# 01/2020    25
# 12/2018    23
# 07/2018    22
# 05/2021    22
# 10/2020    22
# 11/2017    22
# 10/2018    20
# 09/2018    20
# 02/2021    19
# 01/2018    19
# 11/2019    19
# 01/2021    19
# 05/2020    18
# 08/2018    18
# 02/2018    18
# 12/2020    16
# 10/2017    16
# 09/2017    16
# 04/2017    14
# 07/2017    13
# 12/2017    12
# 11/2016    12
# 05/2017    10
# 04/2016     9
# 02/2017     9
# 10/2016     8
# 12/2016     8
# 04/2020     8
# 06/2017     8
# 08/2017     7
# 03/2017     7
# 03/2016     7
# 09/2016     6
# 01/2015     6
# 05/2016     6
# 06/2016     6
# 10/2014     6
# 04/2015     5
# 05/2015     5
# 07/2016     5
# 12/2014     5
# 01/2017     4
# 03/2015     4
# 09/2015     4
# 07/2015     4
# 05/2013     3
# 03/2013     3
# 08/2016     3
# 06/2014     3
# 04/2012     3
# 08/2012     3
# 04/2014     3
# 02/2016     3
# 03/2014     3
# 08/2011     3
# 12/2011     3
# 11/2012     2
# 01/2016     2
# 08/2013     2
# 12/2015     2
# 10/2012     2
# 06/2010     2
# 07/2014     2
# 10/2015     2
# 06/2013     2
# 09/2010     2
# 12/2013     2
# 06/2015     2
# 06/2011     2
# 05/2011     2
# 12/2008     2
# 08/2015     2
# 04/2013     2
# 08/2014     2
# 11/2014     2
# 02/2015     1
# 03/2012     1
# 07/2010     1
# 05/2009     1
# 01/2013     1
# 10/2009     1
# 10/2010     1
# 11/2011     1
# 02/2013     1
# 07/2013     1
# 01/2010     1
# 02/2011     1
# 03/2010     1
# 02/2012     1
# 06/2008     1
# 11/2015     1
# 11/2006     1
# 11/2013     1
# 08/2010     1
# 12/2009     1
# 12/2012     1
# 05/2005     1
# 01/2014     1
# Name: first_registration, dtype: int64
#
#
# None
#
# COLUMN NAME    :  gearbox
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Automatic    1287
# Manual       1077
# Name: gearbox, dtype: int64
#
#
# None
#
# COLUMN NAME    :  seller
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1
# --------------------------------
# Dealer    2364
# Name: seller, dtype: int64
#
#
# None
#
# COLUMN NAME    :  co_emissions
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  234
# --------------------------------
# 0.00      54
# 114.00    50
# 108.00    49
# 93.00     42
# 136.00    42
# 124.00    39
# 117.00    38
# 119.00    37
# 125.00    37
# 139.00    37
# 144.00    36
# 99.00     35
# 122.00    34
# 107.00    33
# 126.00    32
# 130.00    32
# 128.00    32
# 111.00    31
# 127.00    31
# 112.00    30
# 129.00    30
# 138.00    29
# 92.00     28
# 109.00    28
# 174.00    27
# 120.00    27
# 121.00    27
# 116.00    26
# 131.00    26
# 148.00    26
# 103.00    26
# 147.00    25
# 135.00    25
# 171.00    23
# 134.00    23
# 105.00    22
# 118.00    22
# 110.00    21
# 164.00    21
# 115.00    20
# 140.00    19
# 150.00    18
# 98.00     18
# 133.00    18
# 101.00    18
# 158.00    17
# 96.00     17
# 95.00     17
# 154.00    17
# 143.00    16
# 102.00    16
# 113.00    16
# 145.00    16
# 156.00    16
# 94.00     15
# 64.00     15
# 97.00     15
# 137.00    15
# 123.00    15
# 153.00    15
# 85.00     15
# 104.00    15
# 106.00    14
# 149.00    14
# 176.00    14
# 170.00    14
# 181.00    13
# 142.00    13
# 161.00    12
# 132.00    12
# 141.00    12
# 26.00     12
# 76.00     12
# 162.00    12
# 159.00    11
# 191.00    10
# 34.00     10
# 84.00     10
# 42.00     10
# 40.00     10
# 183.00    10
# 180.00    10
# 152.00    10
# 157.00    10
# 194.00     9
# 175.00     9
# 168.00     9
# 54.00      9
# 155.00     9
# 91.00      8
# 179.00     8
# 49.00      8
# 186.00     8
# 146.00     8
# 41.00      8
# 197.00     8
# 166.00     7
# 189.00     7
# 160.00     7
# 190.00     7
# 163.00     7
# 184.00     7
# 47.00      6
# 214.00     6
# 44.00      6
# 151.00     6
# 51.00      6
# 182.00     6
# 268.00     6
# 284.00     6
# 90.00      6
# 39.00      5
# 198.00     5
# 31.00      5
# 248.00     5
# 254.00     5
# 178.00     5
# 167.00     5
# 199.00     5
# 192.00     5
# 52.00      5
# 188.00     5
# 100.00     4
# 270.00     4
# 247.00     4
# 220.00     4
# 273.00     4
# 89.00      4
# 68.00      4
# 196.00     4
# 185.00     4
# 165.00     4
# 230.00     4
# 169.00     4
# 87.00      4
# 281.00     4
# 244.00     4
# 216.00     4
# 35.00      4
# 173.00     4
# 25.00      4
# 203.00     4
# 280.00     4
# 204.00     4
# 172.00     4
# 236.00     4
# 245.00     3
# 222.00     3
# 277.00     3
# 258.00     3
# 255.00     3
# 249.00     3
# 259.00     3
# 219.00     3
# 46.00      3
# 75.00      3
# 187.00     3
# 298.00     3
# 215.00     3
# 217.00     3
# 177.00     3
# 200.00     3
# 225.00     3
# 195.00     3
# 257.00     3
# 86.00      2
# 269.00     2
# 83.00      2
# 212.00     2
# 262.00     2
# 209.00     2
# 283.00     2
# 303.00     2
# 206.00     2
# 205.00     2
# 228.00     2
# 238.00     2
# 279.00     2
# 50.00      2
# 202.00     2
# 414.00     2
# 43.00      2
# 22.00      2
# 88.00      2
# 246.00     2
# 14.00      2
# 232.00     2
# 36.00      2
# 251.00     1
# 267.00     1
# 276.00     1
# 289.00     1
# 399.00     1
# 241.00     1
# 260.00     1
# 282.00     1
# 234.00     1
# 314.00     1
# 66.00      1
# 910.00     1
# 21.00      1
# 231.00     1
# 227.00     1
# 24.00      1
# 293.00     1
# 17.00      1
# 16.00      1
# 15.00      1
# 18.00      1
# 285.00     1
# 235.00     1
# 348.00     1
# 218.00     1
# 271.00     1
# 208.00     1
# 261.00     1
# 274.00     1
# 32.00      1
# 272.00     1
# 207.00     1
# 330.00     1
# 326.00     1
# 224.00     1
# 275.00     1
# 233.00     1
# 240.00     1
# 82.00      1
# 210.00     1
# 19.00      1
# 296.00     1
# 239.00     1
# 29.00      1
# 263.00     1
# 299.00     1
# Name: co_emissions, dtype: int64
#
#
# None
#
# COLUMN NAME    :  full_service_history
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Yes    1897
# No      467
# Name: full_service_history, dtype: int64
#
#
# None
#
# COLUMN NAME    :  production_date
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  18
# --------------------------------
# 2019.00    510
# 2021.00    458
# 2022.00    379
# 2018.00    332
# 2020.00    321
# 2017.00    139
# 2016.00     86
# 2015.00     40
# 2014.00     37
# 2013.00     17
# 2010.00     12
# 2012.00     12
# 2011.00     10
# 2009.00      5
# 2008.00      3
# 2005.00      1
# 2006.00      1
# 1970.00      1
# Name: production_date, dtype: int64
#
#
# None
#
# COLUMN NAME    :  energy_efficiency_class
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  125
# --------------------------------
# 5.00     102
# 4.10      86
# 4.70      85
# 5.10      79
# 5.60      76
# 4.50      73
# 4.30      72
# 4.80      71
# 5.20      68
# 5.40      68
# 5.50      65
# 4.90      65
# 5.30      61
# 4.60      61
# 4.00      50
# 5.70      49
# 6.00      45
# 4.40      44
# 6.50      40
# 7.20      39
# 6.30      39
# 4.20      38
# 5.90      38
# 5.80      36
# 6.20      36
# 6.10      35
# 6.60      34
# 3.70      33
# 6.80      31
# 7.40      30
# 7.70      29
# 7.00      27
# 6.40      26
# 0.00      25
# 7.60      25
# 1.70      23
# 6.70      22
# 7.10      21
# 1.50      17
# 6.90      17
# 3.30      17
# 3.80      16
# 7.50      15
# 7.30      15
# 2.80      15
# 3.90      15
# 8.60      14
# 8.20      14
# 3.60      14
# 7.90      13
# 8.70      12
# 9.40      12
# 1.90      12
# 7.80      11
# 1.80      11
# 8.40      11
# 10.80     11
# 1.20      10
# 2.30      10
# 12.00      9
# 1.10       9
# 8.00       8
# 8.30       8
# 8.90       7
# 12.40      7
# 2.10       7
# 3.50       7
# 11.80      6
# 9.50       6
# 2.40       6
# 9.00       6
# 1.60       5
# 1.40       5
# 10.70      5
# 0.80       5
# 10.50      5
# 11.20      5
# 12.30      5
# 2.00       4
# 9.70       4
# 10.20      4
# 12.80      4
# 12.10      4
# 10.00      4
# 10.40      4
# 9.60       4
# 11.40      4
# 3.40       4
# 11.10      4
# 3.00       4
# 10.90      4
# 8.80       3
# 9.90       3
# 9.30       3
# 11.90      3
# 11.60      3
# 11.30      3
# 12.20      3
# 8.10       3
# 13.60      2
# 2.20       2
# 3.20       2
# 0.90       2
# 0.60       2
# 9.10       2
# 1.00       2
# 12.90      2
# 11.50      2
# 10.10      2
# 14.40      2
# 13.00      2
# 13.90      1
# 8.50       1
# 2.90       1
# 9.20       1
# 9.80       1
# 10.30      1
# 12.50      1
# 11.70      1
# 56.00      1
# 1.30       1
# 14.90      1
# 10.60      1
# 0.70       1
# 12.60      1
# Name: combined_fuel_cons, dtype: int64
#
#
# None

# %%
first_looking("make_model", "make", "model")
# Out:
# COLUMN NAME    :  make_model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  212
# --------------------------------
# Ford Focus                  99
# Opel Insignia               97
# Opel Astra                  94
# Opel Corsa                  89
# Ford Fiesta                 80
# Volvo V60                   70
# Opel Grandland X            62
# Volvo XC60                  54
# Ford Kuga                   53
# Toyota Yaris                48
# Opel Crossland X            48
# SEAT Leon                   46
# Volvo XC40                  44
# Volvo V90                   38
# Skoda Fabia                 34
# Nissan Qashqai              34
# Opel Cascada                34
# Ford Mustang                34
# Toyota Corolla              32
# Toyota Aygo X               31
# Renault Clio                31
# Toyota C-HR                 30
# Volvo V90 Cross Country     30
# Volvo XC90                  28
# Hyundai i30                 28
# Peugeot 308                 26
# Mercedes-Benz C 200         26
# Mercedes-Benz C 300         22
# Ford Mondeo                 22
# Mercedes-Benz AMG GT        21
# Mondeo                22
# AMG GT                21
# Adam                  21
# Superb                21
# Ibiza                 21
# Octavia               20
# C 63 AMG              20
# Mokka                 19
# Karoq                 19
# Arona                 18
# Micra                 17
# Mokka X               17
# C 400                 15
# Grandland             15
# Ateca                 14
# 3008                  14
# E 400                 14
# Aygo                  13
# Megane                13
# Townstar              13
#                       13
# 500C                  12
# Karl                  12
# Kodiaq                12
# C 43 AMG              12
# GLC 63 AMG            12
# Supra                 11
# Juke                  11
# E 300                 11
# 500                   11
# RAV 4                 11
# V40                   10
# E 53 AMG              10
# TUCSON                10
# Citigo                 9
# Auris                  9
# Tourneo Custom         9
# 2008                   9
# Transit Connect        9
# Puma                   9
# Sandero                9
# Kadjar                 9
# Avensis                9
# GLC 43 AMG             8
# BAYON                  8
# C 220                  8
# C 180                  8
# V60 Cross Country      8
# Captur                 8
# S 580                  8
# Scala                  8
# 508                    8
# Tarraco                7
# 208                    7
# 108                    7
# i20                    7
# Tipo                   7
# S90                    7
# CLA 45 AMG             7
# E 200                  7
# GLE 400                7
# E 220                  7
# Proace                 6
# Talisman               6
# Pulsar                 6
# NV200                  6
# X                      6
# 370Z                   6
# Rapid                  6
# CLA 200                6
# GLC 400                6
# Prius                  6
# S60                    6
# Duster                 5
# Hilux                  5
# A 250                  5
# CLS 400                5
# GLC 300                5
# 5008                   5
# GLE 300                5
# i10                    5
# Jogger                 4
# Kamiq                  4
# Mirai                  4
# GLB 35 AMG             4
# Yaris Cross            4
# EcoSport               4
# GLE 580                4
# Crossland              4
# CLA 35 AMG             4
# E 350                  4
# A 35 AMG               4
# Ranger                 4
# Edge                   4
# S 63 AMG               4
# CLS 450                4
# CLS 53 AMG             3
# SLC 200                3
# G 500                  3
# G 400                  3
# KONA                   3
# 500X                   3
# CLA 180                3
# Navara                 3
# C 250                  3
# GLA 200                3
# Transit Custom         2
# S 400                  2
# IONIQ                  2
# NV300                  2
# i40                    2
# E 450                  2
# Primastar              2
# GLC 350                2
# Tourneo Courier        2
# 207                    2
# G 63 AMG               2
# GLA 220                2
# A 45 AMG               2
# 124 Spider             2
# GLS 400                2
# Alpine A110            2
# Logan                  2
# GLC 250                2
# Twingo                 2
# GLE 53 AMG             2
# GT86                   2
# B 250                  2
# Alaskan                2
# Kangoo                 1
# Express                1
# CLS 63 AMG             1
# Megane E               1
# SL 600                 1
# S                      1
# VELOSTER               1
# Grand C                1
# iX35                   1
# GLE 43 AMG             1
# SL 63 AMG              1
# SANTA FE               1
# CL                     1
# STARIA                 1
# E 250                  1
# S 350                  1
# Vectra                 1
# S 560                  1
# SLK                    1
# SL 500                 1
# Zafira Life            1
# S80                    1
# Grand Tourneo          1
# B 200                  1
# RCZ                    1
# C 350                  1
# Highlander             1
# Vivaro                 1
# Land Cruiser           1
# iQ                     1
# CLS 300                1
# Verso                  1
# GLE 450                1
# GLK 250                1
# GT                     1
# GLK 350                1
# Yeti                   1
# GLK 220                1
# G 350                  1
# G                      1
# Mii                    1
# GLC 200                1
# GLB 200                1
# Punto                  1
# GLC 220                1
# 107                    1
# Bronco                 1
# E 63 AMG               1
# GLE 350                1
# Explorer               1
# S 500                  1
# Combo Life             1
# Name: model, dtype: int64

# %%
df[['make_model', 'make', 'model', "short_description"]].sample(20)
# Out:
#                   make_model           make         model  \
# 1985             Ford Fiesta           Ford       Fiesta
# 966             Peugeot 2008        Peugeot         2008
# 711               Opel Astra           Opel        Astra
# 1160               SEAT Leon           SEAT         Leon
# 27    Mercedes-Benz C 63 AMG  Mercedes-Benz     C 63 AMG
# 918           Renault Megane        Renault       Megane
# 59       Mercedes-Benz C 200  Mercedes-Benz        C 200
# 347      Mercedes-Benz S 580  Mercedes-Benz        S 580
# 201    Mercedes-Benz GLS 400  Mercedes-Benz      GLS 400
# 1693           Ford EcoSport           Ford     EcoSport
# 968             Peugeot 3008        Peugeot         3008
# 937         Renault Talisman        Renault     Talisman
# 415               Opel Corsa           Opel        Corsa
# 261      Mercedes-Benz C 400  Mercedes-Benz        C 400
# 949             Renault Clio        Renault         Clio
# 525         Opel Crossland X           Opel  Crossland X
# 1520            Toyota Auris         Toyota        Auris
# 939           Renault Megane        Renault       Megane
# 260      Mercedes-Benz E 400  Mercedes-Benz        E 400
# 858               Opel Corsa           Opel        Corsa
#
#                                       short_description
# 1985                           1.0 EcoBoost S&S ST-LINE
# 966         1.2 PureTech Allure Klima ParkAssist Kamera
# 711           K Sports Tourer 1.5 D Edition LED 2xKlima
# 1160                        FR Plus 1.5 eTSI 150 PS DSG
# 27             Cabrio*Comand*Perf.-Abgas*Night*Driver's
# 918                            Limited 1.5 Blue DCI 115
# 59     Cabrio AMG Line Leder + Verdeck Rot/360°/ Autom.
# 347   e L 9G*AMG*Chauffeur-Paket*DigitalLight*Pano*HUD*
# 201    d 4MATIC AMG Line/Navi/SHD/Distronic/LED Styling
# 1693              Active 1.0 *LED*B&O*BLIS*SHZ*CAM*PDC*
# 968            1.6 PureTech 180 EAT8 GT-LINE Pano Leder
# 937             Grandtour 1.3 TCe Life Automatik EU6d-T
# 415         100PS Color Edition *Klima*WSS+Lkrd+SHz*PDC
# 261   4M T AVANTGARDE/ILS/Com/Pano/AHK/Burmester Autom.
# 949          V 1.3 TCe 130 Edt. One Autom.* BOSE* Navi*
# 525                        1.2 2020 HeadUp LED Navi PDC
# 1520         1.2 Turbo Team D DAB, Kamera, SHZ, BT, USB
# 939             Grandtour TCe 140 Business Edi. GPF EDC
# 260          d T 4M Exclusive+COM+Mbeam+Sthzg+Distr+360
# 858     E 1.2 ON, PDC, SHZ,LRHZ,FS heizbar, IntelliLink

# %%
df['model'].str.contains(r'^\s*$', na=False).value_counts()
# Out:
# False    2351
# True       13
# Name: model, dtype: int64

# %%
df["model"] = df["model"].replace(r'^\s*$', np.nan, regex=True)
df[df["model"].isna()][['make_model', 'make', 'model']]
# Out:
#           make_model           make model
# 5     Mercedes-Benz   Mercedes-Benz   NaN
# 15    Mercedes-Benz   Mercedes-Benz   NaN
# 53    Mercedes-Benz   Mercedes-Benz   NaN
# 54    Mercedes-Benz   Mercedes-Benz   NaN
# 76    Mercedes-Benz   Mercedes-Benz   NaN
# 302   Mercedes-Benz   Mercedes-Benz   NaN
# 308   Mercedes-Benz   Mercedes-Benz   NaN
# 321   Mercedes-Benz   Mercedes-Benz   NaN
# 900         Renault         Renault   NaN
# 902         Renault         Renault   NaN
# 1399         Toyota          Toyota   NaN
# 1468         Toyota          Toyota   NaN
# 2026        Hyundai         Hyundai   NaN

# %%
df.iloc[162]
# Out:
# make_model                                               Mercedes-Benz E 300
# short_description           E300d Cp. AMG+DISTR+PANO+BURM MEM+AMBIE+ILS+360°
# make                                                           Mercedes-Benz
# model                                                                 E 300
# location                            Hans-Schardt-Straße 2,  66822 Lebach, DE
# price                                                               50988.00
# body_type                                                              Coupe
# type                                                                    Used
# doors                                                                   2.00
# warranty                                                                 24
# mileage                                                             57800.00
# first_registration                                                   11/2019
# gearbox                                                            Automatic
# fuel_type                                           Diesel (Particle filter)
# seller                                                                Dealer
# seats                                                                   4.00
# engine_size                                                          1950.00
# gears                                                                   9.00
# co_emissions                                                          140.00
# drivetrain                                                              Rear
# cylinders                                                               4.00
# comfort_&_convenience      ['360° camera, Armrest, Automatic climate cont...
# entertainment_&_media      ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# safety_&_security          ['ABS, Adaptive Cruise Control, Adaptive headl...
# extras                     Alloy wheels, Ambient lighting, Automatically ...
# empty_weight                                                         1810.00
# full_service_history                                                     Yes
# upholstery                                                               NaN
# production_date                                                      2019.00
# previous_owner                                                          2.00
# energy_efficiency_class                                            efficient
# new                                                      Mercedes-Benz E 300
# combined_fuel_cons                                                      5.30
# Name: 162, dtype: object

# %%
# Let's define models and extract them from "short_description" feature
model_pattern = '(Mitecki)|(BJ40)|(Business)|(1300)|(TURBO)|(bj 42)|(4cv)|(B 220)|(E 63)|(S 580e)|(SL 43)|(EDITION 1)|(A 160)|(GLE 63)|(C 63)|(C 300)|(C 180)|(A 200)|(C 200)|(A 180)|(A 180)|(Clase GLK)|(Clase SL)|(ANDERE)|(220)|(E 500)|(GLA 250)|(4Matic)|(C 43)|(200CDI)|(AMG GT)|(AMG Autom)|(AMG-Night)|(4M)|(2.0 CDTi)|(1.4 Turbo)|(1.4 S/S)|(1.4 T)|(Cabrio 1.4)|(Cabrio 1.6)|(Cabrio 2.0)|(Olympia)|(Astra)|(Adam)|(i30)|(Twizy)|(Alpine)|(Zen)|(Spider)|(Intens)|(COUPE)|(Cabriolet)|(124 Spider)|(Qubo)|(Ultimate AWD)|(1st Edition AWD)|(240 Z)|(Buckel)|(CRDI)|(RS200)|(SPYDER)|(GR Supra)|(2,0 T-Bar)|(1.8)|(Mach E)|(370 Z)|(Zagato)|(Tornado)|(Essential)|(1100D)|(Topolino Lotus)|(850)|(Neuer 500)|(124 Spyder)|(R.S. Line)|(Blue dCi)|(1500)|(Coupè)|(201)|(Berline|(Berlina)|(403)|(600)|(850)|(124)|(128 sport)|(Cupra)|(COMFORT TCe)|(Abarth)|(Coupé)|(X-MODE)|(Family Active)|(LJ70)|(Auris Touring Sports)|(RAV)|(Cabrio)|(T-Bird)|(MUSTANG)|(RAPTOR)|(GALAXIE SUNLINER)|(HOT ROD)|(Spaceback)|(Datsun)|(Skyline)|(Roadster)|(1.0 T-GDI)|(Mild-Hybrid)|(BAYON)|(I30N)|(P 1800 E)|(P1800E)|(P1800)|(2.4 Momentum)|(PV544 Sport)|(444))'

# Let's create a new feature named "extracted_models" using model_pattern
df["extracted_models"] = (df["short_description"].str.extract(model_pattern, flags=re.IGNORECASE)).bfill(axis=1)[0]

# let's explore which "make_model", "make", and "model" have NaN values
df[df["model"].isna()][['make_model', 'make', 'model', "extracted_models", "short_description"]]
# Out:
#           make_model           make model extracted_models  \
# 5     Mercedes-Benz   Mercedes-Benz   NaN            SL 43
# 15    Mercedes-Benz   Mercedes-Benz   NaN           ANDERE
# 53    Mercedes-Benz   Mercedes-Benz   NaN            C 180
# 54    Mercedes-Benz   Mercedes-Benz   NaN            C 200
# 76    Mercedes-Benz   Mercedes-Benz   NaN           AMG GT
# 302   Mercedes-Benz   Mercedes-Benz   NaN            C 300
# 308   Mercedes-Benz   Mercedes-Benz   NaN             E 63
# 321   Mercedes-Benz   Mercedes-Benz   NaN           S 580e
# 900         Renault         Renault   NaN              Zen
# 902         Renault         Renault   NaN        R.S. Line
# 1399         Toyota          Toyota   NaN         GR Supra
# 1468         Toyota          Toyota   NaN              RAV
# 2026        Hyundai         Hyundai   NaN        1.0 T-GDI
#
#                                       short_description
# 5       SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY
# 15              ANDERE 43 Premium-Navi*360°Ka.*AIRSCARF
# 53                      C 180 Cabrio 9G-TRONIC AMG Line
# 54                      C 200 Cabrio 9G-TRONIC AMG Line
# 76     AMG GT S E AMG PERFORMANCE grau magno HUD+CARBON
# 302   C 300 e T 9G AMG*Pano*Distronic*Digital-Light*...
# 308   E 63 AMG E 63 S AMG 4M+ MBUXHighE+PD+Burm+Mbea...
# 321    S 580e 4M L 9G*AMG*Chauffeur*Pano*Digital-Light*
# 900   Zen 1.3 TCe  LED+Navi+Keyless+Rückfahrkam.+PDC...
# 902                 R.S. Line TCe 140 *Navi *360°*KLIMA
# 1399       GR Supra Dynamic Kamera,Navigation, Sitzhzg.
# 1468  RAV 2.5 Hybrid PlugIn 4x4 Technik-P., Klimaaut...
# 2026  1.0 T-GDI 48V Mild-Hybrid Intro Edition 100PS ...

# %%
df["model"].isna().sum()
# Out:
# 13

# %%
df['model'].fillna(df['extracted_models']).isnull().sum()
# Out:
# 0

# %%
df[['make_model', 'make', 'model', "extracted_models", "short_description"]]
# Out:
#                 make_model           make    model extracted_models  \
# 0      Mercedes-Benz E 400  Mercedes-Benz   E 400                4M
# 1     Mercedes-Benz AMG GT  Mercedes-Benz  AMG GT               NaN
# 2      Mercedes-Benz C 400  Mercedes-Benz   C 400               NaN
# 3     Mercedes-Benz AMG GT  Mercedes-Benz  AMG GT          Roadster
# 4     Mercedes-Benz AMG GT  Mercedes-Benz  AMG GT          Roadster
# ...                    ...            ...      ...              ...
# 2359             Volvo S60          Volvo     S60               NaN
# 2360             Volvo S90          Volvo     S90               NaN
# 2361             Volvo S90          Volvo     S90               NaN
# 2362             Volvo S60          Volvo     S60               NaN
# 2363             Volvo S60          Volvo     S60               NaN
#
#                                       short_description
# 0     d 4M AMG/Com/ILS/Distr/KeyG/360/Standh/ABC Autom.
# 1     Mercedes- Keramik/Carbon/Burmester/Night Distr...
# 2     AMG/Comand/Distr/KeyGO/Sitzklima/Memory Distronic
# 3        Roadster COMAND/Burmester/Memory/Kamera Autom.
# 4        GT S Roadster KAMERA+BURMESTER+MEMORY+AIRSCARF
# ...                                                 ...
# 2359  R Design B5 Benzin EU6d LED Navi StandHZG Keyless
# 2360  R Design AWD B5 Diesel EU6d Leder LED Navi Sta...
# 2361                             D4 Geartronic R Design
# 2362  R Design B4 Benzin EU6d LED Navi StandHZG Keyless
# 2363      R Design B4 Mild Hybrid Benzin EU6d Pano BLIS
#
# [2364 rows x 5 columns]

# %%
df[(df["model"].isna()) & (df["extracted_models"].isna())][['make_model', 'make', 'model', "extracted_models", "short_description"]]
# Out:
# Empty DataFrame
# Columns: [make_model, make, model, extracted_models, short_description]
# Index: []

# %%
model_index_nan = df[df["model"].isna()][['make_model', 'make', 'model', "extracted_models", "short_description"]].index

model_index_nan
# Out:
# Int64Index([5, 15, 53, 54, 76, 302, 308, 321, 900, 902, 1399, 1468, 2026], dtype='int64')

# %%
df['model'].fillna(df['extracted_models'], inplace=True)

display(df['model'].isnull().sum())
display(df['make_model'].isnull().sum())
# Out:
# 0
# 0

# %%
df[df["model"].isna()][['make_model', 'make', 'model', "extracted_models", "short_description"]]
# Out:
# Empty DataFrame
# Columns: [make_model, make, model, extracted_models, short_description]
# Index: []

# %%
display(df.shape)  # Gives the shape of df BEFORE dropping NaN values in 'model'

df.dropna(subset=['model'], inplace=True)

display(df['model'].isnull().sum())  # Gives the total number of NaN values in 'model' AFTER dropping them 

display(df.shape)  # Gives the shape of df AFTER dropping NaN values in 'model'
# Out:
# (2364, 34)
# 0
# (2364, 34)

# %%
df["modified_make_model"] = df["make"] + " " + df["model"]
modified_make_model = df.pop("modified_make_model")
df.insert(1, 'modified_make_model', modified_make_model)
df["modified_make_model"]
# Out:
# 0        Mercedes-Benz E 400
# 1       Mercedes-Benz AMG GT
# 2        Mercedes-Benz C 400
# 3       Mercedes-Benz AMG GT
# 4       Mercedes-Benz AMG GT
#                 ...
# 2359               Volvo S60
# 2360               Volvo S90
# 2361               Volvo S90
# 2362               Volvo S60
# 2363               Volvo S60
# Name: modified_make_model, Length: 2364, dtype: object

# %%
df[["make_model", "modified_make_model"]]
# Out:
#                 make_model    modified_make_model
# 0      Mercedes-Benz E 400   Mercedes-Benz E 400
# 1     Mercedes-Benz AMG GT  Mercedes-Benz AMG GT
# 2      Mercedes-Benz C 400   Mercedes-Benz C 400
# 3     Mercedes-Benz AMG GT  Mercedes-Benz AMG GT
# 4     Mercedes-Benz AMG GT  Mercedes-Benz AMG GT
# ...                    ...                    ...
# 2359             Volvo S60             Volvo S60
# 2360             Volvo S90             Volvo S90
# 2361             Volvo S90             Volvo S90
# 2362             Volvo S60             Volvo S60
# 2363             Volvo S60             Volvo S60
#
# [2364 rows x 2 columns]

# %%
df['modified_make_model'].fillna(df['make_model'], inplace=True)

display(df['model'].isnull().sum())
display(df['make_model'].isnull().sum())
display(df['modified_make_model'].isnull().sum())
# Out:
# 0
# 0
# 0

# %%
df['make_model'] = df['modified_make_model']
df.iloc[162]
# Out:
# make_model                                              Mercedes-Benz E 300
# modified_make_model                                     Mercedes-Benz E 300
# short_description           E300d Cp. AMG+DISTR+PANO+BURM MEM+AMBIE+ILS+360°
# make                                                           Mercedes-Benz
# model                                                                 E 300
# location                            Hans-Schardt-Straße 2,  66822 Lebach, DE
# price                                                               50988.00
# body_type                                                              Coupe
# type                                                                    Used
# doors                                                                   2.00
# warranty                                                                 24
# mileage                                                             57800.00
# first_registration                                                   11/2019
# gearbox                                                            Automatic
# fuel_type                                           Diesel (Particle filter)
# seller                                                                Dealer
# seats                                                                   4.00
# engine_size                                                          1950.00
# gears                                                                   9.00
# co_emissions                                                          140.00
# drivetrain                                                              Rear
# cylinders                                                               4.00
# comfort_&_convenience      ['360° camera, Armrest, Automatic climate cont...
# entertainment_&_media      ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# safety_&_security          ['ABS, Adaptive Cruise Control, Adaptive headl...
# extras                     Alloy wheels, Ambient lighting, Automatically ...
# empty_weight                                                         1810.00
# full_service_history                                                     Yes
# upholstery                                                               NaN
# production_date                                                      2019.00
# previous_owner                                                          2.00
# energy_efficiency_class                                            efficient
# new                                                      Mercedes-Benz E 300
# combined_fuel_cons                                                      5.30
# extracted_models                                                         NaN
# Name: 162, dtype: object

# %%
df["make_model"].replace(["Ford SPYDER", "Ford MUSTANG", "Renault Grand Espace", "Fiat Spider", "Fiat Spider Europa", "Fiat 1300", "Opel Zafira Tourer", "Opel Zafira Life", "Toyota GR Supra", "Ford Grand C-Max", "Volvo P 1800 E", "Volvo P1800E", "Volvo coupe", "Toyota Auris Touring Sports", "Ford Mustang Mach-E\t", "Toyota Prius+", "Toyota 1.8", "Mercedes-Benz AMG-Night", "Mercedes-Benz Clase GLK", "Mercedes-Benz Clase SL", "Ford Hot Rod", "Ford HOT ROD", "Ford Hot rod", "Fiat 124 Coupè", "Fiat COUPÈ", "Fiat Coupè", "Toyota Corolla Verso", "Toyota Verso-S", "Renault Alpine", "Hyundai KONA Elektro", "Hyundai 1.0 T-GDi", "Hyundai H 350", "Hyundai H-1", "Hyundai ACCENT", "Hyundai CRDI", "Renault"],
                         ["Ford Mustang", "Ford Mustang", "Renault Espace", "Fiat 124 Spider", "Fiat 124 Spider", "Fiat 130", "Opel Zafira", "Opel Zafira", "Toyota Supra", "Ford C-Max", "Volvo P1800", "Volvo P1800", "Volvo Coupe", "Toyota Auris", "Ford Mustang Mach-E", "Toyota Prius", "Toyota MR 2", "Mercedes-Benz AMG GT", "Mercedes-Benz Clase", "Mercedes-Benz Clase", "Ford Hot Rod", "Ford Hot Rod", "Ford Hot Rod", "Fiat 124 Coupe", "Fiat 124 Coupe", "Fiat 124 Coupe", "Toyota Verso", "Toyota Verso", "Renault Alpine A110", "Hyundai KONA", "Hyundai 1.0 T-GDI", "Hyundai H", "Hyundai H", "Hyundai Accent", "Hyundai Accent", "Renault Megane"], inplace=True)

# %%
df[["make_model", "make", "model"]] = df[["make_model", "make", "model"]].apply(lambda x: x.str.title())

# %%
df.drop(["modified_make_model", "short_description", "extracted_models"], axis=1, inplace=True)
df.head()
# Out:
#               make_model           make    model  \
# 0   Mercedes-Benz E 400   Mercedes-Benz   E 400
# 1  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 2   Mercedes-Benz C 400   Mercedes-Benz   C 400
# 3  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 4  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
#
#                                        location     price    body_type  \
# 0      Julius-Rütgers-Str. 1,  15537 Erkner, DE  64870.00  Convertible
# 1     Wormser Landstraße 194,  67346 Speyer, DE 197500.00  Convertible
# 2          Autofocus 3,  15517 Fürstenwalde, DE  63370.00  Convertible
# 3  Meckenheimer Straße 12,  53359 Rheinbach, DE 175000.00  Convertible
# 4   St.-Georgener-Straße 1,  79111 Freiburg, DE 149890.00  Convertible
#
#               type  doors warranty  mileage first_registration    gearbox  \
# 0             Used   2.00      24  78473.00            01/2020  Automatic
# 1   Employee's car   2.00       0   9550.00            04/2021  Automatic
# 2   Employee's car   2.00      24  20145.00            01/2021  Automatic
# 3             Used   2.00      24   3561.00            07/2021  Automatic
# 4             Used   3.00      Yes 23851.00            12/2019  Automatic
#
#                         fuel_type  seller  seats  engine_size  gears  \
# 0        Diesel (Particle filter)  Dealer   4.00      2925.00   9.00
# 1                        Super 95  Dealer   2.00      3982.00   7.00
# 2                        Super 95  Dealer   4.00      2996.00   9.00
# 3                        Super 95  Dealer   2.00      3982.00   7.00
# 4  Super E10 95 (Particle filter)  Dealer   2.00      3982.00   7.00
#
#    co_emissions drivetrain  cylinders  \
# 0        162.00        4WD       6.00
# 1        298.00       Rear       8.00
# 2        196.00        4WD       6.00
# 3        296.00        NaN       8.00
# 4        262.00        NaN       8.00
#
#                                comfort_&_convenience  \
# 0  ['360° camera, Air conditioning, Air suspensio...
# 1  ['Air conditioning, Armrest, Automatic climate...
# 2  ['Armrest, Automatic climate control, 2 zones,...
# 3  ['Air conditioning, Armrest, Automatic climate...
# 4  ['Air conditioning, Armrest, Automatic climate...
#
#                                entertainment_&_media  \
# 0  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 1  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 3  ['Android Auto, Apple CarPlay, Digital radio, ...
# 4  ['Apple CarPlay, Bluetooth, Digital radio, Han...
#
#                                    safety_&_security  \
# 0  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 1  ['ABS, Adaptive Cruise Control, Alarm system, ...
# 2  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 3  ['ABS, Blind spot monitor, Central door lock, ...
# 4  ['ABS, Adaptive Cruise Control, Alarm system, ...
#
#                                               extras  empty_weight  \
# 0  Alloy wheels, Ambient lighting, Automatically ...       2010.00
# 1  Alloy wheels, Ambient lighting, Automatically ...       1735.00
# 2  Alloy wheels, Ambient lighting, Automatically ...       1825.00
# 3  Alloy wheels, Automatically dimming interior m...       1700.00
# 4  Alloy wheels (20"), Ambient lighting, Automati...       1700.00
#
#   full_service_history    upholstery  production_date  previous_owner  \
# Mercedes-Benz B 200           1
# Toyota Highlander             1
# Mercedes-Benz Glc 220         1
# Mercedes-Benz Glc 200         1
# Mercedes-Benz C 180           1
# Toyota Supra                  1
# Mercedes-Benz Glb 200         1
# Mercedes-Benz Sl 600          1
# Toyota Iq                     1
# Toyota Verso                  1
# Mercedes-Benz Amg Gt          1
# Mercedes-Benz Cl              1
# Mercedes-Benz Sl 63 Amg       1
# Mercedes-Benz Gle 350         1
# Nissan Gt                     1
# Mercedes-Benz G 350           1
# Mercedes-Benz C 300           1
# Mercedes-Benz S 500           1
# Mercedes-Benz Glk 220         1
# Seat Mii                      1
# Mercedes-Benz E 63            1
# Mercedes-Benz Cls 63 Amg      1
# Fiat Punto                    1
# Mercedes-Benz S 580E          1
# Peugeot 107                   1
# Mercedes-Benz E 250           1
# Mercedes-Benz Gle 43 Amg      1
# Name: make_model, dtype: int64
#
#
# COLUMN NAME    :  make
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  13
# --------------------------------
# Opel             516
# Mercedes-Benz    357
# Ford             336
# Volvo            296
# Toyota           227
# Skoda            134
# Seat             107
# Nissan           107
# Peugeot           80
# Renault           78
# Hyundai           70
# Fiat              36
# Dacia             20
# Name: make, dtype: int64
#
#
# COLUMN NAME    :  model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  221
# --------------------------------
# Focus                 99
# Insignia              97
# Astra                 94
# Corsa                 89
# Fiesta                80
# V60                   70
# Grandland X           62
# Xc60                  54
# Kuga                  53
# Crossland X           48
# Yaris                 48
# Leon                  46
# Xc40                  44
# V90                   38
# Fabia                 34
# Mustang               34
# Qashqai               34
# Cascada               34
# Corolla               32
# Clio                  31
# Aygo X                31
# V90 Cross Country     30
# C                     30
# I30                   28
# Xc90                  28
# 308                   26
# C 200                 26
# Mondeo                22
# C 300                 22
# Superb                21
# Amg Gt                21
# Adam                  21
# Ibiza                 21
# Octavia               20
# C 63 Amg              20
# Karoq                 19
# Mokka                 19
# Arona                 18
# Mokka X               17
# Micra                 17
# Grandland             15
# C 400                 15
# 3008                  14
# Ateca                 14
# E 400                 14
# Aygo                  13
# Megane                13
# Townstar              13
# Karl                  12
# Kodiaq                12
# 500C                  12
# Glc 63 Amg            12
# C 43 Amg              12
# Rav 4                 11
# 500                   11
# E 300                 11
# Juke                  11
# Supra                 11
# Tucson                10
# E 53 Amg              10
# V40                   10
# Kadjar                 9
# 2008                   9
# Sandero                9
# Citigo                 9
# Avensis                9
# Auris                  9
# Transit Connect        9
# Tourneo Custom         9
# Puma                   9
# S 580                  8
# V60 Cross Country      8
# Captur                 8
# Bayon                  8
# 508                    8
# C 220                  8
# Glc 43 Amg             8
# C 180                  8
# Scala                  8
# Gle 400                7
# Tipo                   7
# Tarraco                7
# 108                    7
# 208                    7
# I20                    7
# E 220                  7
# Cla 45 Amg             7
# E 200                  7
# S90                    7
# Talisman               6
# Cla 200                6
# S60                    6
# Proace                 6
# Rapid                  6
# Prius                  6
# 370Z                   6
# Glc 400                6
# X                      6
# Nv200                  6
# Pulsar                 6
# Hilux                  5
# Duster                 5
# Cls 400                5
# Glc 300                5
# A 250                  5
# 5008                   5
# I10                    5
# Gle 300                5
# Kamiq                  4
# S 63 Amg               4
# Cls 450                4
# Glb 35 Amg             4
# Ecosport               4
# Mirai                  4
# A 35 Amg               4
# Yaris Cross            4
# Ranger                 4
# Edge                   4
# Gle 580                4
# Cla 35 Amg             4
# Crossland              4
# Jogger                 4
# E 350                  4
# Navara                 3
# Gla 200                3
# Cla 180                3
# G 500                  3
# C 250                  3
# Cls 53 Amg             3
# G 400                  3
# 500X                   3
# Kona                   3
# Slc 200                3
# Gla 220                2
# Transit Custom         2
# Gls 400                2
# G 63 Amg               2
# Gle 53 Amg             2
# Nv300                  2
# E 450                  2
# Tourneo Courier        2
# Glc 250                2
# Ioniq                  2
# I40                    2
# Primastar              2
# Gt86                   2
# S 400                  2
# 124 Spider             2
# 207                    2
# A 45 Amg               2
# Glc 350                2
# B 250                  2
# Alpine A110            2
# Alaskan                2
# Logan                  2
# Twingo                 2
# Grand C                1
# Glk 250                1
# S                      1
# C 200                  1
# Glk 350                1
# Zen                    1
# Grand Tourneo          1
# Megane E               1
# Kangoo                 1
# Express                1
# Explorer               1
# R.S. Line              1
# Ix35                   1
# S 560                  1
# Vectra                 1
# S80                    1
# Combo Life             1
# Vivaro                 1
# Sl 43                  1
# Zafira Life            1
# Sl 500                 1
# Slk                    1
# Veloster               1
# Andere                 1
# Gle 450                1
# Staria                 1
# 1.0 T-Gdi              1
# Santa Fe               1
# Cls 300                1
# S 350                  1
# Rcz                    1
# Bronco                 1
# E 63 Amg               1
# G                      1
# Yeti                   1
# C 350                  1
# Rav                    1
# Land Cruiser           1
# B 200                  1
# Highlander             1
# Glc 220                1
# Glc 200                1
# C 180                  1
# Gr Supra               1
# Glb 200                1
# Sl 600                 1
# Iq                     1
# Verso                  1
# Amg Gt                 1
# Cl                     1
# Sl 63 Amg              1
# Gle 350                1
# Gt                     1
# G 350                  1
# C 300                  1
# S 500                  1
# Glk 220                1
# Mii                    1
# E 63                   1
# Cls 63 Amg             1
# Punto                  1
# S 580E                 1
# 107                    1
# E 250                  1
# Gle 43 Amg             1
# Name: model, dtype: int64

# %%
first_looking("body_type")
# Out:
# COLUMN NAME    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# Off-Road/Pick-up    684
# Station wagon       609
# Sedan               461
# Compact             293
# Coupe               175
# Convertible         142
# Name: body_type, dtype: int64

# %%
df['body_type'] = df['body_type'].str.title()

# %%
first_looking("body_type")
# Out:
# COLUMN NAME    :  body_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# --------------------------------
# Off-Road/Pick-Up    684
# Station Wagon       609
# Sedan               461
# Compact             293
# Coupe               175
# Convertible         142
# Name: body_type, dtype: int64

# %% [markdown]
# FILLING MISSING VALUES

# %%
df_isnull = df[df.columns[df.isnull().any()]]
df_isnull.columns
# Out:
# Index(['fuel_type', 'seats', 'engine_size', 'gears', 'drivetrain', 'cylinders',
#        'comfort_&_convenience', 'entertainment_&_media', 'safety_&_security',
#        'extras', 'empty_weight', 'upholstery', 'previous_owner'],
#       dtype='object')

# %%
interact(show_missing_values, limit=(0, 100, 5))
# Out:
# interactive(children=(IntSlider(value=50, description='limit', step=5), Output()), _dom_classes=('widget-inter…
# <function __main__.show_missing_values(limit)>

# %%
first_looking("engine_size")
# Out:
# COLUMN NAME    :  engine_size
# --------------------------------
# per_of_nulls   :  % 0.25
# num_of_nulls   :  6
# num_of_uniques :  102
# --------------------------------
# 1969.00    267
# 999.00     191
# 1199.00    185
# 1598.00    169
# 998.00     157
# 1498.00     82
# 1991.00     67
# 3982.00     67
# 1332.00     56
# 1998.00     54
# 1997.00     53
# 1984.00     50
# 1995.00     49
# 1798.00     43
# 1499.00     42
# 2996.00     40
# 1956.00     40
# 1364.00     39
# 1968.00     38
# 1987.00     38
# 2925.00     37
# 1490.00     37
# 2999.00     34
# 1496.00     32
# 1197.00     31
# 1497.00     29
# 5038.00     26
# 1950.00     25
# 898.00      24
# 1398.00     23
# 1477.00     22
# 1229.00     17
# 1461.00     16
# 1399.00     13
# 1618.00     12
# 1482.00     11
# 2261.00     11
# 2488.00     10
# 1368.00      9
# 1242.00      9
# 2143.00      9
# 1597.00      9
# 1993.00      8
# 1595.00      8
# 1999.00      8
# 2998.00      8
# 1084.00      8
# 1591.00      8
# 875.00       7
# 4951.00      6
# 1560.00      6
# 2792.00      6
# 1796.00      6
# 3696.00      6
# NaN          6
# 1395.00      6
# 1198.00      5
# 2987.00      5
# 2487.00      5
# 2755.00      5
# 1341.00      5
# 1329.00      4
# 1248.00      4
# 2299.00      4
# 1333.00      3
# 1596.00      3
# 3198.00      3
# 2494.00      3
# 1149.00      3
# 1685.00      2
# 2521.00      2
# 5461.00      2
# 1580.00      2
# 1686.00      2
# 1582.00      2
# 1390.00      2
# 0.00         2
# 2199.00      1
# 2000.00      1
# 1500.00      1
# 2359.00      1
# 2956.00      1
# 1388.00      1
# 2966.00      1
# 1353.00      1
# 2298.00      1
# 1342.00      1
# 2198.00      1
# 5162.00      1
# 3720.00      1
# 5513.00      1
# 4663.00      1
# 1749.00      1
# 3799.00      1
# 2231.00      1
# 2478.00      1
# 2393.00      1
# 1422.00      1
# 1400.00      1
# 1495.00      1
# 3498.00      1
# 1200.00      1
# 2400.00      1
# Name: engine_size, dtype: int64

# %%
df["engine_size"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type","engine_size"]).price.describe()
# Out:
#                                             count     mean      std      min  \
# make_model    body_type        engine_size
# Dacia Duster  Off-Road/Pick-Up 1197.00       1.00 14990.00      NaN 14990.00
#                                1332.00       2.00 20070.00  1527.35 18990.00
#                                1461.00       1.00 21690.00      NaN 21690.00
#                                1598.00       1.00 16490.00      NaN 16490.00
# Dacia Jogger  Station Wagon    999.00        4.00 23207.50  1364.61 21750.00
# ...                                           ...      ...      ...      ...
# Volvo Xc40    Off-Road/Pick-Up 1969.00      22.00 31586.36  3684.71 25480.00
# Volvo Xc60    Compact          1969.00       2.00 72940.00     0.00 72940.00
#               Off-Road/Pick-Up 1969.00      48.00 50439.12 17273.21 27990.00
#                                1984.00       4.00 17935.00  1091.19 16990.00
# Volvo Xc90    Off-Road/Pick-Up 1969.00      28.00 64244.57 22843.15 29980.00
#
#                                                 25%      50%      75%      max
# make_model    body_type        engine_size
# Dacia Duster  Off-Road/Pick-Up 1197.00     14990.00 14990.00 14990.00 14990.00
#                                1332.00     19530.00 20070.00 20610.00 21150.00
#                                1461.00     21690.00 21690.00 21690.00 21690.00
#                                1598.00     16490.00 16490.00 16490.00 16490.00
# Dacia Jogger  Station Wagon    999.00      22237.50 23195.00 24165.00 24690.00
# ...                                             ...      ...      ...      ...
# Volvo Xc40    Off-Road/Pick-Up 1969.00     29440.00 31770.00 34862.50 36490.00
# Volvo Xc60    Compact          1969.00     72940.00 72940.00 72940.00 72940.00
#               Off-Road/Pick-Up 1969.00     36074.75 46930.00 68915.00 83890.00
#                                1984.00     16990.00 17935.00 18880.00 18880.00
# Volvo Xc90    Off-Road/Pick-Up 1969.00     44970.00 64220.00 84780.00 97450.00
#
# [635 rows x 8 columns]

# %% [markdown]
# ## The engine_size of cars changes by their make_models & body_type most of the time. So it is more beneficial to decide to fill missing values with mode value of corresponding group.

# %%
df["engine_size"].replace("-", np.nan, inplace=True)

# %%
def fill(df, group_col1, group_col2, col_name, method): # method can be either "mode" or "mean" or "median" or "ffill"
    
    '''Fills the missing values with "mode/mean/median/ffill/bfill method" according to double-stage grouping'''
    
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

    elif method == "mean":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("mean"), inplace = True)
        df[col_name].fillna(df[col_name].mean(), inplace = True)
        
    elif method == "median":
        df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
        df[col_name].fillna(df[col_name].median(), inplace = True)
        
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("COLUMN NAME    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False).sort_index())

# %%
fill(df, "make_model", "body_type", "engine_size", "mode")
# Out:
# COLUMN NAME    :  engine_size
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  102
# --------------------------------
# 0.00         4
# 875.00       7
# 898.00      24
# 998.00     158
# 999.00     192
# 1084.00      8
# 1149.00      3
# 1197.00     31
# 1198.00      5
# 1199.00    186
# 1200.00      1
# 1229.00     17
# 1242.00      9
# 1248.00      4
# 1329.00      4
# 1332.00     56
# 1333.00      3
# 1341.00      5
# 1342.00      1
# 1353.00      1
# 1364.00     39
# 1368.00      9
# 1388.00      1
# 1390.00      2
# 1395.00      6
# 1398.00     23
# 1399.00     13
# 1400.00      1
# 1422.00      1
# 1461.00     16
# 1477.00     22
# 1482.00     11
# 1490.00     37
# 1495.00      1
# 1496.00     32
# 1497.00     29
# 1498.00     82
# 1499.00     42
# 1500.00      1
# 1560.00      6
# 1580.00      2
# 1582.00      2
# 1591.00      8
# 1595.00      8
# 1596.00      3
# 1597.00      9
# 1598.00    169
# 1618.00     12
# 1685.00      2
# 1686.00      2
# 1749.00      1
# 1796.00      6
# 1798.00     44
# 1950.00     25
# 1956.00     40
# 1968.00     38
# 1969.00    267
# 1984.00     50
# 1987.00     38
# 1991.00     67
# 1993.00      8
# 1995.00     49
# 1997.00     53
# 1998.00     54
# 1999.00      8
# 2000.00      1
# 2143.00      9
# 2198.00      1
# 2199.00      1
# 2231.00      1
# 2261.00     11
# 2298.00      1
# 2299.00      4
# 2359.00      1
# 2393.00      1
# 2400.00      1
# 2478.00      1
# 2487.00      5
# 2488.00     10
# 2494.00      3
# 2521.00      2
# 2755.00      5
# 2792.00      6
# 2925.00     37
# 2956.00      1
# 2966.00      1
# 2987.00      5
# 2996.00     40
# 2998.00      8
# 2999.00     34
# 3198.00      3
# 3498.00      1
# 3696.00      6
# 3720.00      1
# 3799.00      1
# 3982.00     67
# 4663.00      1
# 4951.00      6
# 5038.00     26
# 5162.00      1
# 5461.00      2
# 5513.00      1
# Name: engine_size, dtype: int64

# %%
first_looking("doors")
# Out:
# COLUMN NAME    :  doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# 5.00    1889
# 2.00     216
# 3.00     132
# 4.00     127
# Name: doors, dtype: int64

# %%
# The number of doors of cars mostly changes by their make_models and body_types. So it's decided to fill missing values with mode value of corresponding group.
# This is the nested for loop where it's used in fill_mode(df, group_col1, group_col2, col_name) DEF to be generalized for all data

for group1 in list(df["make_model"].unique()):
    for group2 in list(df["body_type"].unique()):
        cond1 = df["make_model"]==group1
        cond2 = (df["make_model"]==group1) & (df["body_type"]==group2)
        mode1 = list(df[cond1]["doors"].mode())
        mode2 = list(df[cond2]["doors"].mode())
        if mode2 != []:
            df.loc[cond2, "doors"] = df.loc[cond2, "doors"].fillna(df[cond2]["doors"].mode()[0])
        elif mode1 != []:
            df.loc[cond2, "doors"] = df.loc[cond2, "doors"].fillna(df[cond1]["doors"].mode()[0])
        else:
            df.loc[cond2, "doors"] = df.loc[cond2, "doors"].fillna(df["doors"].mode()[0])

# %%
# df["doors"].value_counts(dropna=False)
first_looking("doors")
# Out:
# COLUMN NAME    :  doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# 5.00    1889
# 2.00     216
# 3.00     132
# 4.00     127
# Name: doors, dtype: int64

# %%
def fill_mode(df, group_col1, group_col2, col_name):
    
    for group1 in list(df[group_col1].unique()):
        for group2 in list(df[group_col2].unique()):
            cond1 = df[group_col1]==group1
            cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
            mode1 = list(df[cond1][col_name].mode())
            mode2 = list(df[cond2][col_name].mode())
            if mode2 != []:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
            elif mode1 != []:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
            else:
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])
    
    print("column name    : ", col_name)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col_name].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col_name].isnull().sum())
    print("num_of_uniques : ", df[col_name].nunique())
    print("--------------------------------")
    print(df[col_name].value_counts(dropna = False))

# %%
# In fact there is no need to run this DEF since all NaNs manually were filled above by for nested loop
fill_mode(df, "make_model", "body_type", "doors")
# Out:
# column name    :  doors
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  4
# --------------------------------
# 5.00    1889
# 2.00     216
# 3.00     132
# 4.00     127
# Name: doors, dtype: int64

# %%
first_looking("gears")
# Out:
# COLUMN NAME    :  gears
# --------------------------------
# per_of_nulls   :  % 10.49
# num_of_nulls   :  248
# num_of_uniques :  8
# --------------------------------
# 6.00     915
# 8.00     458
# 5.00     253
# NaN      248
# 7.00     197
# 9.00     192
# 1.00      85
# 10.00     14
# 4.00       2
# Name: gears, dtype: int64

# %%
df[df["fuel_type"]=="Electric"].gears.value_counts(dropna=False)
# Out:
# Series([], Name: gears, dtype: int64)

# %%
df["gears"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type", "gearbox", "gears"]).price.describe()
# Out:
#                                                  count     mean      std  \
# make_model     body_type        gearbox   gears
# Dacia Duster   Off-Road/Pick-Up Manual    5.00    1.00 16490.00      NaN
#                                           6.00    4.00 19205.00  3042.52
# Dacia Jogger   Station Wagon    Manual    6.00    4.00 23207.50  1364.61
# Dacia Logan    Station Wagon    Manual    5.00    2.00 10990.00     0.00
# Dacia Sandero  Compact          Automatic 1.00    1.00 18990.00      NaN
# ...                                                ...      ...      ...
# Volvo Xc40     Off-Road/Pick-Up Manual    6.00   12.00 29681.67  2205.12
# Volvo Xc60     Compact          Automatic 8.00    2.00 72940.00     0.00
#                Off-Road/Pick-Up Automatic 8.00   44.00 52210.86 16933.96
#                                 Manual    6.00    8.00 24442.50  7342.62
# Volvo Xc90     Off-Road/Pick-Up Automatic 8.00   28.00 64244.57 22843.15
#
#                                                      min      25%      50%  \
# make_model     body_type        gearbox   gears
# Dacia Duster   Off-Road/Pick-Up Manual    5.00  16490.00 16490.00 16490.00
#                                           6.00  14990.00 17990.00 20070.00
# Dacia Jogger   Station Wagon    Manual    6.00  21750.00 22237.50 23195.00
# Dacia Logan    Station Wagon    Manual    5.00  10990.00 10990.00 10990.00
# Dacia Sandero  Compact          Automatic 1.00  18990.00 18990.00 18990.00
# ...                                                  ...      ...      ...
# Volvo Xc40     Off-Road/Pick-Up Manual    6.00  25480.00 28880.00 30385.00
# Volvo Xc60     Compact          Automatic 8.00  72940.00 72940.00 72940.00
#                Off-Road/Pick-Up Automatic 8.00  28680.00 37890.00 48460.00
#                                 Manual    6.00  16990.00 18407.50 23435.00
# Volvo Xc90     Off-Road/Pick-Up Automatic 8.00  29980.00 44970.00 64220.00
#
#                                                      75%      max
# make_model     body_type        gearbox   gears
# Dacia Duster   Off-Road/Pick-Up Manual    5.00  16490.00 16490.00
#                                           6.00  21285.00 21690.00
# Dacia Jogger   Station Wagon    Manual    6.00  24165.00 24690.00
# Dacia Logan    Station Wagon    Manual    5.00  10990.00 10990.00
# Dacia Sandero  Compact          Automatic 1.00  18990.00 18990.00
# ...                                                  ...      ...
# Volvo Xc40     Off-Road/Pick-Up Manual    6.00  30980.00 31980.00
# Volvo Xc60     Compact          Automatic 8.00  72940.00 72940.00
#                Off-Road/Pick-Up Automatic 8.00  68990.00 83890.00
#                                 Manual    6.00  29470.00 33910.00
# Volvo Xc90     Off-Road/Pick-Up Automatic 8.00  84780.00 97450.00
#
# [616 rows x 8 columns]

# %% [markdown]
# The number of gears of cars changes by their make_models, body_types, and gearbox most of the time. So it's decided to fill missing values with mode value of corresponding group.

# %%
df["gears"].replace("-", np.nan, inplace=True)

# %%
for group1 in df["make_model"].unique():
    for group2 in df["body_type"].unique():
        for group3 in df["gearbox"].unique():
            cond1 = df["make_model"] == group1
            cond2 = (df["make_model"] == group1) & (df["body_type"] == group2)
            cond3 = (df["make_model"] == group1) & (df["body_type"] == group2) & (df["gearbox"] == group3)
            mode1 = list(df[cond1]["gears"].mode())
            mode2 = list(df[cond2]["gears"].mode())
            mode3 = list(df[cond3]["gears"].mode())
            if mode3 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond3]["gears"].mode()[0])
            elif mode2 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond2]["gears"].mode()[0])
            elif mode1 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond1]["gears"].mode()[0])
            else:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df["gears"].mode()[0])

# %%
first_looking("gears")
# Out:
# COLUMN NAME    :  gears
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  8
# --------------------------------
# 6.00     975
# 8.00     467
# 5.00     283
# 9.00     273
# 7.00     214
# 1.00     131
# 10.00     19
# 4.00       2
# Name: gears, dtype: int64

# %%
df[df["gears"].isna()][["make_model", "body_type", "gearbox"]]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, gearbox]
# Index: []

# %%
first_looking("gearbox")
# Out:
# COLUMN NAME    :  gearbox
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Automatic    1287
# Manual       1077
# Name: gearbox, dtype: int64

# %%
df[df["fuel_type"]=="Electric"].gearbox.value_counts(dropna=False)
# Out:
# Series([], Name: gearbox, dtype: int64)

# %%
df["gearbox"].fillna("-", inplace=True)

# %%
df.groupby(["make_model", "body_type", "gearbox"]).price.describe()
# Out:
#                                                       count      mean  \
# make_model                body_type        gearbox
# Dacia Duster              Off-Road/Pick-Up Manual      5.00  18662.00
# Dacia Jogger              Station Wagon    Manual      4.00  23207.50
# Dacia Logan               Station Wagon    Manual      2.00  10990.00
# Dacia Sandero             Compact          Automatic   1.00  18990.00
#                                            Manual      3.00  17690.00
#                           Off-Road/Pick-Up Manual      1.00  10950.00
#                           Sedan            Manual      4.00  12247.50
# Fiat 124 Spider           Convertible      Manual      2.00  23470.00
# Fiat 500                  Compact          Automatic   1.00  14475.00
#                                            Manual      4.00  17856.00
#                           Off-Road/Pick-Up Automatic   1.00  29985.00
#                           Sedan            Manual      5.00  12285.80
# Fiat 500C                 Convertible      Automatic   1.00  19990.00
#                                            Manual     11.00  16182.82
# Fiat 500X                 Off-Road/Pick-Up Automatic   1.00  16990.00
#                                            Manual      1.00  15350.00
#                           Sedan            Manual      1.00  23990.00
# Fiat Punto                Compact          Manual      1.00   5799.00
# Fiat Tipo                 Sedan            Manual      4.00  17427.25
#                           Station Wagon    Automatic   1.00  31285.00
#                                            Manual      2.00  11730.00
# Ford Bronco               Off-Road/Pick-Up Automatic   1.00  47950.00
# Ford Ecosport             Compact          Manual      4.00  23865.00
# Ford Edge                 Off-Road/Pick-Up Automatic   4.00  34775.00
# Ford Explorer             Off-Road/Pick-Up Automatic   1.00  67990.00
# Ford Fiesta               Compact          Automatic   4.00  21255.00
#                                            Manual     32.00  15803.03
#                           Coupe            Manual      1.00  20740.00
#                           Sedan            Automatic   9.00  21363.33
#                                            Manual     34.00  15609.74
# Ford Focus                Coupe            Manual      2.00  26920.00
#                           Sedan            Automatic   6.00  28580.00
#                                            Manual     31.00  24826.26
#                           Station Wagon    Automatic  15.00  25704.27
#                                            Manual     45.00  21962.84
# Ford Grand C              Station Wagon    Manual      1.00  19290.00
# Ford Grand Tourneo        Station Wagon    Manual      1.00  25180.00
# Ford Kuga                 Off-Road/Pick-Up Automatic  15.00  34638.00
#                                            Manual     32.00  19055.81
#                           Station Wagon    Automatic   9.00  21451.78
#                                            Manual     31.00  19333.84
# Opel Cascada              Convertible      Automatic  11.00  27261.64
#                                            Manual     23.00  22598.87
# Opel Combo Life           Station Wagon    Automatic   1.00  32640.00
# Opel Corsa                Compact          Automatic   7.00  20284.14
#                                            Manual     72.00  14059.79
#                           Sedan            Automatic   4.00  22619.50
#                                            Manual      6.00  14782.17
# Opel Crossland            Off-Road/Pick-Up Automatic   1.00  32650.00
#                                            Manual      3.00  20426.67
# Opel Crossland X          Off-Road/Pick-Up Automatic   9.00  21628.44
#                                            Manual     39.00  19701.64
# Opel Grandland            Off-Road/Pick-Up Automatic  11.00  32384.09
#                                            Manual      4.00  22400.00
# Opel Grandland X          Off-Road/Pick-Up Automatic  44.00  28845.70
#                                            Manual     18.00  23123.89
# Opel Insignia             Coupe            Automatic   1.00  33990.00
#                           Sedan            Automatic  24.00  31291.96
#                                            Manual     11.00  21090.73
#                           Station Wagon    Automatic  43.00  33535.16
#                                            Manual     18.00  21445.78
# Opel Karl                 Compact          Manual      7.00  10226.29
#                           Sedan            Manual      5.00  11399.80
# Opel Mokka                Off-Road/Pick-Up Automatic   3.00  21130.00
#                                            Manual     16.00  17618.56
# Opel Mokka X              Off-Road/Pick-Up Automatic   2.00  15989.50
#                                            Manual     15.00  15545.60
# Opel Vectra               Sedan            Manual      1.00   4479.00
# Opel Vivaro               Station Wagon    Manual      1.00  23980.00
# Opel Zafira Life          Station Wagon    Manual      1.00  37490.00
# Peugeot 107               Sedan            Manual      1.00   4290.00
# Peugeot 108               Compact          Manual      2.00  13990.00
#                           Convertible      Manual      1.00  12990.00
#                           Sedan            Manual      4.00  12715.00
# Peugeot 2008              Off-Road/Pick-Up Automatic   3.00  29606.67
#                                            Manual      5.00  15460.00
#                           Sedan            Manual      1.00  11900.00
# Peugeot 207               Convertible      Manual      2.00  10215.00
# Peugeot 208               Compact          Automatic   3.00  27653.33
#                                            Manual      2.00  18690.00
#                           Sedan            Automatic   1.00  26490.00
#                                            Manual      1.00  13480.00
# Peugeot 3008              Off-Road/Pick-Up Automatic  10.00  32049.00
#                                            Manual      4.00  23090.00
# Peugeot 308               Compact          Manual      2.00  31990.00
#                           Sedan            Automatic   7.00  32062.86
#                                            Manual      7.00  17230.00
#                           Station Wagon    Automatic   6.00  32680.00
#                                            Manual      4.00  20787.50
# Peugeot 5008              Off-Road/Pick-Up Automatic   3.00  40786.67
#                                            Manual      2.00  23095.00
# Peugeot 508               Sedan            Automatic   2.00  31990.00
#                           Station Wagon    Automatic   6.00  42071.67
# Peugeot Rcz               Coupe            Manual      1.00  13360.00
# Renault Alaskan           Off-Road/Pick-Up Automatic   2.00  39240.00
# Renault Alpine A110       Coupe            Automatic   2.00  65339.50
# Renault Captur            Off-Road/Pick-Up Automatic   3.00  20768.33
#                                            Manual      4.00  13932.50
#                           Sedan            Manual      1.00  14690.00
# Renault Clio              Compact          Automatic   2.00  22570.00
#                                            Manual      9.00  17847.78
#                                            Manual      3.00  21771.67
#                           Station Wagon    Automatic  12.00  34846.67
#                                            Manual      2.00  24434.50
# Skoda Yeti                Off-Road/Pick-Up Manual      1.00  10930.00
# Toyota Auris              Sedan            Automatic   2.00  19120.00
#                                            Manual      3.00  11090.00
#                           Station Wagon    Automatic   3.00  18123.33
#                                            Manual      1.00  12490.00
# Toyota Avensis            Sedan            Manual      1.00  16390.00
#                           Station Wagon    Automatic   2.00  17739.50
#                                            Manual      6.00  14507.67
# Toyota Aygo               Compact          Manual     12.00   8785.83
#                           Sedan            Automatic   1.00  20880.00
# Toyota Aygo X             Compact          Automatic  12.00  17490.00
#                                            Manual     16.00  13924.25
#                           Sedan            Manual      3.00  18040.00
# Toyota C                  Coupe            Automatic   2.00  30640.00
#                           Off-Road/Pick-Up Automatic  24.00  28987.83
#                                            Manual      4.00  18104.75
# Toyota Corolla            Sedan            Automatic   9.00  24810.78
#                                            Manual      3.00  18093.33
#                           Station Wagon    Automatic  19.00  29734.89
#                                            Manual      1.00  19489.00
# Toyota Gt86               Coupe            Manual      2.00  23440.00
# Toyota Highlander         Off-Road/Pick-Up Automatic   1.00  64490.00
# Toyota Hilux              Off-Road/Pick-Up Automatic   5.00  55748.00
# Toyota Iq                 Compact          Automatic   1.00   8990.00
# Toyota Land Cruiser       Off-Road/Pick-Up Manual      1.00  33990.00
# Toyota Mirai              Sedan            Automatic   4.00  39764.75
# Toyota Prius              Sedan            Automatic   6.00  28321.50
# Toyota Proace             Off-Road/Pick-Up Manual      5.00  30586.00
#                           Station Wagon    Automatic   1.00  45990.00
# Toyota Rav                Off-Road/Pick-Up Automatic   1.00  46990.00
# Toyota Rav 4              Off-Road/Pick-Up Automatic   7.00  36041.14
#                                            Manual      4.00  24989.25
# Toyota Supra              Coupe            Automatic   1.00  51990.00
# Toyota Supra              Coupe            Automatic  10.00  55826.00
#                                            Manual      1.00  71990.00
# Toyota Verso              Station Wagon    Automatic   1.00   8490.00
# Toyota Yaris              Compact          Automatic  18.00  21819.67
#                                            Manual      9.00  14505.56
#                           Coupe            Manual      2.00  46214.50
#                           Sedan            Automatic  12.00  21981.67
#                                            Manual      7.00  17435.71
# Toyota Yaris Cross        Off-Road/Pick-Up Automatic   4.00  29440.00
# Volvo S60                 Sedan            Automatic   6.00  49075.00
# Volvo S80                 Sedan            Automatic   1.00  29990.00
# Volvo S90                 Sedan            Automatic   7.00  48934.29
# Volvo V40                 Sedan            Automatic   1.00  21990.00
#                                            Manual      3.00  18706.67
#                           Station Wagon    Automatic   2.00  22590.00
#                                            Manual      4.00  18464.50
# Volvo V60                 Station Wagon    Automatic  66.00  38220.27
#                                            Manual      4.00  20460.00
# Volvo V60 Cross Country   Station Wagon    Automatic   6.00  50800.00
#                                            Manual      2.00  21990.00
# Volvo V90                 Station Wagon    Automatic  38.00  47713.95
# Volvo V90 Cross Country   Station Wagon    Automatic  30.00  36462.00
# Volvo Xc40                Off-Road/Pick-Up Automatic  32.00  36382.44
#                                            Manual     12.00  29681.67
# Toyota Verso              Station Wagon    Automatic   8490.00   8490.00
# Toyota Yaris              Compact          Automatic  25302.50  28540.00
#                                            Manual     16990.00  26220.00
#                           Coupe            Manual     46846.75  47479.00
#                           Sedan            Automatic  24325.00  26500.00
#                                            Manual     16540.00  44950.00
# Toyota Yaris Cross        Off-Road/Pick-Up Automatic  31490.00  32990.00
# Volvo S60                 Sedan            Automatic  49740.00  59890.00
# Volvo S80                 Sedan            Automatic  29990.00  29990.00
# Volvo S90                 Sedan            Automatic  52395.00  67990.00
# Volvo V40                 Sedan            Automatic  21990.00  21990.00
#                                            Manual     19325.00  20990.00
#                           Station Wagon    Automatic  22590.00  22590.00
#                                            Manual     18949.00  18949.00
# Volvo V60                 Station Wagon    Automatic  41950.00  56350.00
#                                            Manual     22930.00  22930.00
# Volvo V60 Cross Country   Station Wagon    Automatic  62075.00  66890.00
#                                            Manual     21990.00  21990.00
# Volvo V90                 Station Wagon    Automatic  61155.00  73450.00
# Volvo V90 Cross Country   Station Wagon    Automatic  38305.00  43990.00
# Volvo Xc40                Off-Road/Pick-Up Automatic  37727.50  60790.00
#                                            Manual     30980.00  31980.00
# Volvo Xc60                Compact          Automatic  72940.00  72940.00
#                           Off-Road/Pick-Up Automatic  68990.00  83890.00
#                                            Manual     29470.00  33910.00
# Volvo Xc90                Off-Road/Pick-Up Automatic  84780.00  97450.00

# %% [markdown]
# The type of gearbox of cars changes by their make_models and body_types most of the time. So it's decided to fill missing values with mode value of corresponding group.

# %%
df["gearbox"] = df["gearbox"].replace('-', np.nan)

# %%
fill(df, "make_model", "body_type", "gearbox", "mode")
# Out:
# COLUMN NAME    :  gearbox
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# --------------------------------
# Automatic    1287
# Manual       1077
# Name: gearbox, dtype: int64

# %%
# This is the nested for loop where it's used in fill(df, group_col1, group_col2, col_name, method) DEF to be generalized for all data

for group1 in df["make_model"].unique():
    for group2 in df["body_type"].unique():
        for group3 in df["gearbox"].unique():
            cond1 = df["make_model"] == group1
            cond2 = (df["make_model"] == group1) & (df["body_type"] == group2)
            cond3 = (df["make_model"] == group1) & (df["body_type"] == group2) & (df["gearbox"] == group3)
            mode1 = list(df[cond1]["gears"].mode())
            mode2 = list(df[cond2]["gears"].mode())
            mode3 = list(df[cond3]["gears"].mode())
            if mode3 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond3]["gears"].mode()[0])
            elif mode2 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond2]["gears"].mode()[0])
            elif mode1 != []:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df[cond1]["gears"].mode()[0])
            else:
                df.loc[cond3, "gears"] = df.loc[cond3, "gears"].fillna(df["gears"].mode()[0])

# %%
first_looking("gears")
# Out:
# COLUMN NAME    :  gears
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  8
# --------------------------------
# 6.00     975
# 8.00     467
# 5.00     283
# 9.00     273
# 7.00     214
# 1.00     131
# 10.00     19
# 4.00       2
# Name: gears, dtype: int64

# %%
first_looking("fuel_type")
# Out:
# COLUMN NAME    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 6.51
# num_of_nulls   :  154
# num_of_uniques :  17
# --------------------------------
# Diesel (Particle filter)                    529
# Super 95                                    476
# Super E10 95                                395
# Regular/Benzine 91                          190
# Super E10 95 (Particle filter)              189
# Regular/Benzine 91 (Particle filter)        181
# NaN                                         154
# Super 95 (Particle filter)                  123
# Gasoline                                     32
# Diesel                                       31
# Super Plus 98                                30
# Super Plus E10 98                            13
# Regular/Benzine E10 91                       10
# Super Plus 98 (Particle filter)               4
# Regular/Benzine E10 91 (Particle filter)      3
# Super Plus E10 98 (Particle filter)           2
# Gasoline (Particle filter)                    1
# Hydrogen                                      1
# Name: fuel_type, dtype: int64

# %%
df["fuel_type"].fillna("-", inplace=True)

# %% [markdown]
# If we use the same transmission in both engines, the power to the wheels would be uneven and disproportionate as per the engine RPM and driving conditions. Hence we cannot couple the same manual transmission with both the engines.

# %%
# check if there is any pattern among ""make_model", "body_type", "gearbox", and "fuel_type" by "price"
df.groupby(["make_model", "body_type", "gearbox", "fuel_type"]).price.describe()
# Out:
#                                                                          count  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)         1.00
#                                          Super 95                         2.00
#                                          Super 95 (Particle filter)       1.00
#                                          Super E10 95                     1.00
# Dacia Jogger  Station Wagon    Manual    Super 95                         3.00
# ...                                                                        ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter)   2.00
#                                Manual    Diesel (Particle filter)         8.00
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)        18.00
#                                          Regular/Benzine 91               8.00
#                                          Super 95                         2.00
#
#                                                                             mean  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       15740.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       23693.33
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       24442.50
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       54628.33
#                                          Regular/Benzine 91             82709.75
#                                          Super 95                       76930.00
#
#                                                                              std  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)            NaN
#                                          Super 95                        1060.66
#                                          Super 95 (Particle filter)          NaN
#                                          Super E10 95                        NaN
# Dacia Jogger  Station Wagon    Manual    Super 95                        1173.47
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter)     0.00
#                                Manual    Diesel (Particle filter)        7342.62
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       21152.66
#                                          Regular/Benzine 91             15894.38
#                                          Super 95                           0.00
#
#                                                                              min  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       14990.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       22400.00
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       16990.00
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       29980.00
#                                          Regular/Benzine 91             64990.00
#                                          Super 95                       76930.00
#
#                                                                              25%  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       15365.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       23195.00
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       18407.50
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       43990.00
#                                          Regular/Benzine 91             69496.75
#                                          Super 95                       76930.00
#
#                                                                              50%  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       15740.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       23990.00
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       23435.00
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       45780.00
#                                          Regular/Benzine 91             84199.50
#                                          Super 95                       76930.00
#
#                                                                              75%  \
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       16115.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       24340.00
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       29470.00
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       63450.00
#                                          Regular/Benzine 91             97412.50
#                                          Super 95                       76930.00
#
#                                                                              max
# make_model    body_type        gearbox   fuel_type
# Dacia Duster  Off-Road/Pick-Up Manual    Diesel (Particle filter)       21690.00
#                                          Super 95                       16490.00
#                                          Super 95 (Particle filter)     18990.00
#                                          Super E10 95                   21150.00
# Dacia Jogger  Station Wagon    Manual    Super 95                       24690.00
# ...                                                                          ...
# Volvo Xc60    Off-Road/Pick-Up Automatic Super E10 95 (Particle filter) 51890.00
#                                Manual    Diesel (Particle filter)       33910.00
# Volvo Xc90    Off-Road/Pick-Up Automatic Diesel (Particle filter)       93890.00
#                                          Regular/Benzine 91             97450.00
#                                          Super 95                       76930.00
#
# [951 rows x 8 columns]

# %%
df["fuel_type"] = df["fuel_type"].replace('-', np.nan)

# %%
#Domain Knowledge demonstrates that the fuel type of cars might change by their make_models and gear_box most of the time. So it's decided to fill missing values with mode value of corresponding group.

# fills the missing values in the "fuel_type" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "gearbox", "fuel_type", "mode")
# Out:
# COLUMN NAME    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  17
# --------------------------------
# Diesel                                       32
# Diesel (Particle filter)                    577
# Gasoline                                     32
# Gasoline (Particle filter)                    1
# Hydrogen                                      4
# Regular/Benzine 91                          215
# Regular/Benzine 91 (Particle filter)        198
# Regular/Benzine E10 91                       10
# Regular/Benzine E10 91 (Particle filter)      3
# Super 95                                    528
# Super 95 (Particle filter)                  124
# Super E10 95                                402
# Super E10 95 (Particle filter)              189
# Super Plus 98                                30
# Super Plus 98 (Particle filter)               4
# Super Plus E10 98                            13
# Super Plus E10 98 (Particle filter)           2
# Name: fuel_type, dtype: int64

# %%
first_looking("seats")
# Out:
# COLUMN NAME    :  seats
# --------------------------------
# per_of_nulls   :  % 1.06
# num_of_nulls   :  25
# num_of_uniques :  8
# --------------------------------
# 5.00    1923
# 4.00     300
# 2.00      46
# 7.00      43
# NaN       25
# 8.00      12
# 3.00      11
# 9.00       3
# 0.00       1
# Name: seats, dtype: int64

# %%
#Domain Knowledge demonstrates that the number of seats of cars might change by their make_models and body_types most of the time. 
#So it's decided to fill missing values with mode value of corresponding group.

# # fills the missing values in the "seats" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "seats", "mode")
# Out:
# COLUMN NAME    :  seats
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  8
# --------------------------------
# 0.00       1
# 2.00      46
# 3.00      11
# 4.00     316
# 5.00    1932
# 7.00      43
# 8.00      12
# 9.00       3
# Name: seats, dtype: int64

# %%
first_looking("co_emissions")
# Out:
# COLUMN NAME    :  co_emissions
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  234
# --------------------------------
# 0.00      54
# 114.00    50
# 108.00    49
# 93.00     42
# 136.00    42
# 124.00    39
# 117.00    38
# 119.00    37
# 125.00    37
# 139.00    37
# 144.00    36
# 99.00     35
# 122.00    34
# 107.00    33
# 126.00    32
# 130.00    32
# 128.00    32
# 111.00    31
# 127.00    31
# 112.00    30
# 129.00    30
# 138.00    29
# 92.00     28
# 109.00    28
# 174.00    27
# 120.00    27
# 121.00    27
# 116.00    26
# 131.00    26
# 148.00    26
# 103.00    26
# 147.00    25
# 135.00    25
# 171.00    23
# 134.00    23
# 105.00    22
# 118.00    22
# 110.00    21
# 164.00    21
# 115.00    20
# 140.00    19
# 150.00    18
# 98.00     18
# 133.00    18
# 101.00    18
# 158.00    17
# 96.00     17
# 95.00     17
# 154.00    17
# 143.00    16
# 102.00    16
# 113.00    16
# 145.00    16
# 156.00    16
# 94.00     15
# 64.00     15
# 97.00     15
# 137.00    15
# 123.00    15
# 153.00    15
# 85.00     15
# 104.00    15
# 106.00    14
# 149.00    14
# 176.00    14
# 170.00    14
# 181.00    13
# 142.00    13
# 161.00    12
# 132.00    12
# 141.00    12
# 26.00     12
# 76.00     12
# 162.00    12
# 159.00    11
# 191.00    10
# 34.00     10
# 84.00     10
# 42.00     10
# 40.00     10
# 183.00    10
# 180.00    10
# 152.00    10
# 157.00    10
# 194.00     9
# 175.00     9
# 168.00     9
# 54.00      9
# 155.00     9
# 91.00      8
# 179.00     8
# 49.00      8
# 186.00     8
# 146.00     8
# 41.00      8
# 197.00     8
# 166.00     7
# 189.00     7
# 160.00     7
# 190.00     7
# 163.00     7
# 184.00     7
# 47.00      6
# 214.00     6
# 44.00      6
# 151.00     6
# 51.00      6
# 182.00     6
# 268.00     6
# 284.00     6
# 90.00      6
# 39.00      5
# 198.00     5
# 31.00      5
# 248.00     5
# 254.00     5
# 178.00     5
# 167.00     5
# 199.00     5
# 192.00     5
# 52.00      5
# 188.00     5
# 100.00     4
# 270.00     4
# 247.00     4
# 220.00     4
# 273.00     4
# 89.00      4
# 68.00      4
# 196.00     4
# 185.00     4
# 165.00     4
# 230.00     4
# 169.00     4
# 87.00      4
# 281.00     4
# 244.00     4
# 216.00     4
# 35.00      4
# 173.00     4
# 25.00      4
# 203.00     4
# 280.00     4
# 204.00     4
# 172.00     4
# 236.00     4
# 245.00     3
# 222.00     3
# 277.00     3
# 258.00     3
# 255.00     3
# 249.00     3
# 259.00     3
# 219.00     3
# 46.00      3
# 75.00      3
# 187.00     3
# 298.00     3
# 215.00     3
# 217.00     3
# 177.00     3
# 200.00     3
# 225.00     3
# 195.00     3
# 257.00     3
# 86.00      2
# 269.00     2
# 83.00      2
# 212.00     2
# 262.00     2
# 209.00     2
# 283.00     2
# 303.00     2
# 206.00     2
# 205.00     2
# 228.00     2
# 238.00     2
# 279.00     2
# 50.00      2
# 202.00     2
# 414.00     2
# 43.00      2
# 22.00      2
# 88.00      2
# 246.00     2
# 14.00      2
# 232.00     2
# 36.00      2
# 251.00     1
# 267.00     1
# 276.00     1
# 289.00     1
# 399.00     1
# 241.00     1
# 260.00     1
# 282.00     1
# 234.00     1
# 314.00     1
# 66.00      1
# 910.00     1
# 21.00      1
# 231.00     1
# 227.00     1
# 24.00      1
# 293.00     1
# 17.00      1
# 16.00      1
# 15.00      1
# 18.00      1
# 285.00     1
# 235.00     1
# 348.00     1
# 218.00     1
# 271.00     1
# 208.00     1
# 261.00     1
# 274.00     1
# 32.00      1
# 272.00     1
# 207.00     1
# 330.00     1
# 326.00     1
# 224.00     1
# 275.00     1
# 233.00     1
# 240.00     1
# 82.00      1
# 210.00     1
# 19.00      1
# 296.00     1
# 239.00     1
# 29.00      1
# 263.00     1
# 299.00     1
# Name: co_emissions, dtype: int64

# %%
# All NaN values are converted to dash/hyphen sign "-" to see them in the output of describe() and explore the hidden pattern

df["co_emissions"].fillna("-", inplace=True)

# %%
# let's explore if there is any pattern among ""make_model", "body_type", "fuel_type", and "co_emissions" by "price"

df.groupby(["make_model", "body_type", "fuel_type", "co_emissions"]).price.describe()
# Out:
#                                                                         count  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00         1.00
#                                Super 95                   138.00         1.00
#                                                           149.00         1.00
#                                Super 95 (Particle filter) 138.00         1.00
#                                Super E10 95               131.00         1.00
# ...                                                                       ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00         2.00
#                                Regular/Benzine 91         47.00          2.00
#                                                           50.00          2.00
#                                                           52.00          4.00
#                                Super 95                   47.00          2.00
#
#                                                                            mean  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97425.00
#                                Super 95                   47.00        76930.00
#
#                                                                          std  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00         NaN
#                                Super 95                   138.00         NaN
#                                                           149.00         NaN
#                                Super 95 (Particle filter) 138.00         NaN
#                                Super E10 95               131.00         NaN
# ...                                                                      ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00        0.00
#                                Regular/Benzine 91         47.00         0.00
#                                                           50.00         0.00
#                                                           52.00        28.87
#                                Super 95                   47.00         0.00
#
#                                                                             min  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97400.00
#                                Super 95                   47.00        76930.00
#
#                                                                             25%  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97400.00
#                                Super 95                   47.00        76930.00
#
#                                                                             50%  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97425.00
#                                Super 95                   47.00        76930.00
#
#                                                                             75%  \
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97450.00
#                                Super 95                   47.00        76930.00
#
#                                                                             max
# make_model    body_type        fuel_type                  co_emissions
# Dacia Duster  Off-Road/Pick-Up Diesel (Particle filter)   119.00       21690.00
#                                Super 95                   138.00       14990.00
#                                                           149.00       16490.00
#                                Super 95 (Particle filter) 138.00       18990.00
#                                Super E10 95               131.00       21150.00
# ...                                                                         ...
# Volvo Xc90    Off-Road/Pick-Up Diesel (Particle filter)   159.00       48880.00
#                                Regular/Benzine 91         47.00        70999.00
#                                                           50.00        64990.00
#                                                           52.00        97450.00
#                                Super 95                   47.00        76930.00
#
# [1571 rows x 8 columns]

# %% [markdown]
# It seems more sensible/rational to impute missing values in two stages:
#
# With the Mode value of Electric feature for Electric cars.
#
# With the Median values of related make_model, body_type and fuel_type features for the others.

# %%
# Let's replace dash/hyphen sign "-" with np.nan

df["co_emissions"].replace("-", np.nan, inplace=True)

# %%
# Let's explore CO Emission values of Electric Vehicles

df.loc[df["fuel_type"] == "Electric", "co_emissions"]
# Out:
# Series([], Name: co_emissions, dtype: float64)

# %%
# Let's see the occurances of unique CO Emission values for Electric Vehicles

df[df["fuel_type"] == "Electric"]["co_emissions"].value_counts(dropna=False)
# Out:
# Series([], Name: co_emissions, dtype: int64)

# %%
# Let's explore CO Emission values of Vehicles which run with Benzine

df[df["fuel_type"] == "Benzine"]["co_emissions"].value_counts(dropna=False)
# Out:
# Series([], Name: co_emissions, dtype: int64)

# %%
first_looking("cylinders")
# Out:
# COLUMN NAME    :  cylinders
# --------------------------------
# per_of_nulls   :  % 11.0
# num_of_nulls   :  260
# num_of_uniques :  7
# --------------------------------
# 4.00     1314
# 3.00      559
# NaN       260
# 6.00      126
# 8.00       89
# 5.00       10
# 2.00        5
# 12.00       1
# Name: cylinders, dtype: int64

# %%
# All NaN values are converted to dash/hyphen sign "-" to see them in the output of describe() and explore the hidden pattern

df["cylinders"].fillna("-", inplace=True)

# %%
# Let's replace dash/hyphen sign "-" with np.nan

df["cylinders"].replace("-", np.nan, inplace=True)

# %%
# fills the missing values in the "cylinders" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "cylinders", "mode")
# Out:
# COLUMN NAME    :  cylinders
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  7
# --------------------------------
# 2.00        6
# 3.00      651
# 4.00     1454
# 5.00       10
# 6.00      137
# 8.00      105
# 12.00       1
# Name: cylinders, dtype: int64

# %% [markdown]
# However, it is preferred to drop the cylinders feature in this analysis since there have been some other features, such as hp, engine_size, and empty_weight, having fewer missing values and giving similar insight. So it's assumed to continue without the cylinders feature in this analysis.

# %%
df.shape
# Out:
# (2364, 32)

# %%
df.drop("cylinders", axis=1, inplace=True)

# %%
df.shape
# Out:
# (2364, 31)

# %%
first_looking("drivetrain")
# Out:
# COLUMN NAME    :  drivetrain
# --------------------------------
# per_of_nulls   :  % 53.05
# num_of_nulls   :  1254
# num_of_uniques :  3
# --------------------------------
# NaN       1254
#  4WD       544
#  Front     508
#  Rear       58
# Name: drivetrain, dtype: int64

# %%
# All NaN values are converted to dash/hyphen sign "-" to see them in the output of describe() and explore the hidden pattern

df["drivetrain"].fillna("-", inplace=True)

# %%
#  explore if there is any pattern among "make_model", "body_type", and "drivetrain" by "price"

df.groupby(["make_model", "body_type", "drivetrain"]).price.describe()
# Out:
#                                                        count      mean  \
# make_model                body_type        drivetrain
# Dacia Duster              Off-Road/Pick-Up  4WD         1.00  21690.00
#                                             Front       3.00  16823.33
#                                            -            1.00  21150.00
# Dacia Jogger              Station Wagon    -            4.00  23207.50
# Dacia Logan               Station Wagon     Front       2.00  10990.00
# Dacia Sandero             Compact          -            4.00  18015.00
#                           Off-Road/Pick-Up -            1.00  10950.00
#                           Sedan             Front       1.00  10980.00
#                                            -            3.00  12670.00
# Fiat 124 Spider           Convertible       Rear        1.00  24980.00
#                                            -            1.00  21960.00
# Fiat 500                  Compact           Front       5.00  17179.80
#                           Off-Road/Pick-Up  Front       1.00  29985.00
#                           Sedan            -            5.00  12285.80
# Fiat 500C                 Convertible       Front       7.00  17601.86
#                                            -            5.00  14957.60
# Fiat 500X                 Off-Road/Pick-Up  4WD         1.00  16990.00
#                                             Front       1.00  15350.00
#                           Sedan             Front       1.00  23990.00
# Fiat Punto                Compact          -            1.00   5799.00
# Fiat Tipo                 Sedan            -            4.00  17427.25
#                           Station Wagon     Front       1.00  31285.00
#                                            -            2.00  11730.00
# Ford Bronco               Off-Road/Pick-Up  4WD         1.00  47950.00
# Ford Ecosport             Compact          -            4.00  23865.00
# Ford Edge                 Off-Road/Pick-Up  4WD         4.00  34775.00
# Ford Explorer             Off-Road/Pick-Up  4WD         1.00  67990.00
# Ford Fiesta               Compact           Front      14.00  18719.21
#                                            -           22.00  14938.55
#                           Coupe            -            1.00  20740.00
#                           Sedan             Front       6.00  12950.83
#                                            -           37.00  17440.43
# Ford Focus                Coupe            -            2.00  26920.00
#                           Sedan             4WD         1.00  39980.00
#                                             Front       6.00  24807.50
#                                            -           30.00  25075.63
#                           Station Wagon     Front      11.00  24217.55
#                                            -           49.00  22602.02
# Ford Grand C              Station Wagon    -            1.00  19290.00
# Ford Grand Tourneo        Station Wagon    -            1.00  25180.00
# Ford Kuga                 Off-Road/Pick-Up  4WD         9.00  26435.56
#                                             Front       5.00  31054.00
#                                            -           39.00  29176.36
# Ford Mondeo               Sedan            -            3.00  22653.33
#                           Station Wagon     4WD         2.00  36465.00
#                                             Front       3.00  25223.33
#                                            -           14.00  24514.93
# Ford Mustang              Convertible       Rear        4.00  66215.00
#                                            -            6.00  46416.33
# Renault R.S. Line         Off-Road/Pick-Up  Front       1.00  32710.00
# Renault Talisman          Sedan             Front       1.00  30490.00
#                           Station Wagon     Front       5.00  27168.00
# Renault Twingo            Compact           Rear        1.00  12990.00
#                           Convertible      -            1.00  10790.00
# Renault Zen               Off-Road/Pick-Up  Front       1.00  26450.00
# Seat Arona                Off-Road/Pick-Up  Front      12.00  19922.92
#                                            -            6.00  19980.00
# Seat Ateca                Off-Road/Pick-Up  4WD         6.00  33294.83
#                                             Front       6.00  29031.67
#                                            -            2.00  23950.00
# Seat Ibiza                Compact           Front       6.00  15226.67
#                                            -            1.00  19690.00
#                           Sedan             Front       8.00  16700.12
#                                            -            5.00  17668.00
#                           Station Wagon    -            1.00  10479.00
# Seat Leon                 Compact           Front       1.00  19490.00
#                           Coupe             Front       3.00  15621.67
#                                            -            1.00  14425.00
#                           Sedan             Front      11.00  24375.45
#                                            -            4.00  17362.50
#                           Station Wagon     4WD        12.00  31579.33
#                                             Front       8.00  25252.50
#                                            -            6.00  21031.50
# Seat Mii                  Compact           Front       1.00   8290.00
# Seat Tarraco              Off-Road/Pick-Up  4WD         5.00  36642.00
#                                             Front       1.00  28940.00
#                                            -            1.00  26990.00
# Skoda Citigo              Compact           Front       3.00   8946.67
#                                            -            2.00   8150.00
#                           Sedan             Front       3.00   9196.67
#                                            -            1.00   8989.00
# Skoda Fabia               Compact           Front      11.00  17432.27
#                                            -            4.00  12695.00
#                           Sedan             Front      12.00  18819.00
#                                            -            4.00  14680.00
#                           Station Wagon    -            3.00  15223.33
# Skoda Kamiq               Off-Road/Pick-Up  Front       3.00  22303.33
#                                            -            1.00  21590.00
# Skoda Karoq               Off-Road/Pick-Up  4WD         3.00  32130.00
#                                             Front       8.00  25887.50
#                                            -            8.00  27517.50
# Skoda Kodiaq              Off-Road/Pick-Up  4WD         9.00  46175.00
#                                             Front       1.00  31940.00
#                                            -            2.00  27850.00
# Skoda Octavia             Sedan            -            4.00  25405.00
#                           Station Wagon     4WD         1.00  26399.00
#                                             Front      11.00  31160.45
#                                            -            4.00  24237.00
# Skoda Rapid               Sedan             Front       1.00  11986.00
#                                            -            4.00  12937.50
#                           Station Wagon     Front       1.00  13230.00
# Skoda Scala               Sedan             Front       4.00  22066.00
#                                            -            4.00  25122.50
# Skoda Superb              Coupe            -            1.00  19880.00
#                           Sedan             Front       2.00  23762.50
#                                            -            4.00  25055.00
#                           Station Wagon     4WD         5.00  32372.00
#                                             Front       7.00  36614.29
#                                            -            2.00  24434.50
# Skoda Yeti                Off-Road/Pick-Up  4WD         1.00  10930.00
# Toyota Auris              Sedan            -            5.00  14302.00
#                           Station Wagon    -            4.00  16715.00
# Toyota Avensis            Sedan            -            1.00  16390.00
#                           Station Wagon     Front       1.00  11990.00
#                                            -            7.00  15790.71
# Toyota Aygo               Compact           Front       1.00  13590.00
#                                            -           11.00   8349.09
#                           Sedan             Front       1.00  20880.00
# Toyota Aygo X             Compact          -           28.00  15452.43
#                           Sedan            -            3.00  18040.00
# Toyota Proace             Off-Road/Pick-Up  Front      32530.00  32530.00
#                           Station Wagon    -           45990.00  45990.00
# Toyota Rav                Off-Road/Pick-Up  4WD        46990.00  46990.00
# Toyota Rav 4              Off-Road/Pick-Up  4WD        49330.00  53350.00
#                                            -           30490.00  36989.00
# Toyota Supra              Coupe            -           51990.00  51990.00
# Toyota Supra              Coupe             Rear       59900.00  71990.00
#                                            -           62015.00  65690.00
# Toyota Verso              Station Wagon    -            8490.00   8490.00
# Toyota Yaris              Compact           Front      17460.00  17980.00
#                                            -           23990.00  28540.00
#                           Coupe             4WD        46846.75  47479.00
#                           Sedan             4WD        44950.00  44950.00
#                                             Front      21925.00  23950.00
#                                            -           24220.00  26500.00
# Toyota Yaris Cross        Off-Road/Pick-Up  4WD        32990.00  32990.00
#                                            -           29040.00  30990.00
# Volvo S60                 Sedan             4WD        59890.00  59890.00
#                                             Front      48990.00  49990.00
# Volvo S80                 Sedan             4WD        29990.00  29990.00
# Volvo S90                 Sedan             4WD        52900.00  67990.00
#                                             Front      33980.00  33980.00
#                                            -           37900.00  37900.00
# Volvo V40                 Sedan             Front      19325.00  20990.00
#                                            -           21990.00  21990.00
#                           Station Wagon     Front      22590.00  22590.00
#                                            -           18949.00  18949.00
# Volvo V60                 Station Wagon     4WD        46880.00  54990.00
#                                             Front      35950.00  56350.00
#                                            -           37157.50  41950.00
# Volvo V60 Cross Country   Station Wagon     4WD        62075.00  66890.00
#                                            -           21990.00  21990.00
# Volvo V90                 Station Wagon     4WD        63450.00  73450.00
#                                             Front      35270.00  35270.00
#                                            -           37105.00  38950.00
# Volvo V90 Cross Country   Station Wagon     4WD        38305.00  43990.00
# Volvo Xc40                Off-Road/Pick-Up  4WD        36092.50  36490.00
#                                             Front      35020.00  47330.00
#                                            -           35490.00  60790.00
# Volvo Xc60                Compact           4WD        72940.00  72940.00
#                           Off-Road/Pick-Up  4WD        69890.00  83890.00
#                                             Front      38720.00  39480.00
#                                            -           33910.00  34979.00
# Volvo Xc90                Off-Road/Pick-Up  4WD        84780.00  97450.00

# %% [markdown]
# Domain Knowledge demonstrates that the drivetrain of cars changes by their make_models and body_types most of the time. So it's decided to fill missing values with mode value of corresponding group.

# %%
df[df["body_type"] == "Off-Road/Pick-up"][["make_model", "body_type", "fuel_type", "drivetrain"]].value_counts()
# Out:
# Series([], dtype: int64)

# %%
# replace dash/hyphen sign "-" with np.nan

df["drivetrain"] = df["drivetrain"].replace('-', np.nan)

# %%
# fills the missing values in the "drivetrain" with the median value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "drivetrain", "mode")
# Out:
# COLUMN NAME    :  drivetrain
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  3
# --------------------------------
#  4WD       845
#  Front    1362
#  Rear      157
# Name: drivetrain, dtype: int64

# %%
first_looking("empty_weight")
# Out:
# COLUMN NAME    :  empty_weight
# --------------------------------
# per_of_nulls   :  % 7.83
# num_of_nulls   :  185
# num_of_uniques :  587
# --------------------------------
# NaN        185
# 1280.00     39
# 1165.00     35
# 1733.00     35
# 1055.00     29
#           ...
# 1511.00      1
# 1439.00      1
# 1792.00      1
# 1992.00      1
# 1819.00      1
# Name: empty_weight, Length: 588, dtype: int64

# %%
# All NaN values are converted to dash/hyphen sign "-" to see them in the output of describe() and explore the hidden pattern

df["empty_weight"].fillna("-", inplace=True)

# %%
# explore if there is any pattern among "make_model", "body_type", and "empty_weight" by "price"

df.groupby(["make_model", "body_type", "empty_weight"]).price.describe()
# Out:
#                                              count     mean      std      min  \
# make_model    body_type        empty_weight
# Dacia Duster  Off-Road/Pick-Up 1254.00        1.00 16490.00      NaN 16490.00
#                                1275.00        1.00 14990.00      NaN 14990.00
#                                1309.00        1.00 18990.00      NaN 18990.00
#                                1317.00        1.00 21150.00      NaN 21150.00
#                                1480.00        1.00 21690.00      NaN 21690.00
# ...                                            ...      ...      ...      ...
# Volvo Xc90    Off-Road/Pick-Up 2327.00        2.00 97400.00     0.00 97400.00
#                                2328.00        4.00 84224.50 15271.49 70999.00
#                                2329.00        2.00 64990.00     0.00 64990.00
#                                2339.00        2.00 93890.00     0.00 93890.00
#                                2395.00        2.00 76930.00     0.00 76930.00
#
#                                                  25%      50%      75%  \
# make_model    body_type        empty_weight
# Dacia Duster  Off-Road/Pick-Up 1254.00      16490.00 16490.00 16490.00
#                                1275.00      14990.00 14990.00 14990.00
#                                1309.00      18990.00 18990.00 18990.00
#                                1317.00      21150.00 21150.00 21150.00
#                                1480.00      21690.00 21690.00 21690.00
# ...                                              ...      ...      ...
# Volvo Xc90    Off-Road/Pick-Up 2327.00      97400.00 97400.00 97400.00
#                                2328.00      70999.00 84224.50 97450.00
#                                2329.00      64990.00 64990.00 64990.00
#                                2339.00      93890.00 93890.00 93890.00
#                                2395.00      76930.00 76930.00 76930.00
#
#                                                  max
# make_model    body_type        empty_weight
# Dacia Duster  Off-Road/Pick-Up 1254.00      16490.00
#                                1275.00      14990.00
#                                1309.00      18990.00
#                                1317.00      21150.00
#                                1480.00      21690.00
# ...                                              ...
# Volvo Xc90    Off-Road/Pick-Up 2327.00      97400.00
#                                2328.00      97450.00
#                                2329.00      64990.00
#                                2339.00      93890.00
#                                2395.00      76930.00
#
# [1172 rows x 8 columns]

# %% [markdown]
# Domain Knowledge demonstrates that the empty weight of cars changes by their make_models and body_types most of the time. So it's decided to fill missing values with mode value of corresponding group.

# %%
# Let's replace dash/hyphen sign "-" with np.nan

df["empty_weight"].replace("-", np.nan, inplace=True)

# %%
# fills the missing values in the "drivetrain" with the mode value based on "make_model", "body_type", and "empty_weight"

fill(df, "make_model", "body_type", "empty_weight", "mode")
# Out:
# COLUMN NAME    :  empty_weight
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  587
# --------------------------------
# 865.00     2
# 884.00     1
# 915.00     6
# 926.00     4
# 928.00     1
#           ..
# 2513.00    1
# 2530.00    1
# 2560.00    2
# 2612.00    1
# 2690.00    1
# Name: empty_weight, Length: 587, dtype: int64

# %%
first_looking("comfort_&_convenience")
# Out:
# COLUMN NAME    :  comfort_&_convenience
# --------------------------------
# per_of_nulls   :  % 0.13
# num_of_nulls   :  3
# num_of_uniques :  1735
# --------------------------------
# ['Air conditioning, Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows']                                                                                                                                                                                 12
# ['Air conditioning, Electrical side mirrors, Hill Holder, Leather steering wheel, Multi-function steering wheel, Power windows, Split rear seats, Tinted windows']                                                                                                                                                                                                                                                                                                                                                                                                                                                                           11
# ['Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Tinted windows']                                                                                                                                             11
# ['Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Electrically heated windshield, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows']                                                                                          11
# ['Air conditioning, Armrest, Automatic climate control, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heads-up display, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows']                                                    11
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ..
# ['Air conditioning, Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Electrically heated windshield, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Split rear seats, Start-stop system, Tinted windows']                                                                                                                                                                     1
# ['Air conditioning, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Start-stop system, Tinted windows']                                                                                                                                                                                                                                                                                  1
# ['Air conditioning, Armrest, Cruise control, Electrical side mirrors, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Multi-function steering wheel, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating']                                                                                                                                                                                                                                                                                                                                                                                 1
# ['360° camera, Air conditioning, Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heads-up display, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Sunroof, Tinted windows']     1
# ['Air conditioning, Armrest, Automatic climate control, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Panorama roof, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system, Sunroof']                                                                                        1
# Name: comfort_&_convenience, Length: 1736, dtype: int64

# %%
# fills the missing values in the "comfort_&_convenience" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "comfort_&_convenience", "mode")
# Out:
# COLUMN NAME    :  comfort_&_convenience
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1735
# --------------------------------
# ['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, 2 zones, Auxiliary heating, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Heads-up display, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Panorama roof, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Sunroof, Tinted windows']    1
# ['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, 2 zones, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heads-up display, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Panorama roof, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Sunroof, Tinted windows']                            1
# ['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, 2 zones, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heads-up display, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Tinted windows']                                                    1
# ['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heads-up display, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Tinted windows']                                  1
# ['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heated steering wheel, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Tinted windows']                                                    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# ['Electrical side mirrors, Fold flat passenger seat, Hill Holder, Lumbar support, Parking assist system sensors rear, Power windows, Sliding door right, Start-stop system, Tinted windows']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# ['Electrical side mirrors, Fold flat passenger seat, Hill Holder, Lumbar support, Power windows, Sliding door right, Start-stop system, Tinted windows']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3
# ['Electrical side mirrors, Hill Holder, Leather steering wheel, Multi-function steering wheel, Power windows, Split rear seats']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# ['Electrical side mirrors, Hill Holder, Multi-function steering wheel, Power windows, Split rear seats']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# ['Hill Holder, Power windows, Split rear seats, Tinted windows']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Name: comfort_&_convenience, Length: 1735, dtype: int64

# %%
df['comfort_&_convenience'].unique()
# Out:
# array(["['360° camera, Air conditioning, Air suspension, Armrest, Automatic climate control, Auxiliary heating, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Heads-up display, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Massage seats, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Split rear seats, Start-stop system, Wind deflector']",
#        "['Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Electrically adjustable seats, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Start-stop system, Wind deflector']",
#        "['Armrest, Automatic climate control, 2 zones, Cruise control, Electrical side mirrors, Electrically adjustable seats, Heads-up display, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system self-steering, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Seat ventilation, Start-stop system, Wind deflector']",
#        ...,
#        "['Air conditioning, Armrest, Automatic climate control, Auxiliary heating, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Heads-up display, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system, Sunroof']",
#        "['Air conditioning, Armrest, Automatic climate control, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Hill Holder, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Parking assist system camera, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system, Tinted windows']",
#        "['Air conditioning, Armrest, Automatic climate control, Cruise control, Electric tailgate, Electrical side mirrors, Electrically adjustable seats, Electrically heated windshield, Heated steering wheel, Hill Holder, Keyless central door lock, Leather steering wheel, Light sensor, Lumbar support, Multi-function steering wheel, Navigation system, Panorama roof, Parking assist system camera, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Seat heating, Start-stop system, Sunroof']"],
#       dtype=object)

# %%
premium = ["Electrical side mirrors", "Parking assist", "Air conditioning", "Hill Holder", "Power windows"]
premium_plus = ["Multi-function", "Navigation ", "Keyless central door lock", "Heads-up", "Massage seats", "heating", "Automatic climate control", "Heated"]

comfort_package = df['comfort_&_convenience'].apply(lambda sentence: "Premium Plus" if all(word in sentence for word in premium_plus) else ("Premium" if all(word in sentence for word in premium) else "Standard"))
comfort_package.value_counts()
# Out:
# Premium         1613
# Standard         726
# Premium Plus      25
# Name: comfort_&_convenience, dtype: int64

# %% [markdown]
# Let us assign each car to related "Comfort & Conveniance Packages" defined above

# %%
premium = ["Electrical side mirrors", "Parking assist", "Air conditioning", "Hill Holder", "Power windows"]
premium_plus = ["Multi-function", "Navigation ", "Keyless central door lock", "Heads-up", "Massage seats", "heating", "Automatic climate control", "Heated"]

df['comfort_&_convenience_Package'] = df['comfort_&_convenience'].apply(lambda sentence: "Premium Plus" if all(word in sentence for word in premium_plus) else ("Premium" if all(word in sentence for word in premium) else "Standard"))
df
# Out:
#                  make_model           make    model  \
# 0      Mercedes-Benz E 400   Mercedes-Benz   E 400
# 1     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 2      Mercedes-Benz C 400   Mercedes-Benz   C 400
# 3     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 4     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# ...                     ...            ...      ...
# 2359             Volvo S60           Volvo     S60
# 2360             Volvo S90           Volvo     S90
# 2361             Volvo S90           Volvo     S90
# 2362             Volvo S60           Volvo     S60
# 2363             Volvo S60           Volvo     S60
#
#                                           location     price    body_type  \
# 0         Julius-Rütgers-Str. 1,  15537 Erkner, DE  64870.00  Convertible
# 1        Wormser Landstraße 194,  67346 Speyer, DE 197500.00  Convertible
# 2             Autofocus 3,  15517 Fürstenwalde, DE  63370.00  Convertible
# 3     Meckenheimer Straße 12,  53359 Rheinbach, DE 175000.00  Convertible
# 4      St.-Georgener-Straße 1,  79111 Freiburg, DE 149890.00  Convertible
# ...                                            ...       ...          ...
# 2359         Lagerstraße 12,  93055 Regensburg, DE  44990.00        Sedan
# 2360         Lagerstraße 12,  93055 Regensburg, DE  67990.00        Sedan
# 2361     Cannstatter Str. 46,  70190 Stuttgart, DE  37900.00        Sedan
# 2362         Lagerstraße 12,  93055 Regensburg, DE  46890.00        Sedan
# 2363     Hannöversche Str. 44,  44143 Dortmund, DE  43700.00        Sedan
#
#                  type  doors warranty  mileage first_registration    gearbox  \
# 0                Used   2.00      24  78473.00            01/2020  Automatic
# 1      Employee's car   2.00       0   9550.00            04/2021  Automatic
# 2      Employee's car   2.00      24  20145.00            01/2021  Automatic
# 3                Used   2.00      24   3561.00            07/2021  Automatic
# 4                Used   3.00      Yes 23851.00            12/2019  Automatic
# ...               ...    ...      ...      ...                ...        ...
# 2359             Used   4.00      12  10500.00            06/2021  Automatic
# 2360    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2361             Used   4.00      12  37846.00            04/2019  Automatic
# 2362    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2363    Demonstration   4.00      24  13500.00            09/2021  Automatic
#
#                            fuel_type  seller  seats  engine_size  gears  \
# 0           Diesel (Particle filter)  Dealer   4.00      2925.00   9.00
# 1                           Super 95  Dealer   2.00      3982.00   7.00
# 2                           Super 95  Dealer   4.00      2996.00   9.00
# 3                           Super 95  Dealer   2.00      3982.00   7.00
# 4     Super E10 95 (Particle filter)  Dealer   2.00      3982.00   7.00
# ...                              ...     ...    ...          ...    ...
# 2359                        Super 95  Dealer   5.00      1969.00   8.00
# 2360        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2361        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2362                        Super 95  Dealer   5.00      1969.00   8.00
# 2363      Super 95 (Particle filter)  Dealer   5.00      1969.00   8.00
#
#       co_emissions drivetrain  \
# 0           162.00        4WD
# 1           298.00       Rear
# 2           196.00        4WD
# 3           296.00       Rear
# 4           262.00       Rear
# ...            ...        ...
# 2359        140.00      Front
# 2360        128.00        4WD
# 2361        121.00        4WD
# 2362        145.00      Front
# 2363        145.00      Front
#
#                                   comfort_&_convenience  \
# 0     ['360° camera, Air conditioning, Air suspensio...
# 1     ['Air conditioning, Armrest, Automatic climate...
# 2     ['Armrest, Automatic climate control, 2 zones,...
# 3     ['Air conditioning, Armrest, Automatic climate...
# 4     ['Air conditioning, Armrest, Automatic climate...
# ...                                                 ...
# 2359  ['Air conditioning, Automatic climate control,...
# 2360  ['Air conditioning, Armrest, Automatic climate...
# 2361  ['Air conditioning, Armrest, Automatic climate...
# 2362  ['Air conditioning, Armrest, Automatic climate...
# 2363  ['Air conditioning, Armrest, Automatic climate...
#
#                                   entertainment_&_media  \
# 0     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 1     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 3     ['Android Auto, Apple CarPlay, Digital radio, ...
# 4     ['Apple CarPlay, Bluetooth, Digital radio, Han...
# ...                                                 ...
# 2359  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2360  ['Bluetooth, Digital cockpit, Digital radio, H...
# 2361  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2362  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2363  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
#
#                                       safety_&_security  \
# 0     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 1     ['ABS, Adaptive Cruise Control, Alarm system, ...
# 2     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 3     ['ABS, Blind spot monitor, Central door lock, ...
# 4     ['ABS, Adaptive Cruise Control, Alarm system, ...
# ...                                                 ...
# 2359  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2360  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2361  ['ABS, Adaptive Cruise Control, Blind spot mon...
# 2362  ['ABS, Adaptive headlights, Bi-Xenon headlight...
# 2363  ['ABS, Adaptive Cruise Control, Adaptive headl...
#
#                                                  extras  empty_weight  \
# 0     Alloy wheels, Ambient lighting, Automatically ...       2010.00
# 1     Alloy wheels, Ambient lighting, Automatically ...       1735.00
# 2     Alloy wheels, Ambient lighting, Automatically ...       1825.00
# 3     Alloy wheels, Automatically dimming interior m...       1700.00
# 4     Alloy wheels (20"), Ambient lighting, Automati...       1700.00
# ...                                                 ...           ...
# 2359  Alloy wheels, Sport seats, Sport suspension, T...       1752.00
# 2360  Alloy wheels, Sport seats, Touch screen, Voice...       1790.00
# 2361  Alloy wheels (19"), Ambient lighting, Automati...       1866.00
# 2362  Sport seats, Sport suspension, Touch screen, V...       1799.00
# 2363  Alloy wheels, Catalytic Converter, Sport packa...       1819.00
#
#      full_service_history    upholstery  production_date  previous_owner  \
# 0                     Yes           NaN          2020.00            1.00
# 1                     Yes           NaN          2021.00            1.00
# 2                     Yes           NaN          2021.00            1.00
# 3                      No           NaN          2021.00            1.00
# 4                     Yes  Full leather          2019.00            2.00
# ...                   ...           ...              ...             ...
# 2359                  Yes  Part leather          2021.00            1.00
# 2360                   No  Full leather          2021.00            1.00
# 2361                  Yes  Part leather          2019.00            2.00
# 2362                   No  Part leather          2021.00            1.00
# 2363                  Yes  Part leather          2021.00            1.00
#
#      energy_efficiency_class                   new  combined_fuel_cons  \
# 0                  efficient   Mercedes-Benz E 400                6.20
# 1                unefficient  Mercedes-Benz AMG GT               13.00
# 2                unefficient   Mercedes-Benz C 400                8.60
# 3                unefficient  Mercedes-Benz AMG GT               12.90
# 4                unefficient  Mercedes-Benz AMG GT               11.50
# ...                      ...                   ...                 ...
# 2359               efficient             Volvo S60                6.20
# 2360               efficient             Volvo S90                4.90
# 2361               efficient             Volvo S90                4.60
# 2362               efficient             Volvo S60                6.30
# 2363               efficient             Volvo S60                6.30
#
#      comfort_&_convenience_Package
# 0                          Premium
# 1                          Premium
# 2                         Standard
# 3                         Standard
# 4                          Premium
# ...                            ...
# 2359                       Premium
# 2360                       Premium
# 2361                       Premium
# 2362                       Premium
# 2363                       Premium
#
# [2364 rows x 32 columns]

# %%
df['comfort_&_convenience_Package'].value_counts(dropna=False)
# Out:
# Premium         1613
# Standard         726
# Premium Plus      25
# Name: comfort_&_convenience_Package, dtype: int64

# %%
df.shape
# Out:
# (2364, 32)

# %%
# There is no need for old 'comfort_&_convenience' since a new feature of 'comfort_&_convenience_Package' is created

df.drop("comfort_&_convenience", axis=1, inplace=True)

# %%
df.shape
# Out:
# (2364, 31)

# %%
first_looking("entertainment_&_media")
# Out:
# COLUMN NAME    :  entertainment_&_media
# --------------------------------
# per_of_nulls   :  % 0.21
# num_of_nulls   :  5
# num_of_uniques :  433
# --------------------------------
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                        139
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                    104
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                      71
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                          52
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                     52
# ['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                      47
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                        47
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                    43
# ['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                          41
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                     40
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                           40
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                             39
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                      37
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                           36
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                  35
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                    31
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                                 29
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                       29
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                       27
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                                                      27
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                  25
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                     24
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                      23
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                        18
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                              18
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                           17
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                          17
# ['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                                                           16
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                            15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                    15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                      15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                     15
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                          14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                     14
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                          14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                      14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                          14
# ['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                  13
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                           13
# ['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                                       13
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                            12
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                              12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                         12
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                        12
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                   12
# ['CD player, MP3, On-board computer, Radio']                                                                                                                                                                                                            12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                 12
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                                                           12
# ['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                            12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']                                                                                        12
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                             11
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                             11
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                         11
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                10
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                    10
# ['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                                           10
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                         10
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                         10
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                 10
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                         10
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                       9
# ['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                                          9
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                              9
# ['Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                    9
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                           9
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                                  8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                       8
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                  8
# ['Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                         8
# ['On-board computer']                                                                                                                                                                                                                                    8
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                    8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                   7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                      7
# ['CD player, MP3, On-board computer, Radio, USB']                                                                                                                                                                                                        7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                    7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                        7
# ['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                     7
# ['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                         7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                         7
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                       6
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                        6
# ['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                                                               6
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                                    6
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                                        6
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                 6
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                    6
# ['On-board computer, Radio']                                                                                                                                                                                                                             6
# ['Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio']                                                                                                                                                                                 6
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                                         6
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                 6
# ['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                        6
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                     6
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                     6
# ['Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                          6
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                          5
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                         5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                   5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                              5
# NaN                                                                                                                                                                                                                                                      5
# ['Bluetooth, Digital radio, Hands-free equipment, Sound system, USB']                                                                                                                                                                                    5
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                        5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                             5
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                     5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system']                                                                                                                                  5
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                                                  5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                     4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                  4
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                                                                       4
# ['Android Auto, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                         4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB']                                                                           4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                               4
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                               4
# ['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                          4
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                             4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                                 4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, USB']                                                            4
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                                              4
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                       4
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                              4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                           4
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                                             4
# ['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                                                                4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                    4
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                                                                                      3
# ['Digital radio, On-board computer, Radio']                                                                                                                                                                                                              3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                            3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                           3
# ['Digital radio']                                                                                                                                                                                                                                        3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                          3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                          3
# ['Digital radio, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                                        3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB']                                                                                3
# ['Bluetooth, Digital radio, Hands-free equipment, On-board computer, USB']                                                                                                                                                                               3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                                    3
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                            3
# ['Digital cockpit, Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                               3
# ['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                        3
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                                  3
# ['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                    3
# ['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio']                                                                                                                                                                                 3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']                                                                                                3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                    3
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                   3
# ['On-board computer, Radio, USB']                                                                                                                                                                                                                        3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                3
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                      3
# ['Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                   3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                         3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']       3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']                                                             3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']                                                                                      3
# ['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                  3
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                                                              3
# ['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                 3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                       3
# ['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                           3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                             3
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Television, USB']                                                                                                                                          3
# ['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                                         2
# ['On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                                                                                                                        2
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                         2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']      2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                  2
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                                                2
# ['Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                           2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                              2
# ['CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                                         2
# ['Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                              2
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, USB, WLAN / WiFi hotspot']                                                                                                        2
# ['Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                       2
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio']                                                                                                                                                               2
# ['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                 2
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                  2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                             2
# ['Bluetooth, Digital radio, On-board computer, Radio']                                                                                                                                                                                                   2
# ['Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                                   2
# ['Bluetooth, CD player, MP3, On-board computer, Radio, USB']                                                                                                                                                                                             2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                2
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                                         2
# ['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                                     2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                    2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                            2
# ['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                   2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                                                         2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                            2
# ...
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system']                                                                                            1
# ['Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio']                                                                                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                            1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, USB']                                                                                                                                                         1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, USB']                                                                                                                                               1
# ['Digital cockpit, Induction charging for smartphones, MP3, USB']                                                                                                                                                                                        1
# ['Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                             1
# ['Digital radio, Hands-free equipment, On-board computer, Radio']                                                                                                                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, MP3, On-board computer, Radio, USB']                                                                                                                                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, USB']                                                                                                                                            1
# ['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                   1
# ['Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                          1
# ['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                      1
# ['Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                         1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                                                       1
# ['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, USB']                                                                                                                                                                         1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                       1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                      1
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                                                      1
# ['Apple CarPlay, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                                                                         1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer']                                                                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                           1
# ['CD player, MP3, Radio']                                                                                                                                                                                                                                1
# ['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']                                                                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                             1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, USB']                                                                                                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                   1
# ['CD player']                                                                                                                                                                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']                                                                                                       1
# ['Bluetooth, CD player, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                                               1
# ['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                      1
# ['Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                                        1
# ['Bluetooth, Integrated music streaming, On-board computer, USB']                                                                                                                                                                                        1
# ['Digital radio, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']                                                                                                               1
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                                                             1
# ['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                                                                       1
# ['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']                                                                                                                      1
# ['CD player, Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, USB']                                                                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio']                                                                                1
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Sound system, USB']                                                                                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                             1
# ['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                                               1
# ['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, Sound system, USB']                                                                                                                                                                    1
# ['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Sound system, USB']                                                                                                                                                                 1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                    1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                1
# ['Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                     1
# ['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, USB']                                                                                                                                                                          1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                 1
# ['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                               1
# Name: entertainment_&_media, dtype: int64

# %%
# fills the missing values in the "entertainment_&_media" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "entertainment_&_media", "mode")
# Out:
# COLUMN NAME    :  entertainment_&_media
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  433
# --------------------------------
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                            2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']       3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                     1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']                                                               2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                           3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                               10
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                           13
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                       4
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                            2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                          3
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                             1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                            2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                       1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                             1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system']                                                                                         2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                          14
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                              2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, USB']                                                                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                        1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                         1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                       9
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                 6
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                              12
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                          5
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                            15
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                          17
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                  2
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                             11
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                         5
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                                       1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']                                                                    1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                         10
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                                               1
# ['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                               1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']      2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                      15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                  8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                     4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                              5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, USB']                                                            4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']           1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                            2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                      23
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB']                                                          1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                    10
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                             39
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                            2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']                                                                          2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, USB']                                                                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                  25
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']                                                                                      3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                 2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']                                          1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                          14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                     15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                        18
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                    7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']                                                                                  4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']                                                                                                3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system']                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                           9
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                              9
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                         3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                            3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                      71
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                 10
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                    31
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                         12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                                        6
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, USB']                                                                                                                                               1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer']                                                                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system']                                                                                                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                           17
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                      14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                          3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']                                                             3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']                                                                                              2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                         7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                       3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system']                                                                                                                                  5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                      2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                    2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system']                                                                                            1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                  2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                        7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                             2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                     14
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                 2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                    3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']                                                                                                                                         6
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                           4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                      7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                    4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                       29
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                   5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                     40
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                10
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio']                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                             5
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB']                                                                           4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']                                                                                    3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                               4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                                  8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                             3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, USB']                                                                                                         2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']                                                                                        12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']                                                                                                       1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                 12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, USB']                                                                                                              2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']                                                                                                               1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB']                                                                                3
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                           40
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                       8
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                        140
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                    15
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                                 4
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                            2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                              18
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                         11
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, Radio, Sound system, USB']                                                                                                                    1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                           1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                             1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                       27
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                   7
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                    104
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, Radio, USB']                                                                                                                                                         2
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio']                                                                                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                            12
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                        1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                          53
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                     24
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, USB']                                                                                                                                                  1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, MP3, On-board computer, Radio, Sound system']                                                                                                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, On-board computer, Radio, Sound system, USB']                                                                                                                                                   1
# ['Android Auto, Apple CarPlay, Bluetooth, Digital radio, On-board computer, Radio, USB']                                                                                                                                                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                  2
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                     5
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']                                                                                                                 1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                   2
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                      1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, USB, WLAN / WiFi hotspot']                                                                                                        2
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']                                                                                                                              1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                          14
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                      3
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                        47
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                   12
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']                                                                                                                1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']                                                                                                                              4
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                         1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, USB']                                                                                                                                     1
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                       6
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                    43
# ['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                2
# ...
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                   3
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Television, USB']                                                                                                                                          3
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                     52
# ['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                 6
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio']                                                                                                                                                                                       4
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                                    6
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                                               2
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                                 29
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                                             4
# ['Bluetooth, Hands-free equipment, MP3, On-board computer, USB']                                                                                                                                                                                         2
# ['Bluetooth, Hands-free equipment, On-board computer, Radio']                                                                                                                                                                                            1
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system']                                                                                                                                                                              1
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB']                                                                                                                                                                         2
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']                                                                                                                                                    1
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                                                                                                         1
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, USB']                                                                                                                                                                                      27
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']                                                                                                                                                                  5
# ['Bluetooth, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                                                                                       1
# ['Bluetooth, Hands-free equipment, On-board computer, USB']                                                                                                                                                                                              1
# ['Bluetooth, Hands-free equipment, USB']                                                                                                                                                                                                                 1
# ['Bluetooth, Integrated music streaming, On-board computer, USB']                                                                                                                                                                                        1
# ['Bluetooth, MP3, On-board computer, Radio']                                                                                                                                                                                                             1
# ['Bluetooth, MP3, On-board computer, Radio, USB']                                                                                                                                                                                                        1
# ['CD player']                                                                                                                                                                                                                                            1
# ['CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']                                                                                                                                         2
# ['CD player, Digital radio, Integrated music streaming, On-board computer, Radio']                                                                                                                                                                       2
# ['CD player, Digital radio, MP3, On-board computer, Radio, Sound system']                                                                                                                                                                                2
# ['CD player, Digital radio, MP3, On-board computer, Radio, USB']                                                                                                                                                                                         2
# ['CD player, Digital radio, MP3, Radio']                                                                                                                                                                                                                 2
# ['CD player, Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                                     1
# ['CD player, Hands-free equipment, Radio, USB']                                                                                                                                                                                                          1
# ['CD player, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                                            2
# ['CD player, MP3, On-board computer, Radio']                                                                                                                                                                                                            12
# ['CD player, MP3, On-board computer, Radio, Sound system']                                                                                                                                                                                               1
# ['CD player, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                                                                                          1
# ['CD player, MP3, On-board computer, Radio, USB']                                                                                                                                                                                                        7
# ['CD player, MP3, Radio']                                                                                                                                                                                                                                1
# ['CD player, On-board computer, Radio']                                                                                                                                                                                                                  2
# ['CD player, On-board computer, Radio, USB']                                                                                                                                                                                                             1
# ['CD player, On-board computer, USB']                                                                                                                                                                                                                    1
# ['CD player, Radio']                                                                                                                                                                                                                                     2
# ['Digital cockpit, Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                               3
# ['Digital cockpit, Induction charging for smartphones, MP3, USB']                                                                                                                                                                                        1
# ['Digital cockpit, On-board computer, Radio, Sound system']                                                                                                                                                                                              1
# ['Digital radio']                                                                                                                                                                                                                                        3
# ['Digital radio, Hands-free equipment, On-board computer, Radio']                                                                                                                                                                                        1
# ['Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']                                                                                                                                                     1
# ['Digital radio, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']                                                                                                                      1
# ['Digital radio, Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                                        3
# ['Digital radio, MP3, Radio, USB']                                                                                                                                                                                                                       2
# ['Digital radio, On-board computer, Radio']                                                                                                                                                                                                              3
# ['Digital radio, On-board computer, Radio, Sound system']                                                                                                                                                                                                1
# ['Hands-free equipment, MP3, On-board computer, Radio, USB']                                                                                                                                                                                             2
# ['Hands-free equipment, On-board computer, Radio']                                                                                                                                                                                                       1
# ['Integrated music streaming, MP3, On-board computer, Radio, USB']                                                                                                                                                                                       2
# ['MP3, On-board computer, Radio, USB']                                                                                                                                                                                                                   1
# ['On-board computer']                                                                                                                                                                                                                                    8
# ['On-board computer, Radio']                                                                                                                                                                                                                             6
# ['On-board computer, Radio, USB']                                                                                                                                                                                                                        3
# ['On-board computer, Radio, WLAN / WiFi hotspot']                                                                                                                                                                                                        2
# ['On-board computer, USB, WLAN / WiFi hotspot']                                                                                                                                                                                                          1
# ['Radio']                                                                                                                                                                                                                                                2
# ['Sound system']                                                                                                                                                                                                                                         1
# Name: entertainment_&_media, dtype: int64

# %%
df['entertainment_&_media'].unique()
# Out:
# array(["['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, Sound system']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, On-board computer, Sound system, Television']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['CD player, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio']",
#        "['Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Digital cockpit, Digital radio, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['CD player, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, Television, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, Television, WLAN / WiFi hotspot']",
#        "['CD player, Radio']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Induction charging for smartphones, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Hands-free equipment, On-board computer, Radio']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Hands-free equipment, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, MP3, On-board computer, Radio']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']",
#        "['CD player, Hands-free equipment, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, Radio, Sound system, USB']",
#        "['Android Auto, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, Radio, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio']",
#        "['Digital radio, On-board computer, Radio, Sound system']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Digital radio, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Integrated music streaming, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, MP3, On-board computer, USB']",
#        "['Bluetooth, Digital radio, MP3, On-board computer, Radio, USB']",
#        "['CD player, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']",
#        "['On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Digital radio, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, WLAN / WiFi hotspot']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['CD player, Digital radio, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Hands-free equipment, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, USB']",
#        "['Digital radio']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['CD player']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, USB']",
#        "['Digital cockpit, Induction charging for smartphones, MP3, USB']",
#        "['Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['On-board computer']",
#        "['Digital radio, Hands-free equipment, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, USB']",
#        "['CD player, Digital radio, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Digital radio, MP3, Radio, USB']",
#        "['Apple CarPlay, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Digital radio, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['CD player, Digital radio, MP3, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']",
#        "['CD player, MP3, Radio']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, USB']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['CD player, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['CD player, Digital radio, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Digital radio, Hands-free equipment, On-board computer, Radio']",
#        "['Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, MP3, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Television, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, MP3, Radio, USB']",
#        "['CD player, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, On-board computer, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Television, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, USB']",
#        "['Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Sound system, USB']",
#        "['Android Auto, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital radio, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Hands-free equipment, Integrated music streaming, On-board computer, Radio']",
#        "['Bluetooth, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Digital cockpit, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, CD player, Digital cockpit, Digital radio, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Digital radio, On-board computer, Radio, USB']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, On-board computer, Radio, USB']",
#        "['CD player, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital radio, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['On-board computer, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['CD player, On-board computer, USB']",
#        "['Digital cockpit, On-board computer, Radio, Sound system']",
#        "['MP3, On-board computer, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Digital radio, On-board computer']",
#        "['Android Auto, Apple CarPlay, Digital radio, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones, Integrated music streaming, MP3, On-board computer, Radio, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Digital radio, Induction charging for smartphones']",
#        "['Bluetooth, Hands-free equipment']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB']",
#        "['CD player, On-board computer, Radio, USB']", "['Sound system']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, Induction charging for smartphones, MP3, On-board computer, Radio, USB']",
#        "['Apple CarPlay, Bluetooth, Digital radio, Hands-free equipment, On-board computer, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['CD player, Digital radio, Integrated music streaming, On-board computer, Radio']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, Induction charging for smartphones, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, CD player, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['CD player, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system']",
#        "['Android Auto, Apple CarPlay, Bluetooth, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']",
#        "['Android Auto, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, Integrated music streaming, On-board computer, Radio, Sound system']",
#        "['Apple CarPlay, Bluetooth, CD player, Digital cockpit, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Apple CarPlay, Bluetooth, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Bluetooth, CD player, Digital radio, Hands-free equipment, Integrated music streaming, MP3, On-board computer, Radio, Sound system, Television, USB, WLAN / WiFi hotspot']",
#        "['Apple CarPlay, Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, On-board computer, Radio, Sound system, USB']",
#        "['Android Auto, Apple CarPlay, Bluetooth, CD player, Hands-free equipment, MP3, Radio, Sound system, USB']",
#        "['Bluetooth, Digital cockpit, Digital radio, Hands-free equipment, MP3, On-board computer, Radio, Sound system, USB, WLAN / WiFi hotspot']"],
#       dtype=object)

# %%
#Option 1
media_plus = ["Digital", "Television"]

# media_plus = ["Digital radio", "Hands-free", "Television"]

entertainment_media_package = df['entertainment_&_media'].apply(lambda sentence: "Premium Media" if any(word in sentence for word in media_plus) else "Standard Media")
entertainment_media_package.value_counts()
# Out:
# Premium Media     1767
# Standard Media     597
# Name: entertainment_&_media, dtype: int64

# %%
#Option 2
# media_plus = ["Digital", "Television"]

media_plus = ["Digital radio", "Hands-free", "Television", "Induction charging for smartphones", "Apple"]

entertainment_media_package = df['entertainment_&_media'].apply(lambda sentence: "Premium Media" if any(word in sentence for word in media_plus) else "Standard Media")
entertainment_media_package.value_counts()
# Out:
# Premium Media     2296
# Standard Media      68
# Name: entertainment_&_media, dtype: int64

# %% [markdown]
# **Let us assign each car to related ``"Entertainment & Media Packages"`` defined above:**

# %%
media_plus = ["Digital", "Television"]

df['entertainment_&_media_Package'] = df['entertainment_&_media'].apply(lambda sentence: "Premium Media" if any(word in sentence for word in media_plus) else "Standard Media")
df
# Out:
#                  make_model           make    model  \
# 0      Mercedes-Benz E 400   Mercedes-Benz   E 400
# 1     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 2      Mercedes-Benz C 400   Mercedes-Benz   C 400
# 3     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 4     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# ...                     ...            ...      ...
# 2359             Volvo S60           Volvo     S60
# 2360             Volvo S90           Volvo     S90
# 2361             Volvo S90           Volvo     S90
# 2362             Volvo S60           Volvo     S60
# 2363             Volvo S60           Volvo     S60
#
#                                           location     price    body_type  \
# 0         Julius-Rütgers-Str. 1,  15537 Erkner, DE  64870.00  Convertible
# 1        Wormser Landstraße 194,  67346 Speyer, DE 197500.00  Convertible
# 2             Autofocus 3,  15517 Fürstenwalde, DE  63370.00  Convertible
# 3     Meckenheimer Straße 12,  53359 Rheinbach, DE 175000.00  Convertible
# 4      St.-Georgener-Straße 1,  79111 Freiburg, DE 149890.00  Convertible
# ...                                            ...       ...          ...
# 2359         Lagerstraße 12,  93055 Regensburg, DE  44990.00        Sedan
# 2360         Lagerstraße 12,  93055 Regensburg, DE  67990.00        Sedan
# 2361     Cannstatter Str. 46,  70190 Stuttgart, DE  37900.00        Sedan
# 2362         Lagerstraße 12,  93055 Regensburg, DE  46890.00        Sedan
# 2363     Hannöversche Str. 44,  44143 Dortmund, DE  43700.00        Sedan
#
#                  type  doors warranty  mileage first_registration    gearbox  \
# 0                Used   2.00      24  78473.00            01/2020  Automatic
# 1      Employee's car   2.00       0   9550.00            04/2021  Automatic
# 2      Employee's car   2.00      24  20145.00            01/2021  Automatic
# 3                Used   2.00      24   3561.00            07/2021  Automatic
# 4                Used   3.00      Yes 23851.00            12/2019  Automatic
# ...               ...    ...      ...      ...                ...        ...
# 2359             Used   4.00      12  10500.00            06/2021  Automatic
# 2360    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2361             Used   4.00      12  37846.00            04/2019  Automatic
# 2362    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2363    Demonstration   4.00      24  13500.00            09/2021  Automatic
#
#                            fuel_type  seller  seats  engine_size  gears  \
# 0           Diesel (Particle filter)  Dealer   4.00      2925.00   9.00
# 1                           Super 95  Dealer   2.00      3982.00   7.00
# 2                           Super 95  Dealer   4.00      2996.00   9.00
# 3                           Super 95  Dealer   2.00      3982.00   7.00
# 4     Super E10 95 (Particle filter)  Dealer   2.00      3982.00   7.00
# ...                              ...     ...    ...          ...    ...
# 2359                        Super 95  Dealer   5.00      1969.00   8.00
# 2360        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2361        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2362                        Super 95  Dealer   5.00      1969.00   8.00
# 2363      Super 95 (Particle filter)  Dealer   5.00      1969.00   8.00
#
#       co_emissions drivetrain  \
# 0           162.00        4WD
# 1           298.00       Rear
# 2           196.00        4WD
# 3           296.00       Rear
# 4           262.00       Rear
# ...            ...        ...
# 2359        140.00      Front
# 2360        128.00        4WD
# 2361        121.00        4WD
# 2362        145.00      Front
# 2363        145.00      Front
#
#                                   entertainment_&_media  \
# 0     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 1     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2     ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 3     ['Android Auto, Apple CarPlay, Digital radio, ...
# 4     ['Apple CarPlay, Bluetooth, Digital radio, Han...
# ...                                                 ...
# 2359  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2360  ['Bluetooth, Digital cockpit, Digital radio, H...
# 2361  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2362  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
# 2363  ['Android Auto, Apple CarPlay, Bluetooth, Digi...
#
#                                       safety_&_security  \
# 0     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 1     ['ABS, Adaptive Cruise Control, Alarm system, ...
# 2     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 3     ['ABS, Blind spot monitor, Central door lock, ...
# 4     ['ABS, Adaptive Cruise Control, Alarm system, ...
# ...                                                 ...
# 2359  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2360  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2361  ['ABS, Adaptive Cruise Control, Blind spot mon...
# 2362  ['ABS, Adaptive headlights, Bi-Xenon headlight...
# 2363  ['ABS, Adaptive Cruise Control, Adaptive headl...
#
#                                                  extras  empty_weight  \
# 0     Alloy wheels, Ambient lighting, Automatically ...       2010.00
# 1     Alloy wheels, Ambient lighting, Automatically ...       1735.00
# 2     Alloy wheels, Ambient lighting, Automatically ...       1825.00
# 3     Alloy wheels, Automatically dimming interior m...       1700.00
# 4     Alloy wheels (20"), Ambient lighting, Automati...       1700.00
# ...                                                 ...           ...
# 2359  Alloy wheels, Sport seats, Sport suspension, T...       1752.00
# 2360  Alloy wheels, Sport seats, Touch screen, Voice...       1790.00
# 2361  Alloy wheels (19"), Ambient lighting, Automati...       1866.00
# 2362  Sport seats, Sport suspension, Touch screen, V...       1799.00
# 2363  Alloy wheels, Catalytic Converter, Sport packa...       1819.00
#
#      full_service_history    upholstery  production_date  previous_owner  \
# 0                     Yes           NaN          2020.00            1.00
# 1                     Yes           NaN          2021.00            1.00
# 2                     Yes           NaN          2021.00            1.00
# 3                      No           NaN          2021.00            1.00
# 4                     Yes  Full leather          2019.00            2.00
# ...                   ...           ...              ...             ...
# 2359                  Yes  Part leather          2021.00            1.00
# 2360                   No  Full leather          2021.00            1.00
# 2361                  Yes  Part leather          2019.00            2.00
# 2362                   No  Part leather          2021.00            1.00
# 2363                  Yes  Part leather          2021.00            1.00
#
#      energy_efficiency_class                   new  combined_fuel_cons  \
# 0                  efficient   Mercedes-Benz E 400                6.20
# 1                unefficient  Mercedes-Benz AMG GT               13.00
# 2                unefficient   Mercedes-Benz C 400                8.60
# 3                unefficient  Mercedes-Benz AMG GT               12.90
# 4                unefficient  Mercedes-Benz AMG GT               11.50
# ...                      ...                   ...                 ...
# 2359               efficient             Volvo S60                6.20
# 2360               efficient             Volvo S90                4.90
# 2361               efficient             Volvo S90                4.60
# 2362               efficient             Volvo S60                6.30
# 2363               efficient             Volvo S60                6.30
#
#      comfort_&_convenience_Package entertainment_&_media_Package
# 0                          Premium                 Premium Media
# 1                          Premium                 Premium Media
# 2                         Standard                 Premium Media
# 3                         Standard                 Premium Media
# 4                          Premium                 Premium Media
# ...                            ...                           ...
# 2359                       Premium                 Premium Media
# 2360                       Premium                 Premium Media
# 2361                       Premium                 Premium Media
# 2362                       Premium                 Premium Media
# 2363                       Premium                 Premium Media
#
# [2364 rows x 32 columns]

# %%
df['entertainment_&_media_Package'].value_counts(dropna=False)
# Out:
# Premium Media     1767
# Standard Media     597
# Name: entertainment_&_media_Package, dtype: int64

# %%
df.shape
# Out:
# (2364, 32)

# %%
# There is no need for old 'entertainment_&_media' since a new feature of 'entertainment_&_media_Package' is created

df.drop("entertainment_&_media", axis=1, inplace=True)

# %%
df.shape
# Out:
# (2364, 31)

# %%
first_looking("extras")
# Out:
# COLUMN NAME    :  extras
# --------------------------------
# per_of_nulls   :  % 0.21
# num_of_nulls   :  5
# num_of_uniques :  1523
# --------------------------------
# Alloy wheels, Catalytic Converter, Touch screen, Voice Control                                                                                                                                    44
# Alloy wheels, Catalytic Converter, Roof rack, Touch screen                                                                                                                                        39
# Alloy wheels, Catalytic Converter, Touch screen                                                                                                                                                   35
# Alloy wheels, Catalytic Converter, Roof rack, Touch screen, Voice Control                                                                                                                         26
# Alloy wheels, Catalytic Converter                                                                                                                                                                 16
#                                                                                                                                                                                                   ..
# Alloy wheels (16"), Ambient lighting, E10-enabled, Electronic parking brake, Emergency tyre repair kit, Roof rack, Touch screen, Voice Control, Winter package                                     1
# Alloy wheels, Ambient lighting, Automatically dimming interior mirror, Cargo barrier, E10-enabled, Emergency tyre repair kit, Roof rack, Touch screen, Voice Control, Winter package               1
# Alloy wheels (17"), Ambient lighting, Automatically dimming interior mirror, Cargo barrier, E10-enabled, Electronic parking brake, Emergency tyre repair kit, Roof rack, Ski bag, Summer tyres     1
# Alloy wheels, Automatically dimming interior mirror, Cargo barrier, E10-enabled, Emergency tyre repair kit, Roof rack, Summer tyres, Touch screen, Voice Control, Winter package                   1
# Alloy wheels, Catalytic Converter, Sport package, Sport suspension, Touch screen, Voice Control                                                                                                    1
# Name: extras, Length: 1524, dtype: int64

# %%
#  fills the missing values in the "extras" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "extras", "mode")
# Out:
# COLUMN NAME    :  extras
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1523
# --------------------------------
# All season tyres, Alloy wheels (15"), Ambient lighting, Automatically dimming interior mirror, Cargo barrier, E10-enabled, Emergency tyre repair kit, Spare tyre, Spoiler, Sport seats, Touch screen, Voice Control                    1
# All season tyres, Alloy wheels (15"), Ambient lighting, Automatically dimming interior mirror, Cargo barrier, E10-enabled, Emergency tyre repair kit, Spare tyre, Spoiler, Sport seats, Touch screen, Voice Control, Winter package    3
# All season tyres, Alloy wheels (15"), Automatically dimming interior mirror, E10-enabled, Electronic parking brake, Emergency tyre                                                                                                     1
# All season tyres, Alloy wheels (15"), Automatically dimming interior mirror, E10-enabled, Emergency tyre repair kit                                                                                                                    1
# All season tyres, Alloy wheels (15"), Catalytic Converter, E10-enabled, Emergency tyre repair kit, Voice Control, Winter package                                                                                                       1
#                                                                                                                                                                                                                                       ..
# Sport seats, Touch screen, Voice Control                                                                                                                                                                                               1
# Steel wheels                                                                                                                                                                                                                           2
# Touch screen                                                                                                                                                                                                                           4
# Touch screen, Voice Control                                                                                                                                                                                                            5
# Voice Control                                                                                                                                                                                                                          1
# Name: extras, Length: 1523, dtype: int64

# %%
first_looking("safety_&_security")
# Out:
# COLUMN NAME    :  safety_&_security
# --------------------------------
# per_of_nulls   :  % 0.13
# num_of_nulls   :  3
# num_of_uniques :  1373
# --------------------------------
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Blind spot monitor, Central door lock, Central door lock with remote control, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Full-LED headlights, Head airbag, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Rear airbag, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition']    63
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                                 41
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Glare-free high beam headlights, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition']                                                                                  16
# ['ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control']                                                                                                                                                                                                                                                                                                            14
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                   14
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ..
# ['ABS, Adaptive Cruise Control, Central door lock, Daytime running lights, Distance warning system, Driver-side airbag, Electronic stability control, Emergency brake assistant, Fog lights, Full-LED headlights, Glare-free high beam headlights, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition']                                                                                                                                                              1
# ['ABS, Central door lock, Daytime running lights, Driver drowsiness detection, Electronic stability control, Full-LED headlights, Head airbag, Immobilizer, LED Daytime Running Lights, LED Headlights, Power steering, Speed limit control system, Traction control, Traffic sign recognition']                                                                                                                                                                                                                                                                                                                                                               1
# ['ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Full-LED headlights, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control']                                                                                                                                                                                                                                                                                                                     1
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Blind spot monitor, Central door lock, Distance warning system, Driver-side airbag, Electronic stability control, Emergency brake assistant, Fog lights, Full-LED headlights, Glare-free high beam headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Rear airbag, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control']                                                                                                                         1
# ['ABS, Adaptive headlights, Bi-Xenon headlights, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                                                                                                                             1
# Name: safety_&_security, Length: 1374, dtype: int64

# %%
# fills the missing values in the "safety_&_security" with the mode value based on "make_model" and "body_type"

fill(df, "make_model", "body_type", "safety_&_security", "mode")
# Out:
# COLUMN NAME    :  safety_&_security
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  1373
# --------------------------------
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Full-LED headlights, Glare-free high beam headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Laser headlights, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']     1
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                                                          14
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights']                                                                                                                                                     1
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Immobilizer, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                                                                   1
# ['ABS, Adaptive Cruise Control, Adaptive headlights, Alarm system, Bi-Xenon headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']                                                                                                                                       6
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# ['Central door lock, Central door lock with remote control, Daytime running lights, Electronic stability control, Emergency brake assistant, Fog lights, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, Passenger-side airbag, Power steering, Rear airbag, Side airbag, Speed limit control system, Tire pressure monitoring system']                                                                                                                                                                                                                                                                                                                                                 1
# ['Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Emergency brake assistant, Emergency system, Full-LED headlights, Head airbag, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system']                                                                                                                                                                                                                                                                                                                        1
# ['Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Emergency brake assistant, Emergency system, Full-LED headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traffic sign recognition']                                                                                                                                                                                                                                                1
# ['Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Emergency brake assistant, Emergency system, Full-LED headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traffic sign recognition']                                                                                                                                                                                                                                                                            1
# ['Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Emergency brake assistant, Emergency system, Full-LED headlights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traffic sign recognition']                                                                                                                                                                                                                                                                                              1
# Name: safety_&_security, Length: 1373, dtype: int64

# %%
# display all unique values in "safety_&_security"
# pd.set_option('display.max_rows', None)

df['safety_&_security'].unique()
# Out:
# array(["['ABS, Adaptive Cruise Control, Adaptive headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Full-LED headlights, Glare-free high beam headlights, Head airbag, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition']",
#        "['ABS, Adaptive Cruise Control, Alarm system, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Fog lights, Full-LED headlights, Glare-free high beam headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition']",
#        "['ABS, Adaptive Cruise Control, Adaptive headlights, Blind spot monitor, Central door lock, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Full-LED headlights, Glare-free high beam headlights, High beam assist, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Speed limit control system, Tire pressure monitoring system, Traction control, Traffic sign recognition']",
#        ...,
#        "['ABS, Central door lock, Daytime running lights, Distance warning system, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Immobilizer, Isofix, LED Daytime Running Lights, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control']",
#        "['ABS, Bi-Xenon headlights, Central door lock, Daytime running lights, Distance warning system, Driver-side airbag, Electronic stability control, Emergency brake assistant, Emergency system, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Xenon headlights']",
#        "['ABS, Adaptive headlights, Bi-Xenon headlights, Daytime running lights, Distance warning system, Driver drowsiness detection, Driver-side airbag, Electronic stability control, Emergency system, Fog lights, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Lane departure warning system, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control, Traffic sign recognition, Xenon headlights']"],
#       dtype=object)

# %%
premium = ["Tire pressure", "Daytime running lights", "LED Headlight", "Lane departure warning system"]
premium_plus = ["Traction control", "Emergency brake assistant", "Electronic stability control", "Adaptive"]

safety_security_package = df['safety_&_security'].apply(lambda sentence: "Safety Premium Package" if all(word in sentence for word in premium) else ("Safety Premium Plus Package" if all(word in sentence for word in premium_plus) else "Safety Standard Package"))
safety_security_package.value_counts()
# Out:
# Safety Premium Package         1240
# Safety Standard Package         820
# Safety Premium Plus Package     304
# Name: safety_&_security, dtype: int64

# %%
premium = ["Tire pressure", "Daytime running lights", "LED Headlight"]
premium_plus = ["Traction control", "Emergency brake assistant", "Electronic stability control"]

df['safety_&_security_Package'] = df['safety_&_security'].apply(lambda sentence: "Safety Premium Package" if all(word in sentence for word in premium) else ("Safety Premium Plus Package" if all(word in sentence for word in premium_plus) else "Safety Standard Package"))
df
# Out:
#                  make_model           make    model  \
# 0      Mercedes-Benz E 400   Mercedes-Benz   E 400
# 1     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 2      Mercedes-Benz C 400   Mercedes-Benz   C 400
# 3     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 4     Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# ...                     ...            ...      ...
# 2359             Volvo S60           Volvo     S60
# 2360             Volvo S90           Volvo     S90
# 2361             Volvo S90           Volvo     S90
# 2362             Volvo S60           Volvo     S60
# 2363             Volvo S60           Volvo     S60
#
#                                           location     price    body_type  \
# 0         Julius-Rütgers-Str. 1,  15537 Erkner, DE  64870.00  Convertible
# 1        Wormser Landstraße 194,  67346 Speyer, DE 197500.00  Convertible
# 2             Autofocus 3,  15517 Fürstenwalde, DE  63370.00  Convertible
# 3     Meckenheimer Straße 12,  53359 Rheinbach, DE 175000.00  Convertible
# 4      St.-Georgener-Straße 1,  79111 Freiburg, DE 149890.00  Convertible
# ...                                            ...       ...          ...
# 2359         Lagerstraße 12,  93055 Regensburg, DE  44990.00        Sedan
# 2360         Lagerstraße 12,  93055 Regensburg, DE  67990.00        Sedan
# 2361     Cannstatter Str. 46,  70190 Stuttgart, DE  37900.00        Sedan
# 2362         Lagerstraße 12,  93055 Regensburg, DE  46890.00        Sedan
# 2363     Hannöversche Str. 44,  44143 Dortmund, DE  43700.00        Sedan
#
#                  type  doors warranty  mileage first_registration    gearbox  \
# 0                Used   2.00      24  78473.00            01/2020  Automatic
# 1      Employee's car   2.00       0   9550.00            04/2021  Automatic
# 2      Employee's car   2.00      24  20145.00            01/2021  Automatic
# 3                Used   2.00      24   3561.00            07/2021  Automatic
# 4                Used   3.00      Yes 23851.00            12/2019  Automatic
# ...               ...    ...      ...      ...                ...        ...
# 2359             Used   4.00      12  10500.00            06/2021  Automatic
# 2360    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2361             Used   4.00      12  37846.00            04/2019  Automatic
# 2362    Demonstration   4.00      24   9990.00            02/2022  Automatic
# 2363    Demonstration   4.00      24  13500.00            09/2021  Automatic
#
#                            fuel_type  seller  seats  engine_size  gears  \
# 0           Diesel (Particle filter)  Dealer   4.00      2925.00   9.00
# 1                           Super 95  Dealer   2.00      3982.00   7.00
# 2                           Super 95  Dealer   4.00      2996.00   9.00
# 3                           Super 95  Dealer   2.00      3982.00   7.00
# 4     Super E10 95 (Particle filter)  Dealer   2.00      3982.00   7.00
# ...                              ...     ...    ...          ...    ...
# 2359                        Super 95  Dealer   5.00      1969.00   8.00
# 2360        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2361        Diesel (Particle filter)  Dealer   5.00      1969.00   8.00
# 2362                        Super 95  Dealer   5.00      1969.00   8.00
# 2363      Super 95 (Particle filter)  Dealer   5.00      1969.00   8.00
#
#       co_emissions drivetrain  \
# 0           162.00        4WD
# 1           298.00       Rear
# 2           196.00        4WD
# 3           296.00       Rear
# 4           262.00       Rear
# ...            ...        ...
# 2359        140.00      Front
# 2360        128.00        4WD
# 2361        121.00        4WD
# 2362        145.00      Front
# 2363        145.00      Front
#
#                                       safety_&_security  \
# 0     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 1     ['ABS, Adaptive Cruise Control, Alarm system, ...
# 2     ['ABS, Adaptive Cruise Control, Adaptive headl...
# 3     ['ABS, Blind spot monitor, Central door lock, ...
# 4     ['ABS, Adaptive Cruise Control, Alarm system, ...
# ...                                                 ...
# 2359  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2360  ['ABS, Adaptive Cruise Control, Adaptive headl...
# 2361  ['ABS, Adaptive Cruise Control, Blind spot mon...
# 2362  ['ABS, Adaptive headlights, Bi-Xenon headlight...
# 2363  ['ABS, Adaptive Cruise Control, Adaptive headl...
#
#                                                  extras  empty_weight  \
# 0     Alloy wheels, Ambient lighting, Automatically ...       2010.00
# 1     Alloy wheels, Ambient lighting, Automatically ...       1735.00
# 2     Alloy wheels, Ambient lighting, Automatically ...       1825.00
# 3     Alloy wheels, Automatically dimming interior m...       1700.00
# 4     Alloy wheels (20"), Ambient lighting, Automati...       1700.00
# ...                                                 ...           ...
# 2359  Alloy wheels, Sport seats, Sport suspension, T...       1752.00
# 2360  Alloy wheels, Sport seats, Touch screen, Voice...       1790.00
# 2361  Alloy wheels (19"), Ambient lighting, Automati...       1866.00
# 2362  Sport seats, Sport suspension, Touch screen, V...       1799.00
# 2363  Alloy wheels, Catalytic Converter, Sport packa...       1819.00
#
#      full_service_history    upholstery  production_date  previous_owner  \
# 0                     Yes           NaN          2020.00            1.00
# 1                     Yes           NaN          2021.00            1.00
# 2                     Yes           NaN          2021.00            1.00
# 3                      No           NaN          2021.00            1.00
# 4                     Yes  Full leather          2019.00            2.00
# ...                   ...           ...              ...             ...
# 2359                  Yes  Part leather          2021.00            1.00
# 2360                   No  Full leather          2021.00            1.00
# 2361                  Yes  Part leather          2019.00            2.00
# 2362                   No  Part leather          2021.00            1.00
# 2363                  Yes  Part leather          2021.00            1.00
#
#      energy_efficiency_class                   new  combined_fuel_cons  \
# 0                  efficient   Mercedes-Benz E 400                6.20
# 1                unefficient  Mercedes-Benz AMG GT               13.00
# 2                unefficient   Mercedes-Benz C 400                8.60
# 3                unefficient  Mercedes-Benz AMG GT               12.90
# 4                unefficient  Mercedes-Benz AMG GT               11.50
# ...                      ...                   ...                 ...
# 2359               efficient             Volvo S60                6.20
# 2360               efficient             Volvo S90                4.90
# 2361               efficient             Volvo S90                4.60
# 2362               efficient             Volvo S60                6.30
# 2363               efficient             Volvo S60                6.30
#
#      comfort_&_convenience_Package entertainment_&_media_Package  \
# 0                          Premium                 Premium Media
# 1                          Premium                 Premium Media
# 2                         Standard                 Premium Media
# 3                         Standard                 Premium Media
# 4                          Premium                 Premium Media
# ...                            ...                           ...
# 2359                       Premium                 Premium Media
# 2360                       Premium                 Premium Media
# 2361                       Premium                 Premium Media
# 2362                       Premium                 Premium Media
# 2363                       Premium                 Premium Media
#
#      safety_&_security_Package
# 0       Safety Premium Package
# 1       Safety Premium Package
# 2       Safety Premium Package
# 3       Safety Premium Package
# 4       Safety Premium Package
# ...                        ...
# 2359    Safety Premium Package
# 2360    Safety Premium Package
# 2361    Safety Premium Package
# 2362    Safety Premium Package
# 2363    Safety Premium Package
#
# [2364 rows x 32 columns]

# %%
df['safety_&_security_Package'].value_counts(dropna=False)
# Out:
# Safety Premium Package         1435
# Safety Premium Plus Package     606
# Safety Standard Package         323
# Name: safety_&_security_Package, dtype: int64

# %%
df.shape
# Out:
# (2364, 32)

# %%
df.drop("safety_&_security", axis=1, inplace=True)

# %%
df.shape
# Out:
# (2364, 31)

# %% [markdown]
# FINAL

# %%
df.head()
# Out:
#               make_model           make    model  \
# 0   Mercedes-Benz E 400   Mercedes-Benz   E 400
# 1  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 2   Mercedes-Benz C 400   Mercedes-Benz   C 400
# 3  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
# 4  Mercedes-Benz Amg Gt   Mercedes-Benz  Amg Gt
#
#                                        location     price    body_type  \
# 0      Julius-Rütgers-Str. 1,  15537 Erkner, DE  64870.00  Convertible
# 1     Wormser Landstraße 194,  67346 Speyer, DE 197500.00  Convertible
# 2          Autofocus 3,  15517 Fürstenwalde, DE  63370.00  Convertible
# 3  Meckenheimer Straße 12,  53359 Rheinbach, DE 175000.00  Convertible
# 4   St.-Georgener-Straße 1,  79111 Freiburg, DE 149890.00  Convertible
#
#               type  doors warranty  mileage first_registration    gearbox  \
# 0             Used   2.00      24  78473.00            01/2020  Automatic
# 1   Employee's car   2.00       0   9550.00            04/2021  Automatic
# 2   Employee's car   2.00      24  20145.00            01/2021  Automatic
# 3             Used   2.00      24   3561.00            07/2021  Automatic
# 4             Used   3.00      Yes 23851.00            12/2019  Automatic
#
#                         fuel_type  seller  seats  engine_size  gears  \
# 0        Diesel (Particle filter)  Dealer   4.00      2925.00   9.00
# 1                        Super 95  Dealer   2.00      3982.00   7.00
# 2                        Super 95  Dealer   4.00      2996.00   9.00
# 3                        Super 95  Dealer   2.00      3982.00   7.00
# 4  Super E10 95 (Particle filter)  Dealer   2.00      3982.00   7.00
#
#    co_emissions drivetrain                                             extras  \
# 0        162.00        4WD  Alloy wheels, Ambient lighting, Automatically ...
# 1        298.00       Rear  Alloy wheels, Ambient lighting, Automatically ...
# 2        196.00        4WD  Alloy wheels, Ambient lighting, Automatically ...
# 3        296.00       Rear  Alloy wheels, Automatically dimming interior m...
# 4        262.00       Rear  Alloy wheels (20"), Ambient lighting, Automati...
#
#    empty_weight full_service_history    upholstery  production_date  \
# 0       2010.00                  Yes           NaN          2020.00
# 1       1735.00                  Yes           NaN          2021.00
# 2       1825.00                  Yes           NaN          2021.00
# 3       1700.00                   No           NaN          2021.00
# 4       1700.00                  Yes  Full leather          2019.00
#
#    previous_owner energy_efficiency_class                   new  \
# 0            1.00               efficient   Mercedes-Benz E 400
# 1            1.00             unefficient  Mercedes-Benz AMG GT
# 2            1.00             unefficient   Mercedes-Benz C 400
# 3            1.00             unefficient  Mercedes-Benz AMG GT
# 4            2.00             unefficient  Mercedes-Benz AMG GT
#
#    combined_fuel_cons comfort_&_convenience_Package  \
# 0                6.20                       Premium
# 1               13.00                       Premium
# 2                8.60                      Standard
# 3               12.90                      Standard
# 4               11.50                       Premium
#
#   entertainment_&_media_Package safety_&_security_Package
# 0                 Premium Media    Safety Premium Package
# 1                 Premium Media    Safety Premium Package
# 2                 Premium Media    Safety Premium Package
# 3                 Premium Media    Safety Premium Package
# 4                 Premium Media    Safety Premium Package

# %%
df.shape
# Out:
# (2364, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2364 entries, 0 to 2363
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   make_model                     2364 non-null   object
#  1   make                           2364 non-null   object
#  2   model                          2364 non-null   object
#  3   location                       2364 non-null   object
#  4   price                          2364 non-null   float64
#  5   body_type                      2364 non-null   object
#  6   type                           2364 non-null   object
#  7   doors                          2364 non-null   float64
#  8   warranty                       2364 non-null   object
#  9   mileage                        2364 non-null   float64
#  10  first_registration             2364 non-null   object
#  11  gearbox                        2364 non-null   object
#  12  fuel_type                      2364 non-null   object
#  13  seller                         2364 non-null   object
#  14  seats                          2364 non-null   float64
#  15  engine_size                    2364 non-null   float64
#  16  gears                          2364 non-null   float64
#  17  co_emissions                   2364 non-null   float64
#  18  drivetrain                     2364 non-null   object
#  19  extras                         2364 non-null   object
#  20  empty_weight                   2364 non-null   float64
#  21  full_service_history           2364 non-null   object
#  22  upholstery                     2230 non-null   object
#  23  production_date                2364 non-null   float64
#  24  previous_owner                 2204 non-null   float64
#  25  energy_efficiency_class        2364 non-null   object
#  26  new                            2364 non-null   object
#  27  combined_fuel_cons             2364 non-null   float64
#  28  comfort_&_convenience_Package  2364 non-null   object
#  29  entertainment_&_media_Package  2364 non-null   object
#  30  safety_&_security_Package      2364 non-null   object
# dtypes: float64(11), object(20)
# memory usage: 572.7+ KB

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df)
# Out:
# Column upholstery has mixed object types.
#  NO PROBLEM  with the data types of Columns in the DataFrame.

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# make_model                      0.00
# make                            0.00
# model                           0.00
# location                        0.00
# price                           0.00
# body_type                       0.00
# type                            0.00
# doors                           0.00
# warranty                        0.00
# mileage                         0.00
# first_registration              0.00
# gearbox                         0.00
# fuel_type                       0.00
# seller                          0.00
# seats                           0.00
# engine_size                     0.00
# gears                           0.00
# co_emissions                    0.00
# drivetrain                      0.00
# extras                          0.00
# empty_weight                    0.00
# full_service_history            0.00
# upholstery                      5.67
# production_date                 0.00
# previous_owner                  6.77
# energy_efficiency_class         0.00
# new                             0.00
# combined_fuel_cons              0.00
# comfort_&_convenience_Package   0.00
# entertainment_&_media_Package   0.00
# safety_&_security_Package       0.00
# dtype: float64

# %%
df.duplicated(keep=False).sum()
# Out:
# 327

# %%
df[df.duplicated(keep=False)]
# Out:
#                     make_model           make               model  \
# 79       Mercedes-Benz Amg Gt   Mercedes-Benz             Amg Gt
# 80       Mercedes-Benz Amg Gt   Mercedes-Benz             Amg Gt
# 83     Mercedes-Benz S 63 Amg   Mercedes-Benz           S 63 Amg
# 84     Mercedes-Benz S 63 Amg   Mercedes-Benz           S 63 Amg
# 141    Mercedes-Benz C 43 Amg   Mercedes-Benz           C 43 Amg
# 142    Mercedes-Benz C 43 Amg   Mercedes-Benz           C 43 Amg
# 203       Mercedes-Benz G 400   Mercedes-Benz              G 400
# 204       Mercedes-Benz G 400   Mercedes-Benz              G 400
# 263       Mercedes-Benz C 200   Mercedes-Benz              C 200
# 264       Mercedes-Benz C 200   Mercedes-Benz              C 200
# 271       Mercedes-Benz C 220   Mercedes-Benz              C 220
# 272       Mercedes-Benz C 220   Mercedes-Benz              C 220
# 552          Opel Grandland X            Opel        Grandland X
# 553          Opel Grandland X            Opel        Grandland X
# 554          Opel Crossland X            Opel        Crossland X
# 564          Opel Crossland X            Opel        Crossland X
# 581          Opel Grandland X            Opel        Grandland X
# 585          Opel Grandland X            Opel        Grandland X
# 587          Opel Grandland X            Opel        Grandland X
# 588          Opel Grandland X            Opel        Grandland X
# 625          Opel Crossland X            Opel        Crossland X
# 632          Opel Crossland X            Opel        Crossland X
# 653                Opel Mokka            Opel              Mokka
# 654                Opel Mokka            Opel              Mokka
# 1158               Seat Ibiza            Seat              Ibiza
# 1162               Seat Ibiza            Seat              Ibiza
# 1202             Skoda Kodiaq           Skoda             Kodiaq
# 1205             Skoda Kodiaq           Skoda             Kodiaq
Frankfurter Landstraße 80 + 88,  61440 Oberurs...  47630.00
# 2333               Stockumer Str. 80,  58453 Witten, DE  33660.00
# 2334               Stockumer Str. 80,  58453 Witten, DE  27980.00
# 2335               Stockumer Str. 80,  58453 Witten, DE  33880.00
# 2336  Frankfurter Landstraße 80 + 88,  61440 Oberurs...  35950.00
# 2337    Zeppelinstr. 14-16,  88239 Wangen im Allgäu, DE  22590.00
# 2338               Stockumer Str. 80,  58453 Witten, DE  48880.00
# 2339               Stockumer Str. 80,  58453 Witten, DE  38780.00
# 2340           Nürnberger Str. 51,  91126 Schwabach, DE  35560.00
# 2341               Stockumer Str. 80,  58453 Witten, DE  17980.00
# 2342               Stockumer Str. 80,  58453 Witten, DE  35880.00
# 2343  An der Seilfahrt 2,  45472 Mülheim an der Ruhr...  32990.00
# 2344  An der Seilfahrt 2,  45472 Mülheim an der Ruhr...  33480.00
# 2345               Stockumer Str. 80,  58453 Witten, DE  33930.00
#
#              body_type             type  doors warranty   mileage  \
# 79               Coupe             Used   5.00      24   74566.00
# 80               Coupe             Used   5.00      24   74566.00
# 83               Coupe             Used   3.00      24   26338.00
# 84               Coupe             Used   3.00      24   26338.00
# 141              Coupe    Demonstration   2.00      24    4900.00
# 142              Coupe    Demonstration   2.00      24    4900.00
# 203   Off-Road/Pick-Up   Employee's car   5.00      24   23989.00
# 204   Off-Road/Pick-Up   Employee's car   5.00      24   23989.00
# 263      Station Wagon             Used   5.00      12   86063.00
# 264      Station Wagon             Used   5.00      12   86063.00
# 271      Station Wagon             Used   5.00      Yes  98397.00
# 272      Station Wagon             Used   5.00      Yes  98397.00
# 552   Off-Road/Pick-Up             Used   5.00      60   42112.00
# 553   Off-Road/Pick-Up             Used   5.00      60   42112.00
# 554   Off-Road/Pick-Up   Employee's car   5.00      60    9990.00
# 564   Off-Road/Pick-Up   Employee's car   5.00      60    9990.00
# 581   Off-Road/Pick-Up             Used   5.00      60    9666.00
# 585   Off-Road/Pick-Up             Used   5.00      60    9666.00
# 587   Off-Road/Pick-Up             Used   5.00      60   60000.00
# 588   Off-Road/Pick-Up             Used   5.00      60   60000.00
# 625   Off-Road/Pick-Up   Employee's car   5.00      60    4990.00
# 632   Off-Road/Pick-Up   Employee's car   5.00      60    4990.00
# 653   Off-Road/Pick-Up   Pre-registered   5.00      72      15.00
# 654   Off-Road/Pick-Up   Pre-registered   5.00      72      15.00
# 1158             Sedan   Pre-registered   5.00      48      10.00
# 1162             Sedan   Pre-registered   5.00      48      10.00
# 1202  Off-Road/Pick-Up   Pre-registered   5.00      Yes    100.00
# 1205  Off-Road/Pick-Up   Pre-registered   5.00      Yes    100.00
# 1207  Off-Road/Pick-Up   Pre-registered   5.00      Yes    100.00
# 1239     Station Wagon   Pre-registered   5.00      Yes      5.00
# 1243     Station Wagon   Pre-registered   5.00      Yes      5.00
# 1308           Compact   Pre-registered   5.00      36      20.00
# 1309           Compact   Pre-registered   5.00      36      20.00
# 1425  Off-Road/Pick-Up   Pre-registered   5.00      Yes      5.00
# 1427  Off-Road/Pick-Up             Used   5.00      12   23000.00
# 1430  Off-Road/Pick-Up             Used   5.00      12   23000.00
